# %% [markdown]
# ## การสร้าง Lexicon
#
# รายการ Library ที่ต้องติดตั้งก่อนใช้งานโปรแกรม
#
# 1.pycld2 : https://pypi.org/project/pycld2/
#
# 2.python-numpy : https://www.numpy.org/devdocs/user/quickstart.html
#
# 3.libicu-dev : https://pypi.org/project/PyICU/
#
# 4.polyglot : https://polyglot.readthedocs.io/en/latest/Installation.html

# %% [markdown]
# ## Import library

# %%
from nltk import word_tokenize as wdtk, FreqDist as fqdist
from polyglot.text import Text 
from __future__ import division
import pandas as pd
import csv
import os, errno
import math
import pandas as pd

# %% [markdown]
# ## กำหนดไฟล์ Dataset
#
# ##Root_dir = /home/ubuntu/datascience
#
# ตำแหน่งการอัพโหลดไฟล์ Dataset.txt : sentiment_file/[project_name]/Dataset/dataset.txt

# %%
###-- Project Name --###

project_name = "true" # <--- Rename 

### Config Project Name ###
answer = "dataset.txt" 
dir_lex = "lexicon"

pos_doc = []
neg_doc = []
neu_doc = []
pol= ""
pfd = ""

### วนลูบไฟล์ Dataset

with open("sentiment_file/"+project_name+"/Dataset/"+answer, "r") as ins: 

        i = 1; 
        
        for line in ins:
            
            result = [x.strip() for x in line.split('::')] 
            
            if result :
                
                #pol : sentiment
                #blob : text
                #blob = result[3].strip()
                
                pol =  result[5]
                blob = result[3]
                text = Text(blob.lower()) 
                
                
                #sentiment : neutral
                
                if pol == '0' :
                    
                        pol = 0
                
                        try:
                        
                            for w in text.words:
                            
                                #print("{:<16}{:>2}".format(w.encode('utf-8'), pol))
                                neu_doc.append(w)
                            
                        except:
                                
                                print ("NULL")
                        
                #sentiment : positive
        
                if pol == '1' :
                
                        pol = 1
                    
                        try:
                        
                            for w in text.words:
                            
                                #print("{:<16}{:>2}".format(w.encode('utf-8'), pol))
                                pos_doc.append(w)
                            
                        except:
                                
                                print ("NULL")
                        
                #sentiment : negative  
                
                if pol == '-1' :
                    
                        pol = -1
                        
                        try:
                        
                            for w in text.words:
                            
                                #print("{:<16}{:>2}".format(w.encode('utf-8'), pol))
                                neg_doc.append(w)
                            
                        except:
                                
                                print ("NULL")
                                
                                

### Check Folder and Files

ckdir = dir_lex+'/'+project_name

try:
    os.makedirs(ckdir)
except OSError as e:
    if e.errno != errno.EEXIST:
        raise

# -------------- นับจำนวน Positive ------------------- #

#นับจำนวนคำที่ซ้ำกันในแต่ละคำ เช่น สวัสดี : 10.

pos_dict = {po:pos_doc.count(po) for po in pos_doc}

print ("pos_dic + = "+str(pos_dict))


with open(dir_lex+'/'+project_name+'/dic_positive.txt', 'a') as the_file:
    for x in pos_dict.keys():
        the_file.write('%s:%d\n' % (x,pos_dict[x]))
        print ('+ : '+str(x)+str(pos_dict[x]) )
        
# -------------- นับจำนวน Negative ------------------- #

#นับจำนวนคำที่ซ้ำกันในแต่ละคำ เช่น สวัสดี : 10.
        
neg_dict = {ng:neg_doc.count(ng) for ng in neg_doc}

print ("neg_dic -  = "+str(neg_dict))

with open(dir_lex+'/'+project_name+'/dic_negative.txt', 'a') as the_file:
    for x in neg_dict.keys():
        the_file.write('%s:%d\n' % (x,neg_dict[x]))
        print ('- : '+str(x)+str(neg_dict[x]) )
        
# -------------- นับจำนวน Neutral ------------------- #

#นับจำนวนคำที่ซ้ำกันในแต่ละคำ เช่น สวัสดี : 10.
neu_dict = {ne:neu_doc.count(ne) for ne in neu_doc}
# print "neg_dic -  = "+str(neg_dict)
print ("neu_dic 0 = "+str(neu_dict))

with open(dir_lex+'/'+project_name+'/dic_neutral.txt', 'a') as the_file:
    for x in neu_dict.keys():
        the_file.write('%s:%d\n' % (x,neu_dict[x]))
        print ('0 : '+str(x)+str(neu_dict[x]) )
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# pos_dic + = {'อยาก': 16, 'ได้': 72, 'โปรdtacที่': 2, 'คุ้ม': 5, 'กว่า': 52, 'นี้': 45, 'หรือ': 23, 'โปร': 49, 'ย้าย': 72, 'ค่าย': 61, 'ของ': 30, 'ais': 97, 'true': 83, '-': 199, 'hก็ได้': 2, 'ครับ': 63, '[': 23, 'dtac': 33, ',': 53, 'app': 1, 'reward': 3, 'trinet': 3, ']': 23, 'คือ': 19, 'ใช้': 72, 'โปร699': 1, 'เน็ต6mbps': 1, 'ไม่': 93, 'จำกัด': 2, 'ผม': 48, 'โทร': 17, 'ด้วย': 16, 'ก็': 42, 'ก็ได้': 6, 'ซึ่ง': 4, 'เคย': 16, 'ขอ': 16, 'โปรdtacที': 1, 'เพื่อน': 2, 'เขา': 4, 'แจ้ง': 6, 'ว่า': 36, 'ต้อง': 25, 'รอ': 14, 'ช่วง': 7, 'ใน': 51, 'การ': 47, 'จัด': 3, 'นาน': 12, 'มาก': 19, 'จน': 6, 'คิด': 5, 'จะ': 51, 'แล้ว': 37, 'นะ': 19, 'ตอน': 19, 'โปร899': 1, 'จ่าย': 10, '629บ': 1, '.': 70, 'เน้ต30gb': 1, 'โทร400นาที': 1, 'เรา': 12, 'ไป': 66, 'ออก': 7, 'ทราบ': 4, 'มี': 58, 'ที่': 117, 'ราคา': 30, 'ดี': 66, 'มั้ย': 3, 'แนะนำ': 6, 'หน่อย': 6, 'ตก': 5, 'เดือน': 34, 'ละ': 12, 'เกือบ1พัน': 1, 'เพราะ': 7, 'อีก': 10, 'ราย': 18, 'ตัด': 18, 'บิล': 2, 'ทุกๆ': 2, 'วัน': 24, '16': 6, 'ผ่าน': 13, 'มา': 60, 'แต่': 43, 'เต็ม': 5, 'ไหม': 15, '?': 109, 'online': 4, 'เบอร์': 18, 'เดิม': 19, 'ผมมี': 1, 'ลอง': 5, 'ซื้อ': 13, 'เอา': 5, 'ซิม': 2, 'เติม': 6, 'เงิน': 17, 'ปราก': 2, 'ฎ': 2, 'เน็ต': 46, 'มากๆ': 13, 'ย่าน': 2, 'อยู่': 23, 'ทำงาน': 4, 'แถว': 7, 'รถไฟฟ้า': 4, 'ตลอด': 12, '7': 5, 'ปี': 23, 'ระหว่าง': 1, 'บน': 7, 'bts': 1, '+': 7, 'แอร์': 1, 'พอร์ต': 1, 'ลิงค์': 1, 'ตั้งแต่': 3, 'พญาไท': 1, 'ยัน': 1, 'สุวรรณภูมิ': 1, 'เส้น': 1, 'เสถียร': 7, 'เลย': 43, 'ย': 6, 'บ่นๆ': 1, 'ให้': 68, 'cc': 5, 'ฟัง': 1, 'รับ': 19, 'เรื่อง': 14, 'ไว้': 4, 'ไม่มี': 17, 'ไร': 3, 'เปลี่ยนแปลง': 1, 'หลาย': 6, 'ครั้ง': 7, 'เลิก': 2, 'ปัจจุบัน': 7, 'สัญญาณ': 13, 'เหมือน': 8, 'ล่าสุด': 2, 'บอก': 12, 'คุณ': 8, 'ลูกค้า': 19, 'รถไฟ': 1, 'วิ่ง': 2, 'ความเร็ว': 10, 'อาจ': 4, 'จับ': 1, 'นัก': 3, '(': 24, 'ใจ': 14, 'ทำไม': 19, 'มัน': 6, 'เกี่ยว': 1, 'มั๊ง': 1, ')': 27, 'เมื่อ': 9, '6': 4, 'อ': 2, 'กัน': 24, 'ห่วย': 3, 'หัก': 1, 'ทิ้ง': 2, 'ขึ้น': 9, 'แผน': 1, 'เห็น': 7, 'ร': 6, 'ทรู': 93, 'เท่ากับ': 1, 'และ': 32, 'สมัคร': 4, 'ก่อน': 13, '31': 1, 'ธันวา': 1, 'สนใจ': 10, 'อย่าง': 5, 'แรง': 13, 'ถาม': 7, 'ปกติ': 4, 'รอบ': 5, 'เกิด': 3, '19': 1, 'เสีย': 4, 'ค่า': 33, 'บริการ': 36, 'รึ': 3, 'แค่': 9, '3': 6, 'ขอบคุณ': 9, 'ปล': 1, 'ลับ': 1, 'เครื่อง': 11, 'ใหม่': 11, 'samsung': 3, 'smartphone': 1, 'truemove': 46, 'h': 51, 'จาก': 62, 'แทค': 4, 'เพื่อ': 8, 'ไหน': 15, 'คุ้มๆ': 2, 'บ้าง': 9, 'คะ': 10, 'j4': 1, 'ถ้า': 14, 'ออนไลน์': 5, 'หน้า': 10, 'เค้า': 3, 'เตอร์': 1, 'สะดวก': 5, 'ค่ะ': 26, 'มั๊ย': 3, 'โปร249': 2, 'เอ่ย': 1, 'ยอม': 2, 'ดีๆ': 1, 'มาบ': 2, 'อก': 4, 'หมด': 8, 'เพิ่ม': 3, 'เดียว': 3, 'แบบ': 14, 'ความ': 12, 'รู้สึก': 3, 'ใช้ais': 1, 'บ้าน': 17, 'ของaisfibre': 1, 'สน': 5, 'แคร์': 1, 'เก่า': 3, 'อะ': 1, 'ถึง': 28, 'เวลา': 18, 'สินะ': 1, 'น่า': 15, 'ครั': 5, 'ปลด': 1, 'ล็อค': 1, 'ด่วน': 2, 'แจ้': 1, 'งก': 1, 'สทช': 1, '08004242xx': 1, 'ปฎิ': 1, 'เสธ': 1, 'ยื้อ': 1, 'ว่าง': 1, 'ติดต่อ': 6, '359': 2, 'บาท': 16, '4': 8, 'gb': 3, 'พอ': 6, 'ต่อ': 7, 'เท่า': 3, 'ไหร่': 1, 'ทำ': 10, 'อย่างไร': 1, 'mobile': 6, 'internet': 3, 'สมมุติ': 1, 'special': 1, 'unlimited': 2, 'plus': 2, '300': 4, 'อั้น': 1, '6mbps': 1, '/': 175, 'นอก': 5, 'เครือ200นาที': 1, 'ราคา300บาท': 1, 'ส': 6, 'สมา': 4, 'รถ': 4, 'ศูนย์': 6, 'ป่าว': 2, 'เครือ': 8, 'ข่าย': 8, 'อื่น': 5, 'operator': 4, '24': 1, 'ธค': 1, 'ครบ': 10, 'สัญญา': 8, 'พร้อม': 13, 'แพค': 3, 'เก': 4, 'จนี้': 1, 'น้อย': 3, 'แพง': 4, 'ส่วน': 10, 'ใหญ่': 5, 'ถูกใจ': 1, 'เบ': 4, 'บอร์': 2, 'อิน': 2, 'เต': 2, 'อินเตอร์เน็ต': 6, 'เกิน': 6, '500': 2, 'เกจ': 3, 'ทันที': 3, 'พนักงาน': 8, 'สา': 4, 'ขา': 3, 'ฟิว': 3, 'เจอร์': 3, 'เลือก': 10, 'ผิด': 4, 'เกือบ2': 2, 'อาทิตย์': 5, 'ยัง': 15, 'แก้': 11, '4g': 8, 'รังสิต': 1, 'โบนัส': 3, 'ฟรี': 4, '1': 11, 'แรก': 2, 'เข้าไป': 6, 'หา': 10, 'สาขา': 4, 'ชั้น': 5, 'แก้ไข': 2, 'รอไป': 1, '2': 11, 'ตาม': 11, 'จี้': 1, 'เรียบร้อย': 2, 'เช็ค': 3, 'ดู': 16, 'สอง': 1, 'ล่าง': 2, 'เด๋ว': 1, 'ส่ง': 7, 'หน่วย': 1, 'งาน': 41, 'กลาง': 5, 'สาม': 1, 'สัปดาห์': 1, 'คืบ': 2, 'ใดๆ': 1, 'กลุ่ม': 1, 'เจอ': 8, 'สาเหตุ': 2, 'ปัญหา': 15, 'สรุป': 1 ...
# + : อยาก16
# + : ได้72
# + : โปรdtacที่2
# + : คุ้ม5
# + : กว่า52
# + : นี้45
# + : หรือ23
# + : โปร49
# + : ย้าย72
# + : ค่าย61
# + : ของ30
# + : ais97
# + : true83
# + : -199
# + : hก็ได้2
# + : ครับ63
# + : [23
# + : dtac33
# + : ,53
# + : app1
# + : reward3
# + : trinet3
# + : ]23
# + : คือ19
# + : ใช้72
# + : โปร6991
# + : เน็ต6mbps1
# + : ไม่93
# + : จำกัด2
# + : ผม48
# + : โทร17
# + : ด้วย16
# + : ก็42
# + : ก็ได้6
# + : ซึ่ง4
# + : เคย16
# + : ขอ16
# + : โปรdtacที1
# + : เพื่อน2
# + : เขา4
# + : แจ้ง6
# + : ว่า36
# + : ต้อง25
# + : รอ14
# + : ช่วง7
# + : ใน51
# + : การ47
# + : จัด3
# + : นาน12
# + : มาก19
# + : จน6
# + : คิด5
# + : จะ51
# + : แล้ว37
# + : นะ19
# + : ตอน19
# + : โปร8991
# + : จ่าย10
# + : 629บ1
# + : .70
# + : เน้ต30gb1
# + : โทร400นาที1
# + : เรา12
# + : ไป66
# + : ออก7
# + : ทราบ4
# + : มี58
# + : ที่117
# + : ราคา30
# + : ดี66
# + : มั้ย3
# + : แนะนำ6
# + : หน่อย6
# + : ตก5
# + : เดือน34
# + : ละ12
# + : เกือบ1พัน1
# + : เพราะ7
# + : อีก10
# + : ราย18
# + : ตัด18
# + : บิล2
# + : ทุกๆ2
# + : วัน24
# + : 166
# + : ผ่าน13
# + : มา60
# + : แต่43
# + : เต็ม5
# + : ไหม15
# + : ?109
# + : online4
# + : เบอร์18
# + : เดิม19
# + : ผมมี1
# + : ลอง5
# + : ซื้อ13
# + : เอา5
# + : ซิม2
# + : เติม6
# + : เงิน17
# + : ปราก2
# + : ฎ2
# + : เน็ต46
# + : มากๆ13
# + : ย่าน2
# + : อยู่23
# + : ทำงาน4
# + : แถว7
# + : รถไฟฟ้า4
# + : ตลอด12
# + : 75
# + : ปี23
# + : ระหว่าง1
# + : บน7
# + : bts1
# + : +7
# + : แอร์1
# + : พอร์ต1
# + : ลิงค์1
# + : ตั้งแต่3
# + : พญาไท1
# + : ยัน1
# + : สุวรรณภูมิ1
# + : เส้น1
# + : เสถียร7
# + : เลย43
# + : ย6
# + : บ่นๆ1
# + : ให้68
# + : cc5
# + : ฟัง1
# + : รับ19
# + : เรื่อง14
# + : ไว้4
# + : ไม่มี17
# + : ไร3
# + : เปลี่ยนแปลง1
# + : หลาย6
# + : ครั้ง7
# + : เลิก2
# + : ปัจจุบัน7
# + : สัญญาณ13
# + : เหมือน8
# + : ล่าสุด2
# + : บอก12
# + : คุณ8
# + : ลูกค้า19
# + : รถไฟ1
# + : วิ่ง2
# + : ความเร็ว10
# + : อาจ4
# + : จับ1
# + : นัก3
# + : (24
# + : ใจ14
# + : ทำไม19
# + : มัน6
# + : เกี่ยว1
# + : มั๊ง1
# + : )27
# + : เมื่อ9
# + : 64
# + : อ2
# + : กัน24
# + : ห่วย3
# + : หัก1
# + : ทิ้ง2
# + : ขึ้น9
# + : แผน1
# + : เห็น7
# + : ร6
# + : ทรู93
# + : เท่ากับ1
# + : และ32
# + : สมัคร4
# + : ก่อน13
# + : 311
# + : ธันวา1
# + : สนใจ10
# + : อย่าง5
# + : แรง13
# + : ถาม7
# + : ปกติ4
# + : รอบ5
# + : เกิด3
# + : 191
# + : เสีย4
# + : ค่า33
# + : บริการ36
# + : รึ3
# + : แค่9
# + : 36
# + : ขอบคุณ9
# + : ปล1
# + : ลับ1
# + : เครื่อง11
# + : ใหม่11
# + : samsung3
# + : smartphone1
# + : truemove46
# + : h51
# + : จาก62
# + : แทค4
# + : เพื่อ8
# + : ไหน15
# + : คุ้มๆ2
# + : บ้าง9
# + : คะ10
# + : j41
# + : ถ้า14
# + : ออนไลน์5
# + : หน้า10
# + : เค้า3
# + : เตอร์1
# + : สะดวก5
# + : ค่ะ26
# + : มั๊ย3
# + : โปร2492
# + : เอ่ย1
# + : ยอม2
# + : ดีๆ1
# + : มาบ2
# + : อก4
# + : หมด8
# + : เพิ่ม3
# + : เดียว3
# + : แบบ14
# + : ความ12
# + : รู้สึก3
# + : ใช้ais1
# + : บ้าน17
# + : ของaisfibre1
# + : สน5
# + : แคร์1
# + : เก่า3
# + : อะ1
# + : ถึง28
# + : เวลา18
# + : สินะ1
# + : น่า15
# + : ครั5
# + : ปลด1
# + : ล็อค1
# + : ด่วน2
# + : แจ้1
# + : งก1
# + : สทช1
# + : 08004242xx1
# + : ปฎิ1
# + : เสธ1
# + : ยื้อ1
# + : ว่าง1
# + : ติดต่อ6
# + : 3592
# + : บาท16
# + : 48
# + : gb3
# + : พอ6
# + : ต่อ7
# + : เท่า3
# + : ไหร่1
# + : ทำ10
# + : อย่างไร1
# + : mobile6
# + : internet3
# + : สมมุติ1
# + : special1
# + : unlimited2
# + : plus2
# + : 3004
# + : อั้น1
# + : 6mbps1
# + : /175
# + : นอก5
# + : เครือ200นาที1
# + : ราคา300บาท1
# + : ส6
# + : สมา4
# + : รถ4
# + : ศูนย์6
# + : ป่าว2
# + : เครือ8
# + : ข่าย8
# + : อื่น5
# + : operator4
# + : 241
# + : ธค1
# + : ครบ10
# + : สัญญา8
# + : พร้อม13
# + : แพค3
# + : เก4
# + : จนี้1
# + : น้อย3
# + : แพง4
# + : ส่วน10
# + : ใหญ่5
# + : ถูกใจ1
# + : เบ4
# + : บอร์2
# + : อิน2
# + : เต2
# + : อินเตอร์เน็ต6
# + : เกิน6
# + : 5002
# + : เกจ3
# + : ทันที3
# + : พนักงาน8
# + : สา4
# + : ขา3
# + : ฟิว3
# + : เจอร์3
# + : เลือก10
# + : ผิด4
# + : เกือบ22
# + : อาทิตย์5
# + : ยัง15
# + : แก้11
# + : 4g8
# + : รังสิต1
# + : โบนัส3
# + : ฟรี4
# + : 111
# + : แรก2
# + : เข้าไป6
# + : หา10
# + : สาขา4
# + : ชั้น5
# + : แก้ไข2
# + : รอไป1
# + : 211
# + : ตาม11
# + : จี้1
# + : เรียบร้อย2
# + : เช็ค3
# + : ดู16
# + : สอง1
# + : ล่าง2
# + : เด๋ว1
# + : ส่ง7
# + : หน่วย1
# + : งาน41
# + : กลาง5
# + : สาม1
# + : สัปดาห์1
# + : คืบ2
# + : ใดๆ1
# + : กลุ่ม1
# + : เจอ8
# + : สาเหตุ2
# + : ปัญหา15
# + : สรุป1
# + : โยน1
# + : คีบ1
# + : คน26
# + : ภายใน1
# + : องค์กร1
# + : ไม่ใช่2
# + : เกี่ยง1
# + : ใคร8
# + : เป็น20
# + : สิ1
# + : ที่ไหน1
# + : โอ2
# + : เคร1
# + : คับ2
# + : ช่วย6
# + : ขอบ6
# + : มายัง1
# + : 301
# + : 104
# + : 5996
# + : สี3
# + : เขียว1
# + : ใกล้2
# + : เคียง1
# + : 503
# + : 201
# + : ยิ่ง2
# + : ถูก20
# + : ฟ้า2
# + : 1004
# + : 5901
# + : fibre1
# + : คำถาม1
# + : ปรับ4
# + : ขาด1
# + : อีก41
# + : อะไร6
# + : ง้อ2
# + : ยกเลิก3
# + : ตัว26
# + : จ3
# + : คุย2
# + : กับ19
# + : โดย11
# + : เสนอ1
# + : ข้อแม้1
# + : คล้าย1
# + : ชาว1
# + : ขยาย1
# + : ฉลาด1
# + : แถม6
# + : มัด1
# + : ตอบ3
# + : สงสัย1
# + : ทน1
# + : เรียก2
# + : ติด1
# + : ตั้ง1
# + : สบาย1
# + : เปล่า2
# + : ฝาก2
# + : ข้อคิด1
# + : สัมพันธ์1
# + : ยาก4
# + : รักษา1
# + : tweeted19
# + : กู2
# + : เวอร์1
# + : ฟ1
# + : ลิก1
# + : กระตุก2
# + : ชัด1
# + : ระดับultrahd1
# + : มูฟ3
# + : เอช2
# + : ต้องการ5
# + : หลัง5
# + : เสียใจ1
# + : กับdtacมา1
# + : เกือบ10ปี1
# + : แนะ2
# + : นำ4
# + : พึ่ง2
# + : เข้า9
# + : เร็ว1
# + : ละเอียด2
# + : ประมาณ3
# + : 2001
# + : 2,4001
# + : กระเป๋า1
# + : เยอะ9
# + : คง4
# + : สามารถ8
# + : เปลี่ยน9
# + : โม5
# + : ชั่น5
# + : แท2
# + : ครา2
# + : 6992
# + : เม็ก4
# + : อัน8
# + : ลิ2
# + : มิต2
# + : mb5
# + : เต็มๆ1
# + : ฮะ1
# + : บอล1
# + : ผ่า1
# + : นท2
# + : รู5
# + : ไอ7
# + : ลื่นๆ1
# + : กี้1
# + : แท็ค1
# + : สมัย1
# + : สู้2
# + : ปะ1
# + : d1
# + : tac1
# + : 3bb1
# + : มา41
# + : ลด5
# + : หัน1
# + : ซิ4
# + : มดี1
# + : เเค่1
# + : 20001
# + : ใช้ได้3
# + : มือ13
# + : ถือ10
# + : พก1
# + : ปล่อย3
# + : ไวไฟ1
# + : คอม3
# + : ช1
# + : โหลด1
# + : หนัง3
# + : เล่น7
# + : เกมส์1
# + : ยู1
# + : ทูป1
# + : เฟส1
# + : ไลน์3
# + : กด5
# + : ปรึ๊ดๆ1
# + : รวดเร็ว1
# + : ทันใจ1
# + : 5551
# + : โปรais2
# + : move15
# + : เอาชนะ15
# + : ทั้งๆ16
# + : ขาย18
# + : โทรศัพท์18
# + : ทั้ง13
# + : ขนาด9
# + : กรุงเทพ5
# + : ตจว.คง4
# + : พูด5
# + : ยอมรับ2
# + : ไว5
# + : สุดๆ5
# + : หลังๆ2
# + : เริ่ม4
# + : ขั้น2
# + : ง่ายๆ3
# + : ทำให้2
# + : ยุ่ง2
# + : พยาม2
# + : ยาม2
# + : ที่สุด24
# + : คุณภาพ3
# + : เข้าใจ3
# + : rovers_no2
# + : 96
# + : พิมพ์2
# + : :110
# + : ครอบคลุม2
# + : ทั่ว4
# + : ประเทศ3
# + : คลื่น2
# + : สำหรับ7
# + : core2
# + : competency2
# + : อื่นๆ4
# + : แข่ง2
# + : รู้3
# + : ยุ่1
# + : เจ้าของ1
# + : นั้น1
# + : สมอง1
# + : เก่ง2
# + : ตาย1
# + : ก็ตาม3
# + : ยถากรรม1
# + : เมือง4
# + : เมือ2
# + : งก้2
# + : กาก3
# + : ตจว4
# + : บาง4
# + : แทบ2
# + : ไร้2
# + : น19
# + : ทุก10
# + : พื้นที่2
# + : มั่ว2
# + : ลา3
# + : แบ่ง1
# + : ทางการ1
# + : ตลาด2
# + : หนึ่ง6
# + : truetrue1
# + : นี่2
# + : trueid1
# + : 124
# + : พ่วง1
# + : เช่น2
# + : truevision1
# + : แพ้1
# + : ใด2
# + : เห4
# + : ตุ1
# + : บบ1
# + : แง่1
# + : call1
# + : center1
# + : เอาใจ1
# + : ใส่2
# + : ทำการ2
# + : ท่อง2
# + : ตำรา1
# + : แบ2
# + : บท1
# + : ด้าน3
# + : พอๆ1
# + : ต่าง6
# + : จังหวัด2
# + : อร์เน็ท1
# + : ไฟ3
# + : ไฟเบอร์1
# + : ประสบการณ์4
# + : ช้า4
# + : lost1
# + : signal1
# + : ขณะ1
# + : สิบ2
# + : vpn1
# + : หลุด2
# + : ช่าง3
# + : สิทธิ2
# + : พิเศษ2
# + : พวก1
# + : เซ2
# + : เรเนด1
# + : บัตร4
# + : ค่อย1
# + : นๆ1
# + : ท่าน6
# + : แลก2
# + : ห่าง2
# + : เรื่อยๆ1
# + : หรอก1
# + : อันดับ7
# + : nperf5
# + : spoil3
# + : แอป3
# + : พลิ1
# + : เคชั่1
# + : นที่6
# + : ทดสอบ7
# + : ดาวน์โหลด3
# + : ผู้6
# + : มากมาย4
# + : ทาง13
# + : ยก3
# + : ประเทศไทย2
# + : ผล2
# + : kpi1
# + : สำคัญ1
# + : 5.51
# + : แสน1
# + : ครึ่ง2
# + : 20181
# + : แต่ละ1
# + : success1
# + : ratio1
# + : อัตรา1
# + : ข้อมูล2
# + : สำเร็จ1
# + : 88.161
# + : %5
# + : download1
# + : bitrate2
# + : เฉลี่ย2
# + : 15.731
# + : s3
# + : upload1
# + : อัพโหลด1
# + : 8.411
# + : latency1
# + : สนอง1
# + : ปิง1
# + : 52.501
# + : ms1
# + : streaming1
# + : ประสิทธิภาพ2
# + : เนื่อง1
# + : 71.261
# + : browsing1
# + : เว็บ1
# + : 53.181
# + : ookla3
# + : speedtestttt1
# + : ฝั่ง1
# + : รางวัล2
# + : speedtest2
# + : โลก2
# + : ล้าน4
# + : 1901
# + : ยอด3
# + : 51
# + : คนใช้1
# + : ประจำ3
# + : 2.81
# + : ร่วม2
# + : ม4
# + : 81
# + : ที3
# + : source1
# + : https52
# + : droidsans.com1
# + : vs1
# + : award1
# + : นั่ง2
# + : นว1
# + : นคร1
# + : เนต2
# + : ชิ1
# + : บ2
# + : หาย1
# + : เขต1
# + : เท่านั้น6
# + : ล่ะ2
# + : ลง2
# + : ทันตา1
# + : commented3
# + : 6,9901
# + : โปรtruemove1
# + : package2
# + : 3,9902
# + : ธ.ค3
# + : 25615
# + : –1
# + : 152
# + : ม.ค2
# + : 25622
# + : เพ3
# + : ค4
# + : fun1
# + : ชำระ3
# + : ล่วง2
# + : 1,0002
# + : ส่วนลด2
# + : hot1
# + : deal1
# + : บ่น1
# + : จัง2
# + : อย่า7
# + : งงู้น1
# + : แย่3
# + : งงี้1
# + : เนี่ย1
# + : ซ้ำ1
# + : 1mbps1
# + : ปีด2
# + : เกม1
# + : หน่วง1
# + : แพ็คเกจ1
# + : แหละ2
# + : ยืนยัน1
# + : #355
# + : ติ่ง1
# + : กำลัง3
# + : aisแม่1
# + : ง3
# + : เหี้1
# + : สอน4
# + : เทคนิค3
# + : ซอยผม2
# + : บ๊2
# + : อบ4
# + : ทุย3
# + : ต่ำ2
# + : one2
# + : length2
# + : bob2
# + : ปรมาจารย์1
# + : by3
# + : อ่าง1
# + : ศิลา1
# + : ชลบุรี1
# + : อนุ1
# + : ญาติ1
# + : อาจารย์2
# + : channel4
# + : วิทยาทาน1
# + : ชม6
# + : โฟกัส20
# + : พลอย18
# + : ใส27
# + : ฉลอง4
# + : อันดับ1ใน2
# + : เอเชีย4
# + : แปซิฟิก4
# + : ซ้อน4
# + : 201812132
# + : กิจกรรม3
# + : ปิด7
# + : โรง2
# + : ภาพยนตร์4
# + : 4dx2
# + : aquaman4
# + : meet2
# + : &5
# + : greet2
# + : af2
# + : ชิด1
# + : 133
# + : ธันวาคม4
# + : 2561ที่1
# + : พา2
# + : รา2
# + : กอน2
# + : ซี4
# + : นี3
# + : เพล็2
# + : กซ์2
# + : truemoveh4gno1asiapacific12
# + : กัส9
# + : true5gleader12
# + : truemoveh9
# + : ผู้นำ5gตัว10
# + : จริง11
# + : 4gที่12
# + : retweeted37
# + : rt37
# + : @56
# + : japaikin1
# + : coffee1
# + : เมนู1
# + : 1แถม11
# + : สิทธิ์5
# + : black1
# + : card3
# + : frosty1
# + : วิป1
# + : ครีม1
# + : สดใส3
# + : ช็อค1
# + : เบลเยียม1
# + : 1451
# + : ฿4
# + : ต้อ2
# + : นรับค1
# + : ริ1
# + : สมาส1
# + : strawberry1
# + : chocolate1
# + : ช็อคฯ1
# + : นม2
# + : ตอ1
# + : รเบ1
# + : อรี่1
# + : หวาน6
# + : อม1
# + : เปรี้ยว1
# + : mocha1
# + : brown1
# + : มอ1
# + : เจ้ม1
# + : จ้น1
# + : ปั่น2
# + : หอมๆ1
# + : อร่อย1
# + : aroii1
# + : siam1
# + : square1
# + : รี1
# + : โน1
# + : เวท1
# + : t.co49
# + : 0z15qhxovq1
# + : ฝืน1
# + : เอง3
# + : กิตติคุณ1
# + : exclusive1
# + : ลูก1
# + : ค้า1
# + : สารคดี2
# + : โรงงาน1
# + : ผลิต1
# + : ไม้2
# + : เบสบอล1
# + : hd10
# + : ctbน้า1
# + : หงื1
# + : สาร1
# + : คดี1
# + : ใหม่ๆ1
# + : ช่อง5
# + : bit.ly1
# + : 2pxypva1
# + : ติดตาม7
# + : น่ะ1
# + : ชอบ4
# + : วิชั่น1
# + : เคเบิ้1
# + : ลดังๆ1
# + : fox1
# + : movies1
# + : axn1
# + : hob1
# + : nba1
# + : ture1
# + : x1
# + : ztye1
# + : discovry1
# + : national1
# + : geographic1
# + : explore3
# + : wild2
# + : life1
# + : เปิด23
# + : เฉพาะ1
# + : สมาชิก1
# + : ลิ้งค์1
# + : ป้องกัน1
# + : ลิขสิทธิ์1
# + : cherprangfc1
# + : event1
# + : 5g24
# + : digital1
# + : thailand1
# + : ศุกร์3
# + : 142
# + : สถาน1
# + : รน1
# + : ดิ้ง1
# + : ช้อป2
# + : ไอคอน1
# + : สยาม2
# + : 11.151
# + : ได้ที่2
# + : ar0fkivogy1
# + : cherprangbnk481
# + : xbyn5gx0ci1
# + : psk48official3
# + : อุ๋ง3
# + : showcase22
# + : ณ4
# + : iconsiam3
# + : ห้า3
# + : โมง3
# + : เช้า5
# + : งับ3
# + : ornbnk483
# + : bnk4825
# + : psk483
# + : goอร3
# + : zpqdyjqr1y3
# + : พี่8
# + : อ้น1
# + : พิธีกร1
# + : สาย1
# + : ฮา1
# + : แท้25
# + : เหนือ1
# + : สิ่ง1
# + : วอแว1
# + : ควงแขน1
# + : โอ้1
# + : อ้อน1
# + : ชิป่1
# + : ะ1
# + : เจมส์2
# + : จิ2
# + : jirayu_jj1
# + : jamesjigallery1
# + : mario_mm381
# + : ohnsri10001
# + : vyyrthqkp91
# + : จำ1
# + : ขับ2
# + : หลง3
# + : กลับ3
# + : ทุ่ง1
# + : นา1
# + : ต้นไม้1
# + : แมพ1
# + : หมุน1
# + : จ้า4
# + : าาา2
# + : ตำแหน่ง1
# + : จอด1
# + : ข้าง2
# + : คนละ1
# + : อำเภอ1
# + : ดีใจ1
# + : เย้1
# + : !6
# + : vlgvxmdths1
# + : room4
# + : service4
# + : news6
# + : 0812611
# + : แต้ว4
# + : ณฐพร2
# + : ยิ้ม2
# + : รับคำ1
# + : ภาพ6
# + : ทริป2
# + : ทะเล1
# + : ภูเก็ต2
# + : เพิ่ง1
# + : ควง1
# + : ต้น2
# + : อา1
# + : ชว์1
# + : กระชับ1
# + : รัก9
# + : เกาะ1
# + : ท่อน1
# + : เซต1
# + : สวย4
# + : ชุด1
# + : ว่าย1
# + : น้ำ3
# + : โชว์1
# + : เซ็กซี่1
# + : สวี1
# + : ท2
# + : คู่12
# + : อวด1
# + : แฟนๆ2
# + : เพียบ2
# + : ณฐ1
# + : พร2
# + : taewaew_natapohn1
# + : roomservicenews2
# + : trueinsidehd2
# + : truevisions2
# + : รายการ2
# + : ข่าว2
# + : บันเทิง2
# + : inside8
# + : good4
# + : morning4
# + : 07.302
# + : entertainment2
# + : day2
# + : 12.002
# + : เสาร์2
# + : 10.002
# + : tonight2
# + : 19.552
# + : 19.252
# + : 22.252
# + : visions2
# + : หมายเลข4
# + : 1132
# + : 3352
# + : sd2
# + : 382
# + : fanpage2
# + : facebook2
# + : cussaifamily5
# + : ready1
# + : ploysaiaf123
# + : 5qgtl52tfp1
# + : ml3l0ubn4k2
# + : pamoo983717365
# + : สัมภาษณ์5
# + : >6
# + : <5
# + : เดี่ยว5
# + : หนู5
# + : จิ้5
# + : wevj8kkulb5
# + : ป้าย2
# + : น้อง4
# + : ฝัน2
# + : า3
# + : focus_kittikun2
# + : evn9orxmr2
# + : opv1
# + : สตางค์1
# + : รุ่น1
# + : ที่21
# + : เด็ก1
# + : สร้าง4
# + : เพลง:เด็ก1
# + : จาก:sunny1
# + : parade1
# + : เครดิต:https1
# + : youtu.be1
# + : 8k_ngonkgt41
# + : ทำopvของ1
# + : bnk48มี1
# + : ชื่อ2
# + : เมมเบอร์1
# + : คนใน1
# + : ทำopv2
# + : เพลง20
# + : ประกอบ1
# + : คลิปopv1
# + : เม้น1
# + : ไลค์1
# + : donate1
# + : wallet6
# + : 06387426901
# + : คลิป3
# + : สำรอง1
# + : m.youtube.com1
# + : ucnxrtuavrd7qn6yez5viz4q1
# + : หลัก1
# + : ลืม1
# + : ฝา1
# + : กกดไลค์1
# + : แชร์2
# + : 1212611
# + : ปู5
# + : ยา4
# + : ประกาศ2
# + : แต่ง1
# + : แม3
# + : ทธิ3
# + : ว3
# + : หนัก1
# + : บราก1
# + : บริษัท1
# + : โป1
# + : รดักชั่น1
# + : เฮ้าส์1
# + : ตนเอง1
# + : มกราคม1
# + : รีส์2
# + : strang1
# + : girl1
# + : a1
# + : strange1
# + : land1
# + : ประเดิม1
# + : นางเอก1
# + : ธุรกิจ1
# + : นับ1
# + : เป็นการ1
# + : รากฐาน1
# + : ชีวิต1
# + : แต่งงาน1
# + : prayalundberg1
# + : mrbrag1
# + : บรา1
# + : ก3
# + : มาส1
# + : นาม1
# + : บิน3
# + : กิน1
# + : สนาม2
# + : เซล3
# + : ฟี่3
# + : สะดุด3
# + : ข้าพเจ้า3
# + : มั่นใจ3
# + : bikeอุ่น3
# + : mu6p5wsmb13
# + : รบกวน3
# + : หลักๆ2
# + : กทม1
# + : 7001
# + : ใจจ1
# + : ระ1
# + : สมควร1
# + : 4001
# + : นาที3
# + : เนท3
# + : 16gb1
# + : wifi2
# + : กำหนด1
# + : 16g1
# + : ไมค์1
# + : หัวข้อ2
# + : งการร1
# + : มั่ง1
# + : ป1
# + : จบ1
# + : super1
# + : non1
# + : stop1
# + : เน้น3
# + : โซ1
# + : เชีย1
# + : ลมี1
# + : เดีย1
# + : youtube1
# + : twitter1
# + : netflix4
# + : ซะ1
# + : google1
# + : map2
# + : พบ1
# + : เอ๋1
# + : ออ4
# + : สังเกต1
# + : พัก1
# + : มากกว่า1
# + : วววว1
# + : ฮัล1
# + : โหลๆ1
# + : พระราม4
# + : แวะ1
# + : mello1
# + : เถอะ1
# + : ch31
# + : december2
# + : fest2
# + : presented2
# + : ลาน2
# + : the1
# + : grand1
# + : เซนทรัล2
# + : พระราม91
# + : แ1
# + : จก1
# + : สุข1
# + : เมล1
# + : โล่1
# + : 452kmpcgdg1
# + : สาว1
# + : หาดใหญ่2
# + : 08130342691
# + : แอด1
# + : จริงใจ1
# + : cxqdzmluem1
# + : สวัสดี1
# + : สมช1
# + : พัน1
# + : ทิป1
# + : พอดี1
# + : ไก1
# + : สุด1
# + : มาท2
# + : ปีด4m1
# + : yugioh25002
# + : network1
# + : ระบบ1
# + : postpaid1
# + : เพื่อนๆ1
# + : *4
# + : เบื่อ2
# + : จริงๆ2
# + : เหอะ1
# + : จากaisไปtrueเพื่อ1
# + : ศุน1
# + : ย์trueได้1
# + : os1
# + : ร์ท1
# + : โฟน2
# + : ซื้อ6s1
# + : ของtrue1
# + : ศูนย์trueได้1
# + : เดิน2
# + : ตรวจ2
# + : สอบ1
# + : eservice1
# + : advanced1
# + : แสดง20
# + : จูงใจ1
# + : เน็1
# + : ทมา1
# + : กั๊กๆ1
# + : ขี้2
# + : เหนี่ยว1
# + : สอ1
# + : บนานๆ1
# + : ๆๆ1
# + : เกรงใจ1
# + : แทน1
# + : เน็ท1
# + : พัฒนา2
# + : 3g1
# + : แข็ง1
# + : ป๋า1
# + : วกับเน็ท1
# + : รีบ1
# + : อร์1
# + : วิท1
# + : หาร4
# + : 803
# + : premium3
# + : ultra3
# + : email3
# + : pass3
# + : kbank3
# + : ประกัน3
# + : อายุ4
# + : โอน4
# + : dm3
# + : line3
# + : cqp8662i3
# + : หารnetflix3
# + : netflixหาร3
# + : netflixth3
# + : zidkifc7qy1
# + : bebeeme11
# + : สอบถาม2
# + : thai2
# + : ticket1
# + : major1
# + : we1
# + : master1
# + : money1
# + : คอนเสิร์ต2
# + : btslysbkk1
# + : btsworldtourbkk1
# + : btsloveyourselfbkk1
# + : qp1ng9rqku1
# + : 411
# + : days1
# + : to1
# + : go1
# + : unveil1
# + : tour1
# + : '2
# + : i1
# + : am1
# + : stay1
# + : กราบ1
# + : เนต4g1
# + : เวบ1
# + : ลั่น1
# + : แม่2
# + : straykids1
# + : unveiltourinbangkok1
# + : ehngiwwibu1
# + : replied6
# + : maamildd1
# + : พิ1
# + : เอ4
# + : เปง1
# + : ทรูอะ1
# + : คุน2
# + : ช็อป2
# + : ดูแล5
# + : เรียบ2
# + : ร้2
# + : เจ้า2
# + : หน้าที่2
# + : ๆ3
# + : ub4f7lhqpg1
# + : khajochi19
# + : bnk20
# + : festival19
# + : 5gที่19
# + : true5gdigitalthailand19
# + : tghcmvz1hs19
# + : ค่อน1
# + : ประทับ2
# + : ขาดตอน1
# + : เปรียบ1
# + : เทียบ1
# + : พนัก1
# + : งา1
# + : บaisเมื่อ1
# + : วาน1
# + : ลิบลับ1
# + : สนี่1
# + : ปฎิบัติ1
# + : กอะ1
# + : aisแย่1
# + : เสมอ2
# + : ปลาย1
# + : าา1
# + : ดีอะ2
# + : แย้ม1
# + : เสียง2
# + : อิaisนี่1
# + : ปุ๊บ1
# + : อี1
# + : ดอก1
# + : กกก1
# + : แอ1
# + : พก็1
# + : ไปรรรรร1
# + : ตก.ได้1
# + : กรีส1
# + : สสสสสส1
# + : live1
# + : part1
# + : บรรยากาศ1
# + : เดอะ1
# + : แก1
# + : รนด์1
# + : เซ็นทรัล1
# + : 481
# + : iucpmuynee1
# + : noeybnk481
# + : onefornoey1
# + : votefornoeybnk481
# + : thelittlefin9er1
# + : miraclefornoey1
# + : 71nqzl0nf1
# + : ลังเล1
# + : 6mb1
# + : 4mb1
# + : 2251
# + : แจ๊ค1
# + : แม้ว1
# + : ปรองดอง1
# + : g5nzve1ha01
# + : รหัส1
# + : เร็่ว1
# + : เจ1
# + : งี้1
# + : หรอ1
# + : ป่ะ1
# + : เศษ1
# + : มานะ1
# + : กว่า5ปีอะ1
# + : นี้5ปี1
# + : อีก3เบอร์1
# + : ศรัทธา1
# + : โน๊ะ1
# + : aisหรือ1
# + : วัน52บาท1
# + : vreeview2
# + : อินเทอร์เน็ต1
# + : หลาก1
# + : เพียง1
# + : ประโยชน์1
# + : ต่างๆ1
# + : อัพเดพ1
# + : วิดีโอ1
# + : ขึ้นpackage1
# + : repository1
# + : is1
# + : corrupted1
# + : ควร1
# + : ไง1
# + : ยินดี1
# + : asus1
# + : แพ็ก2
# + : iservice1
# + : bluesherbet_1
# + : งง1
# + : ~1
# + : ร1เม1
# + : กก1
# + : เดือน3991
# + : ค่ายdดี1
# + : 2เครื่อง1
# + : ชัดๆ1
# + : เน็ต4gหาย1
# + : nutyoyo1
# + : ปรกติ1
# + : หนี1
# + : ชะอำ1
# + : มีรร1
# + : ทม2
# + : รร2
# + : เล็กๆ2
# + : ริม1
# + : อ่าน1
# + : หนังสือ1
# + : แปลก1
# + : มัก1
# + : ลด501
# + : ใช้10991
# + : เหลือ500กว่า1
# + : redddtomato1
# + : มีwifi1
# + : ใข้1
# + : ลื่อ1
# + : นมี1
# + : ขีด1
# + : ถึง2ขีด1
# + : ตรัง1
# + : เป็นe1
# + : sim1
# + : อะคะ1
# + : ทรศ.กุงง1
# + : 55555555551
# + : ระยอง1
# + : โซน1
# + : ปลวกแดง1
# + : ยาง1
# + : เค1
# + : เห้อ1
# + : โทรศัพท์samsung1
# + : s91
# + : 4วัน1
# + : ปวด1
# + : ทวง1
# + : หนี้1
# + : คราว1
# + : ปอด1
# + : บึ้ม1
# + : อาจหาญ1
# + : คืน1
# + : เทพ2
# + : เนื่องจาก1
# + : 221
# + : พ.ย1
# + : 611
# + : 18.301
# + : ลาดพร้าว1
# + : บัญชี2
# + : กสิกร1
# + : ไทย1
# + : จขกท.เลย1
# + : 6,147.751
# + : 01.011
# + : รวม1
# + : ทั้งหมด1
# neg_dic -  = {'ได้': 742, 'จดหมาย': 42, 'ทวง': 37, 'หนี้': 72, 'จาก': 205, 'ทรู': 673, '[': 134, 'truemove': 183, 'h': 134, ',': 320, 'คุ้มครอง': 20, 'ผู้': 62, 'บริโภค': 24, 'ร้อง': 41, 'ทุกข์': 14, 'กฎหมาย': 14, 'ชาว': 16, 'บ้าน': 117, ']': 134, 'สวัสดี': 10, 'ค่ะ': 182, 'เนื่อง': 6, 'ด้วย': 120, 'วัน': 232, 'นี้': 446, 'ศุกร์': 3, 'ที่': 698, '21': 6, 'ธันวาคม': 12, '2561': 7, 'เรา': 339, 'รับ': 94, 'จ.ม': 4, '.': 351, '(': 95, 'ตัวแทน': 4, 'ของ': 205, ')': 97, 'ว่า': 498, 'ค้าง': 76, 'ค่า': 231, 'บริการ': 199, 'อยู่': 167, 'และ': 184, 'จะ': 484, 'ขอ': 108, 'เรียก': 44, 'เก็บ': 44, 'เป็น': 358, 'จำนวน': 9, '1,590.59': 1, 'บาท': 83, 'ราย': 136, 'ละเอียด': 15, 'ดัง': 10, 'จม': 2, 'แปะ': 2, 'ไว้': 37, 'ด่าน': 1, 'ล่าง': 2, 'เนื้อหา': 1, 'ใน': 182, 'บอก': 169, 'บริษัท': 50, 'เอ็น': 10, 'แอนด์': 9, 'วาย': 11, 'มอบ': 2, 'หมาย': 6, 'บ.เรี': 2, 'ยล': 6, 'มูฟ': 110, 'เพื่อ': 55, 'มา': 539, 'ตาม': 77, 'บ': 21, 'เพราะ': 124, 'แจ้ง': 174, 'ย้าย': 264, 'ค่าย': 286, 'เบ': 33, 'บอร์ดั': 1, 'ง': 9, 'อ้าง': 11, 'ยัง': 219, 'ไม่': 991, 'การ': 173, 'ชำระ': 83, 'เพิก': 6, 'เฉย': 19, '!': 140, '?': 343, '1': 40, 'เคย': 106, 'ติดต่อ': 64, 'อะไร': 194, 'เลย': 352, 'แม้แต่': 2, 'ครั้ง': 79, 'เดียว': 48, 'หลัง': 96, '2': 69, 'ถ้า': 120, 'มี': 350, 'ยอด': 66, 'ทำการ': 17, 'อย่างไร': 35, '3': 60, 'ผ่าน': 46, 'ปี': 89, 'แล้ว': 450, 'เอกสาร': 21, 'สุดท้าย': 21, 'แน่นอน': 14, 'ทาง': 113, 'ทำ': 146, 'ครบ': 15, 'ทุก': 112, 'ขั้น': 8, 'ตอน': 133, '4': 27, 'จริง': 52, 'ทำไม': 84, 'ถึง': 88, 'ทิ้ง': 11, '3ปี': 3, 'ค่อย': 21, 'มาท': 21, 'วง': 17, 'ไม่มี': 100, 'เห': 32, 'รอ': 60, 'ก็': 534, 'น่า': 43, 'ใช่': 23, 'บ.ทวง': 1, 'เล': 5, 'แชร์': 14, 'ประสบการณ์': 5, 'ดูแล': 15, 'ลูกค้า': 83, 'ดี': 150, 'มาก': 141, 'ais': 107, 'แย่': 32, 'ใช้': 461, 'เบอร์': 188, 'ติด': 83, 'สัญญา': 54, 'นึง': 20, 'เน็ต': 415, 'ช้า': 71, 'จึง': 21, 'aisไป': 1, 'ไมค์': 22, '24ชม': 4, 'ไว': 10, 'ปกติ': 40, 'ชดเชย': 4, 'ลด': 45, 'เดือน': 226, 'ให้': 427, 'อีก3เดือน': 1, 'แต่': 325, 'ไป': 593, 'สิบๆ': 1, 'รอบ': 47, 'หาย': 62, 'ย': 31, 'ขึ้น': 101, 'พอ': 100, 'ถาม': 48, 'ต้อง': 205, 'จ่าย': 163, 'บรรเทา': 1, 'ใดๆ': 12, 'บ้าง': 83, 'ก็ได้': 20, 'ขอโทษ': 5, 'ปรับปรุง': 13, 'สัญญาณ': 160, 'เห็น': 48, 'ออก': 60, 'ปล่อย': 6, 'กิน': 18, 'เงิน': 264, 'ลูก': 13, 'ค้า': 11, 'ฟรีๆ': 2, 'ใคร': 102, 'ประสบ': 6, 'กา': 4, 'รณ์': 4, 'แย่ๆ': 4, 'แก้ไข': 53, 'คะ': 141, 'ยอม': 30, 'ไร': 30, 'เดิม': 81, 'dtac': 35, 'แทค': 13, 'ไง': 97, 'ความ': 108, 'ซวย': 4, 'คน': 120, 'ซื้อ': 93, 'ไอ': 17, 'โฟน': 13, 'xr': 4, 'สมา': 12, 'ร์ท': 10, 'โทรศัพท์': 95, 'มือ': 115, 'ถือ': 107, 'mobile': 28, 'operator': 18, 'เพิ่ง': 16, '128': 1, 'gb': 1, 'สี': 17, 'ขาว': 6, 'เมื่อ': 63, 'อาทิตย์': 18, '16': 4, 'ธค': 5, 'เช็ค': 30, 'เครื่อง': 93, 'ปัญหา': 96, 'จันทร์': 7, 'เริ่ม': 16, 'สังเกตุ': 3, 'สีหน้า': 2, 'จอ': 11, 'มัน': 152, 'แปลกๆ': 2, 'วาง': 3, 'คู่': 3, 'กับ': 159, '6': 15, 'เก่า': 18, 'ชัด': 7, 'หมอง': 1, 'โทน': 6, 'เหลือง': 4, 'คิด': 93, 'ปลอบ': 1, 'ใจ': 36, 'ตัว': 68, 'เอง': 66, 'คง': 42, 'แบบ': 174, 'จน': 66, 'อังคาร': 3, 'เอา': 77, 'เทียบ': 5, 'กะ': 16, 'กัน': 122, 'น้อง': 16, 'ทำงาน': 22, 'โชว์': 3, 'ศูนย์': 43, 'คนละ': 6, 'สีกัน': 1, 'นั้น': 76, 'สว่าง': 2, 'แถม': 17, 'แบ': 10, 'ตอึ': 1, 'ดมาก': 1, 'ดู': 86, 'หนัง': 13, 'ฟัง': 10, 'เพลง': 2, 'ทั้ง': 85, 'ต': 9, 'ยุบ': 1, 'นิด': 5, 'บ่าย': 5, 'แบต': 1, 'หมด': 108, 'ทั้งๆ': 52, 'เล่น': 82, 'ส่ง': 99, 'แอ': 7, 'ปเปิ้ล': 2, 'ตรวจ': 41, 'สอบ': 40, 'นโยบาย': 4, 'เปลี่ยน': 94, 'ผิด': 43, 'ชอบ': 23, 'เสีย': 85, 'ต้อง30000กว่า': 1, 'ใช้ได้': 19, 'ซ่อม': 8, 'รู้สึก': 26, 'โคตร': 12, 'เซ็ง': 12, 'โอน': 11, 'ชื่อ': 25, 'สาขา': 13, 'สวย': 5, 'หรือ': 105, 'เล็ก': 2, 'พ่อ': 11, 'ทั้งหมด': 10, 'ทีนี้': 4, 'ไล่': 4, 'เสนอ': 6, 'เงื่อนไข': 9, 'มาส': 4, 'อง': 10, 'อย่าง': 58, 'ปิด': 66, 'ผม': 409, 'หล่ะ': 3, 'งง': 73, 'ตรรกะ': 2, 'ช่วย': 67, 'ที': 56, 'สำหรับ': 12, 'ที่ทาง': 1, 'สา': 4, 'ขา': 5, 'แนะนำ': 26, 'ต่อ': 95, 'ลง': 34, 'โลง': 1, 'ผมเล': 1, 'tweeted': 178, 'ห้วยขวาง': 1, 'กาก': 44, 'สัส': 2, '#': 114, 'truemoveh': 55, 'https': 50, ':': 116, '/': 218, 't.co': 37, '62ypiur ...
# - : ได้742
# - : จดหมาย42
# - : ทวง37
# - : หนี้72
# - : จาก205
# - : ทรู673
# - : [134
# - : truemove183
# - : h134
# - : ,320
# - : คุ้มครอง20
# - : ผู้62
# - : บริโภค24
# - : ร้อง41
# - : ทุกข์14
# - : กฎหมาย14
# - : ชาว16
# - : บ้าน117
# - : ]134
# - : สวัสดี10
# - : ค่ะ182
# - : เนื่อง6
# - : ด้วย120
# - : วัน232
# - : นี้446
# - : ศุกร์3
# - : ที่698
# - : 216
# - : ธันวาคม12
# - : 25617
# - : เรา339
# - : รับ94
# - : จ.ม4
# - : .351
# - : (95
# - : ตัวแทน4
# - : ของ205
# - : )97
# - : ว่า498
# - : ค้าง76
# - : ค่า231
# - : บริการ199
# - : อยู่167
# - : และ184
# - : จะ484
# - : ขอ108
# - : เรียก44
# - : เก็บ44
# - : เป็น358
# - : จำนวน9
# - : 1,590.591
# - : บาท83
# - : ราย136
# - : ละเอียด15
# - : ดัง10
# - : จม2
# - : แปะ2
# - : ไว้37
# - : ด่าน1
# - : ล่าง2
# - : เนื้อหา1
# - : ใน182
# - : บอก169
# - : บริษัท50
# - : เอ็น10
# - : แอนด์9
# - : วาย11
# - : มอบ2
# - : หมาย6
# - : บ.เรี2
# - : ยล6
# - : มูฟ110
# - : เพื่อ55
# - : มา539
# - : ตาม77
# - : บ21
# - : เพราะ124
# - : แจ้ง174
# - : ย้าย264
# - : ค่าย286
# - : เบ33
# - : บอร์ดั1
# - : ง9
# - : อ้าง11
# - : ยัง219
# - : ไม่991
# - : การ173
# - : ชำระ83
# - : เพิก6
# - : เฉย19
# - : !140
# - : ?343
# - : 140
# - : เคย106
# - : ติดต่อ64
# - : อะไร194
# - : เลย352
# - : แม้แต่2
# - : ครั้ง79
# - : เดียว48
# - : หลัง96
# - : 269
# - : ถ้า120
# - : มี350
# - : ยอด66
# - : ทำการ17
# - : อย่างไร35
# - : 360
# - : ผ่าน46
# - : ปี89
# - : แล้ว450
# - : เอกสาร21
# - : สุดท้าย21
# - : แน่นอน14
# - : ทาง113
# - : ทำ146
# - : ครบ15
# - : ทุก112
# - : ขั้น8
# - : ตอน133
# - : 427
# - : จริง52
# - : ทำไม84
# - : ถึง88
# - : ทิ้ง11
# - : 3ปี3
# - : ค่อย21
# - : มาท21
# - : วง17
# - : ไม่มี100
# - : เห32
# - : รอ60
# - : ก็534
# - : น่า43
# - : ใช่23
# - : บ.ทวง1
# - : เล5
# - : แชร์14
# - : ประสบการณ์5
# - : ดูแล15
# - : ลูกค้า83
# - : ดี150
# - : มาก141
# - : ais107
# - : แย่32
# - : ใช้461
# - : เบอร์188
# - : ติด83
# - : สัญญา54
# - : นึง20
# - : เน็ต415
# - : ช้า71
# - : จึง21
# - : aisไป1
# - : ไมค์22
# - : 24ชม4
# - : ไว10
# - : ปกติ40
# - : ชดเชย4
# - : ลด45
# - : เดือน226
# - : ให้427
# - : อีก3เดือน1
# - : แต่325
# - : ไป593
# - : สิบๆ1
# - : รอบ47
# - : หาย62
# - : ย31
# - : ขึ้น101
# - : พอ100
# - : ถาม48
# - : ต้อง205
# - : จ่าย163
# - : บรรเทา1
# - : ใดๆ12
# - : บ้าง83
# - : ก็ได้20
# - : ขอโทษ5
# - : ปรับปรุง13
# - : สัญญาณ160
# - : เห็น48
# - : ออก60
# - : ปล่อย6
# - : กิน18
# - : เงิน264
# - : ลูก13
# - : ค้า11
# - : ฟรีๆ2
# - : ใคร102
# - : ประสบ6
# - : กา4
# - : รณ์4
# - : แย่ๆ4
# - : แก้ไข53
# - : คะ141
# - : ยอม30
# - : ไร30
# - : เดิม81
# - : dtac35
# - : แทค13
# - : ไง97
# - : ความ108
# - : ซวย4
# - : คน120
# - : ซื้อ93
# - : ไอ17
# - : โฟน13
# - : xr4
# - : สมา12
# - : ร์ท10
# - : โทรศัพท์95
# - : มือ115
# - : ถือ107
# - : mobile28
# - : operator18
# - : เพิ่ง16
# - : 1281
# - : gb1
# - : สี17
# - : ขาว6
# - : เมื่อ63
# - : อาทิตย์18
# - : 164
# - : ธค5
# - : เช็ค30
# - : เครื่อง93
# - : ปัญหา96
# - : จันทร์7
# - : เริ่ม16
# - : สังเกตุ3
# - : สีหน้า2
# - : จอ11
# - : มัน152
# - : แปลกๆ2
# - : วาง3
# - : คู่3
# - : กับ159
# - : 615
# - : เก่า18
# - : ชัด7
# - : หมอง1
# - : โทน6
# - : เหลือง4
# - : คิด93
# - : ปลอบ1
# - : ใจ36
# - : ตัว68
# - : เอง66
# - : คง42
# - : แบบ174
# - : จน66
# - : อังคาร3
# - : เอา77
# - : เทียบ5
# - : กะ16
# - : กัน122
# - : น้อง16
# - : ทำงาน22
# - : โชว์3
# - : ศูนย์43
# - : คนละ6
# - : สีกัน1
# - : นั้น76
# - : สว่าง2
# - : แถม17
# - : แบ10
# - : ตอึ1
# - : ดมาก1
# - : ดู86
# - : หนัง13
# - : ฟัง10
# - : เพลง2
# - : ทั้ง85
# - : ต9
# - : ยุบ1
# - : นิด5
# - : บ่าย5
# - : แบต1
# - : หมด108
# - : ทั้งๆ52
# - : เล่น82
# - : ส่ง99
# - : แอ7
# - : ปเปิ้ล2
# - : ตรวจ41
# - : สอบ40
# - : นโยบาย4
# - : เปลี่ยน94
# - : ผิด43
# - : ชอบ23
# - : เสีย85
# - : ต้อง30000กว่า1
# - : ใช้ได้19
# - : ซ่อม8
# - : รู้สึก26
# - : โคตร12
# - : เซ็ง12
# - : โอน11
# - : ชื่อ25
# - : สาขา13
# - : สวย5
# - : หรือ105
# - : เล็ก2
# - : พ่อ11
# - : ทั้งหมด10
# - : ทีนี้4
# - : ไล่4
# - : เสนอ6
# - : เงื่อนไข9
# - : มาส4
# - : อง10
# - : อย่าง58
# - : ปิด66
# - : ผม409
# - : หล่ะ3
# - : งง73
# - : ตรรกะ2
# - : ช่วย67
# - : ที56
# - : สำหรับ12
# - : ที่ทาง1
# - : สา4
# - : ขา5
# - : แนะนำ26
# - : ต่อ95
# - : ลง34
# - : โลง1
# - : ผมเล1
# - : tweeted178
# - : ห้วยขวาง1
# - : กาก44
# - : สัส2
# - : #114
# - : truemoveh55
# - : https50
# - : :116
# - : /218
# - : t.co37
# - : 62ypiur8si1
# - : เรื่อง127
# - : ออนไลน์21
# - : นะ143
# - : ครับ392
# - : ฝั่ง5
# - : ยื่น4
# - : เรียบร้อย10
# - : เย็น4
# - : ข้อความ63
# - : เครือ55
# - : ข่าย53
# - : มาบ17
# - : ริ2
# - : สามารถ58
# - : มั้ง5
# - : เติม118
# - : ฝ่าย11
# - : true211
# - : iservice20
# - : เบบ17
# - : บอร์37
# - : จา5
# - : กดีแทค3
# - : ระหว่าง9
# - : 115
# - : 20154
# - : ประมาณ25
# - : สี่12
# - : ร้อย18
# - : กว่า103
# - : พร้อม39
# - : ดอกเบี้ย5
# - : 7.52
# - : %87
# - : ก่อน83
# - : หน้า63
# - : ซึ่ง55
# - : มั่นใจ4
# - : ตลอด40
# - : ระยะ11
# - : เวลา65
# - : เขา43
# - : บิล66
# - : งั้น14
# - : โดน97
# - : สิ้น10
# - : เจอ43
# - : เคส4
# - : หงุดหงิด14
# - : หัวใจ1
# - : กลับ70
# - : บาย6
# - : กาล1
# - : กะทู้1
# - : ย้อน41
# - : ปรึกษา5
# - : ยาวนาน1
# - : ที่12
# - : online7
# - : อินเทอร์เน็ต23
# - : internet10
# - : ดิฉัน15
# - : บท11
# - : รู38
# - : ปัจจุบัน14
# - : หลาย28
# - : จัดการ16
# - : ทวน1
# - : อ32
# - : ยูjให้1
# - : 12424
# - : อีเมล14
# - : เลข14
# - : อาศัย1
# - : ณ5
# - : เนื่องจาก24
# - : ต้องการ28
# - : ตรง28
# - : สำมะโนครัว1
# - : เบิก1
# - : รับคำ8
# - : ตอบ38
# - : เหมื่1
# - : ว่าที่5
# - : ต่อว่า1
# - : ใบ33
# - : รีบ13
# - : พบ14
# - : บน6
# - : ทาง1242ตอบ1
# - : ระบบ41
# - : อัต1
# - : โน3
# - : มัติ2
# - : ยู๋1
# - : อีก171
# - : หนึ่ง23
# - : ดำเนิน21
# - : เน้น2
# - : ค14
# - : เคา3
# - : ท์3
# - : ใหม่52
# - : ข้อมูล24
# - : อัพเดท3
# - : ถูก35
# - : คุณ80
# - : ทาง1242แจ้ง1
# - : เสร็จ29
# - : เข้าใจ24
# - : เดิมๆ5
# - : ทราบ33
# - : ข้อ14
# - : ไหม74
# - : ยกเลิก188
# - : ตั้งแต่44
# - : 589
# - : หนังสือ10
# - : คือ179
# - : เรียน28
# - : เจ้า45
# - : เดอะมอลล์5
# - : งาม2
# - : วงศ์2
# - : งาน88
# - : เปิด39
# - : อิน6
# - : เต12
# - : อินเตอร์เน็ต17
# - : เกิด24
# - : พยายาม7
# - : เชื่อม5
# - : 4g59
# - : สำเร็จ4
# - : พัน12
# - : เข้าไป23
# - : เคลียร์14
# - : วาาน1
# - : เวฟ1
# - : ตกลง5
# - : 1202
# - : 1210
# - : 1,238.821
# - : รบกวน28
# - : 08632703451
# - : นี่91
# - : กำลัง17
# - : เงิบ3
# - : กก28
# - : กกก3
# - : โปร146
# - : fibre3
# - : บ่อย19
# - : 516
# - : -198
# - : ช่วง35
# - : ช่าง8
# - : แก้49
# - : สาย27
# - : ทองแดง1
# - : สาเหตุ4
# - : เพ10
# - : ราะ5
# - : มัก2
# - : ขยาย1
# - : รอบๆ1
# - : เมือง9
# - : มัว1
# - : หา45
# - : สนใจ23
# - : อยาก94
# - : postpaid7
# - : รึ17
# - : เปล่า22
# - : กบ1
# - : ษัทเรี1
# - : จำกัด14
# - : พึ่ง18
# - : 483.501
# - : ยอ3
# - : ดมาก้1
# - : ค่าsmsทั้งๆ2
# - : สมัคร102
# - : เสริม19
# - : ทัก2
# - : คอล25
# - : เซน2
# - : อร์7
# - : ระ10
# - : งับ4
# - : บบ3
# - : บรา1
# - : เกิน36
# - : วงเงิน6
# - : กำหนด5
# - : ที่5001
# - : ขอบ12
# - : รู้37
# - : ป9
# - : เซอร์วิส2
# - : มา600กว่า1
# - : อ่าน14
# - : ค่าsmsไป270บาท1
# - : นั่ง5
# - : ร้องไห้2
# - : คือsmsที่1
# - : ตัง10
# - : กู42
# - : อีกtt1
# - : ค่าsmsใน1
# - : ส่วน40
# - : ไถ1
# - : ทวิ6
# - : เถอะ11
# - : เอ๊1
# - : รูป8
# - : วะ8
# - : รี11
# - : เอ15
# - : ส36
# - : แรง27
# - : ทั่ว5
# - : ไทย14
# - : จริมๆ1
# - : ละ78
# - : แท้6
# - : ezehgznz2k1
# - : line4
# - : 293
# - : 20185
# - : ต้องเต1
# - : ยม3
# - : ติดขัด1
# - : คำ21
# - : trueyou2
# - : wifi13
# - : ซิ72
# - : ม67
# - : พอดี16
# - : โทร201
# - : ศัพท์3
# - : ไม7
# - : ปุบ1
# - : เหลือ35
# - : สัก45
# - : ไป300บาท1
# - : ไม่รู้54
# - : กด63
# - : *62
# - : 137ช่วย1
# - : โปรด1
# - : ห่วย27
# - : ของtrue8
# - : ล้ะ1
# - : 499b2
# - : ความเร็ว21
# - : mbps15
# - : เล่นrov1
# - : ปิง5
# - : ๆ26
# - : เหมือน125
# - : ฟรี32
# - : หัว9
# - : ร้อน10
# - : คับ35
# - : น่ะ1
# - : ไม่ใช่27
# - : คุ6
# - : น33
# - : ควร26
# - : ไข้1
# - : เกม19
# - : แล4
# - : สำคัญ3
# - : สตรี4
# - : มด้วย1
# - : หากว่า1
# - : คห4
# - : รือ2
# - : หลุด23
# - : แพ้3
# - : ทำให้14
# - : คุน4
# - : โม้1
# - : เร็ว17
# - : สุด13
# - : ประเทศไทย4
# - : นบ1
# - : อก24
# - : ผู้นำ1
# - : ที่สุด9
# - : จุด8
# - : หลอก31
# - : เยอะ34
# - : ออม1
# - : ประหยัด1
# - : อย่า38
# - : เสียคน1
# - : สิ่ง9
# - : net13
# - : น้อย25
# - : หยุด6
# - : เสาร์6
# - : บำรุง1
# - : ตัดสิน4
# - : call25
# - : center24
# - : ture1
# - : shop9
# - : เท่านั้น10
# - : ตั้ง20
# - : หน้าที่35
# - : นำ29
# - : เซ็น9
# - : ต์1
# - : เข้า84
# - : อุปกรณ์9
# - : นร3
# - : sms37
# - : นัด6
# - : พื้น4
# - : ฐาน12
# - : พลัส1
# - : หมายเลข8
# - : 0202358791
# - : สถานะ1
# - : 246
# - : เลื่อน1
# - : กรุณา6
# - : ทร2
# - : รติ1
# - : ด6
# - : มาก้1
# - : วย1
# - : เก้อ1
# - : นาน27
# - : 4xxx1
# - : คืน76
# - : ว่าง2
# - : บริ3
# - : กาบ1
# - : ริกา1
# - : ร้า2
# - : คุ้ม6
# - : ราคา36
# - : cc6
# - : pantip5
# - : มั้ย28
# - : เดิอน1
# - : i1
# - : pad1
# - : pro3
# - : พนักงาน53
# - : mbs1
# - : unlimitad1
# - : แรก27
# - : สาม19
# - : สอง30
# - : ปา3
# - : เก้า1
# - : เพียง11
# - : แค่51
# - : 2991
# - : เหตุ4
# - : ทน13
# - : 384kbps1
# - : เข1
# - : วี้2
# - : ยง3
# - : จริงๆ38
# - : หมุน8
# - : ข่าง2
# - : จ๊ะ2
# - : @60
# - : ห้อง7
# - : เสถียร9
# - : อิ10
# - : เวน6
# - : เอ้4
# - : ยยยย9
# - : no2
# - : service3
# - : เลือก13
# - : arp6rsft81
# - : สัญญาณtruemovehขาด1
# - : ขาด11
# - : พ.ค1
# - : มิ.ย1
# - : cct1
# - : จับ2
# - : เเจ้ง3
# - : ไข5
# - : ล่าสุด10
# - : ส่วนลด8
# - : แพค15
# - : เกจ8
# - : 3012
# - : ใกล้7
# - : ครึ่ง7
# - : ใส่ใจ2
# - : เกี่ยว3
# - : หรอ24
# - : ดีแล้ว2
# - : สมควร3
# - : มัย4
# - : 96
# - : คำถาม1
# - : หน่อย62
# - : นรก1
# - : chokdee3
# - : clip4
# - : เพิ่ม31
# - : เฮ2
# - : ช2
# - : โกง19
# - : หนี3
# - : _3
# - : iphone10
# - : 6s2
# - : plus2
# - : ศูนย์truemove1
# - : เรียบ7
# - : เสมอ2
# - : ที่151
# - : ธ.ค11
# - : 15.301
# - : ชอป12
# - : ชั่วโมง7
# - : เบื้อง5
# - : ต้น14
# - : สายตา1
# - : ทด1
# - : 16.302
# - : ร้าน18
# - : ข้าง13
# - : นอก7
# - : ฟิล์ม15
# - : กระจก3
# - : ขาย30
# - : ปราก7
# - : ฎ7
# - : นาที13
# - : เต็ม25
# - : ลอง30
# - : แผ่น4
# - : แนบ6
# - : สนิท3
# - : คาด6
# - : คุณภาพ13
# - : แกะ2
# - : ผล9
# - : อาการ12
# - : เดียวกัน9
# - : ด้าน5
# - : ซ้าย1
# - : แนว2
# - : ยาว4
# - : ยี่ห้อ4
# - : อื่น54
# - : 16.501
# - : เดิน27
# - : ดล1
# - : ภาพ14
# - : studio2
# - : 717
# - : 17.301
# - : "34
# - : ทันที7
# - : 18.001
# - : แผง1
# - : สอบถาม36
# - : 4502
# - : ทดลอง3
# - : หลัก20
# - : เกือบ25
# - : 19.001
# - : 10.301
# - : นท24
# - : วาน14
# - : ล่ะ25
# - : ออฟ1
# - : ฟิต1
# - : ประสาน11
# - : ใหญ่20
# - : โดย37
# - : 171
# - : job1
# - : 800005631
# - : 1812161
# - : 0011
# - : คา3
# - : สงสัย11
# - : อื่นๆ6
# - : เค้า19
# - : ประกัน1
# - : ภายใน8
# - : โต2
# - : เชี่ยวชาญ1
# - : พก1
# - : เวอร์เนียร์1
# - : ทดสอบ3
# - : ฯลฯ1
# - : เดิมที1
# - : android1
# - : ios3
# - : แบรนด์1
# - : ระดับ5
# - : โลก12
# - : ปลื้ม1
# - : ซะ7
# - : รูด1
# - : บัตร27
# - : เครดิต4
# - : หนำซ้ำ2
# - : ชัดเจน3
# - : สำรอง2
# - : หมื่น9
# - : พนัก12
# - : งา10
# - : เตือน21
# - : อุทาหรณ์1
# - : หาก17
# - : เคารพ1
# - : ต.ค1
# - : 6111
# - : ขยะ3
# - : หัก31
# - : เรื่อยๆ4
# - : สรุป27
# - : หากิน8
# - : แก่2
# - : เอส6
# - : sim1
# - : card5
# - : 5004
# - : ขอรับ1
# - : ขอบคุณ26
# - : อี30
# - : เวร5
# - : ตัด69
# - : นะคะ3
# - : เจ้าของ7
# - : spoil2
# - : คลิก2
# - : ซ่อน2
# - : ไว้09238017711
# - : share2
# - : plan5
# - : 09711233551
# - : พรุ่ง5
# - : 234.331
# - : พ.ย2
# - : ปรากฏ4
# - : exceeding2
# - : price2
# - : other3
# - : charges2
# - : daily5
# - : guru2
# - : แน่ๆ11
# - : ประสงค์1
# - : แสดง8
# - : จำนงค์1
# - : 1378
# - : เชค1
# - : สูง7
# - : ยย6
# - : 1081
# - : รวม13
# - : vat1
# - : รายการ9
# - : ยืนยัน14
# - : ยินดี6
# - : ร้องขอ3
# - : มัด3
# - : ชก2
# - : ไหนๆ2
# - : มงคล1
# - : สวยๆ1
# - : คนใน5
# - : วิชั่น2
# - : ห้า6
# - : จริงใจ3
# - : ธรรม7
# - : เชื่อ14
# - : เม็ด1
# - : ไหน49
# - : แก่ๆ2
# - : เท่าไร3
# - : กลาง6
# - : จัง10
# - : จังหวัด12
# - : กาฬสินธุ์2
# - : เต่า5
# - : แหละ11
# - : มากๆ29
# - : เฟส5
# - : ไอจี1
# - : แทบ11
# - : ฉัน15
# - : 8991
# - : ดัน6
# - : 1,0102
# - : โน้น1
# - : แอฟ3
# - : สิน1
# - : จ8
# - : อ้าว4
# - : ววว1
# - : จ้า16
# - : าาาา3
# - : จนท.แจ้ง1
# - : จะแจ้ง9
# - : ภาย3
# - : รหัส29
# - : ชม2
# - : 00.261
# - : 7.361
# - : นน1
# - : มม1
# - : 9461
# - : า7
# - : จทน.แจ้ง1
# - : เดี๋ยว20
# - : จนท.ก็1
# - : าา4
# - : าาา5
# - : จทน.บอก1
# - : อ่ะ14
# - : โอเค10
# - : มั่ง3
# - : 49.062
# - : t_t1
# - : โก1
# - : ธร1
# - : พูด11
# - : +23
# - : ก้2
# - : จทน.ก็1
# - : ไหร่23
# - : เท่า27
# - : วววว1
# - : ยาก16
# - : คนใช้7
# - : ระวัง4
# - : สำนักงาน1
# - : ข่มขู่1
# - : 2ปี1
# - : บาง26
# - : เป็น10ปี2
# - : สับ4
# - : มา้1
# - : ออ10
# - : โทรศัพท์a3sจาก1
# - : เซ5
# - : เว่น2
# - : เดือน6mbมี1
# - : ใช้900บาท1
# - : ที่81
# - : 9ธค.วัน1
# - : ที่16ยัง1
# - : ถึง10วัน2
# - : เพจ2
# - : บริการsmsก็1
# - : งิน900หมด1
# - : เเค่1
# - : เ็1
# - : ตนี่1
# - : แรกๆ2
# - : รุ้4
# - : สึก8
# - : โยน4
# - : ลำบาก1
# - : ต่าง11
# - : แบบ14วัน1
# - : ประมาณ399บาท1
# - : ธันวาคม2561เวลา001
# - : 00น2
# - : ที่14ธันวา1
# - : คม1
# - : เวลา001
# - : ที่3ธันวาคม1
# - : เก13
# - : จเร1
# - : อายุ10
# - : รัง11
# - : นอกจาก14
# - : 2พัน1
# - : ระงับ6
# - : โปร่งใส2
# - : แอบ13
# - : เบื่อ9
# - : อารมณ์4
# - : จม.ทวง2
# - : จขกท.ได้1
# - : ศัพ1
# - : ซิม22
# - : เดือน8เดือน1
# - : สลับ5
# - : ที่2เขา1
# - : ค่าง1
# - : ต่อๆ1
# - : จม.อะไร1
# - : จม.ส่ง1
# - : 800กว่า2
# - : 10,600บาท1
# - : ภายใน7วัน2
# - : สงวน1
# - : สิทธิ์8
# - : ผิดนัด2
# - : อัตรา2
# - : 7.5บาท1
# - : พิจารณา5
# - : ตา6
# - : มกฏ2
# - : ตจว3
# - : รา4
# - : 8พัน1
# - : ปลายๆ1
# - : เซนเตอร์6
# - : เครื่อง10600เรา1
# - : เครียด1
# - : มั่วๆ2
# - : แม่47
# - : ปก3
# - : ติ5
# - : เกิน2001
# - : 300บาท1
# - : 1073.381
# - : ระบุ3
# - : อินเตอร์4
# - : เนต44
# - : โดยที่8
# - : ไวไฟ6
# - : มากกว่า16
# - : 703
# - : เด็ก2
# - : แต่ละ2
# - : ค่อน6
# - : หวง1
# - : เซ็นเตอร์15
# - : ตี7
# - : หลับ1
# - : คราว9
# - : ทุ่ม6
# - : พย2
# - : จนถึง8
# - : โมง1
# - : เช้า10
# - : 221
# - : 3g15
# - : จริ้1
# - : งงง2
# - : 2zpidxrf0l1
# - : เน้ต2
# - : pxxsufnaud1
# - : แฮชแทค1
# - : วน5
# - : ไลน์7
# - : วุ่น1
# - : หน่อยๆ1
# - : แอพ9
# - : ต่างๆ7
# - : ไทยรัฐ1
# - : ว้อยยย1
# - : เอ็ง1
# - : เรอ1
# - : ะ8
# - : เปรียบ11
# - : กสทช25
# - : nbtc3
# - : กระทู้14
# - : อัน13
# - : 4mbps9
# - : ลดspeed1
# - : ละ699เป็น1
# - : โทษ2
# - : เกมส์8
# - : ดร1
# - : อป1
# - : แค่h1
# - : rov2
# - : พวก24
# - : ทีวี5
# - : ขนาด26
# - : พื้นที่16
# - : สัญญาณ4gก็ตาม1
# - : ทางoppo1
# - : ที่oppo1
# - : ให้oppo1
# - : ยิ่ง13
# - : หา1331กี่1
# - : ร้าย2
# - : ครอบ3
# - : ครุ1
# - : ม4g1
# - : กันยา2
# - : รอ45วัน1
# - : ทำได้5
# - : ไหว16
# - : อุ1
# - : สาห์1
# - : ข่า2
# - : ผลลัพธ์4
# - : โม24
# - : ชั่น18
# - : คอ3
# - : ลล์2
# - : ชี้แจง8
# - : ปีด27
# - : 1mbps2
# - : วัน107บ1
# - : สะดุด1
# - : ดูviu1
# - : netflix1
# - : หลังๆ4
# - : นิดๆ3
# - : สัญญาณ4g1
# - : เต็ม4ขีด1
# - : น้า1
# - : โรจน์5
# - : ลอว์3
# - : คอลเล3
# - : คชั่น3
# - : อยู่ๆ7
# - : ได้5เดือน1
# - : พอได้3
# - : 20121
# - : 09106244081
# - : คุย20
# - : ผ่า2
# - : วิต1
# - : เตอร์7
# - : สะดวก5
# - : ศูยน์1
# - : แอด1
# - : มิ4
# - : นก็4
# - : 815
# - : ติดตาม5
# - : 208
# - : รัก9
# - : อักษร2
# - : เอ้า3
# - : ช่อง8
# - : ทางการ1
# - : อยู่ดี6
# - : บร1
# - : ษัท1
# - : ไฟ4
# - : 9004
# - : ตอ3
# - : รี่2
# - : ชาติ5
# - : โหลด39
# - : trueไวไฟ1
# - : vruk2epbvo1
# - : จากtrueไปaisเพื่อ2
# - : samsung4
# - : note4
# - : galaxy1
# - : smartphone1
# - : ร17
# - : tv1
# - : เขต1
# - : หอพัก1
# - : ที่พัก1
# - : ขีด17
# - : โหมด3
# - : บิน4
# - : จูน1
# - : แป้ป1
# - : 5011
# - : super2
# - : 156
# - : วิ3
# - : ไค2
# - : ชาร์จ1
# - : ตมัน1
# - : =9
# - : ดีๆ16
# - : วูบ1
# - : นัง1
# - : จี4
# - : catradio2
# - : สด2
# - : เงียบ22
# - : คลื่น9
# - : แป๊ป1
# - : แพ2
# - : ก7
# - : อร์เน็ท3
# - : wallet17
# - : อะ17
# - : ลิ5
# - : มิต4
# - : วอททท1
# - : ทำไมtrue4
# - : ทูร1
# - : แพง16
# - : เน็ต3001
# - : ตุลาคม1
# - : เบา4
# - : เบา2992
# - : เน็ต1mbps1
# - : พอใช้1
# - : พัก6
# - : ตึก5
# - : ติดwifiให้1
# - : มีwifiเรา1
# - : พฤศจิก2
# - : ยน2
# - : มราย7
# - : ตุลา1
# - : ไป1621
# - : เคาน์เตอร์2
# - : ต่ำ6
# - : ก่อน106บาท1
# - : แ้ว1
# - : ใกล้ๆ1
# - : 8051
# - : ใช้wifiตอน1
# - : ที่18ธันวาคม1
# - : มากว่า1
# - : 7661
# - : ใช้3เดือน2
# - : แค่299หรือ1
# - : เสียง16
# - : ทรูอะ1
# - : 88881
# - : ถือว่า10
# - : ขอร้อง2
# - : ดาย1
# - : พ้อ3
# - : เสียดาย3
# - : ห2
# - : มุ่1
# - : ตำบล8
# - : e4
# - : ห่าง2
# - : กม1
# - : 603
# - : เปลี่ยนแปลง3
# - : ใจอ่อน1
# - : จริงจัง2
# - : เสา12
# - : สัย1
# - : ญาณ3
# - : ที่ดิน1
# - : ฟัน1
# - : อัล2
# - : เต็1
# - : ดมา2
# - : ปีก1
# - : ประจำ4
# - : อำเภอ7
# - : พิกัด1
# - : เธอ1
# - : ljlz0k4v661
# - : ยน์2
# - : คะแนน4
# - : แต้ม3
# - : แลก3
# - : เงินสด3
# - : เรือง1
# - : ละธ.ก็1
# - : กลาย6
# - : เช็1
# - : กกะ2
# - : อาจ11
# - : ลุ้น2
# - : วุ่นวาย2
# - : ยุ่ง6
# - : มึง16
# - : เยียว1
# - : ยา1
# - : วว1
# - : ส้นตีน2
# - : โอ้5
# - : โห2
# - : ข้างๆ1
# - : ลื่น5
# - : นนน2
# - : เกีย1
# - : แม้4
# - : ด่า21
# - : you1
# - : edok1
# - : where2
# - : is1
# - : my4
# - : โท2
# - : แร้ว10
# - : ชั้น5
# - : บิว1
# - : เงินtruemoveผ่านmymo1
# - : เงินtrue1
# - : move21
# - : ผ่านmymo1
# - : ดึง2
# - : เป็นการ9
# - : 25561
# - : แทน7
# - : เคยๆ1
# - : เลิก23
# - : กรึ1
# - : horoscope3
# - : แล้4
# - : วอ9
# - : ยู่ๆ3
# - : คงจะ3
# - : มก็3
# - : ครู่4
# - : คุณintelligence1
# - : ทางcall1
# - : 11421
# - : เช่น13
# - : ห้าม8
# - : โน่น1
# - : เหตุผล5
# - : ยากๆ1
# - : มาปก1
# - : ยาง1
# - : ร้อยๆ2
# - : ลูกๆ1
# - : ประ7
# - : หลา1
# - : ดๆ2
# - : ประหลาด1
# - : อัพเดต2
# - : แตก12
# - : ประเด็น7
# - : ปรับ7
# - : 90001
# - : it1
# - : หนา2
# - : แน่น1
# - : business1
# - : engineer2
# - : เซลล์3
# - : ประชุม2
# - : ระบาย1
# - : นับ2
# - : กระจาย3
# - : 3,0002
# - : 25601
# - : โทรฯ3
# - : งัน1
# - : 622
# - : ไกล2
# - : ขับ3
# - : รถ6
# - : ร่วม7
# - : สามสิบ1
# - : กิโล1
# - : สัปดาห์3
# - : ค่ด1
# - : ชัย2
# - : เกมpb2
# - : เซิฟ2
# - : เวอร์5
# - : มา30นาที2
# - : วิธี18
# - : ยก14
# - : 7gb2
# - : 250บาท2
# - : เพ็ค1
# - : เก็จ7
# - : อ้ะ4
# - : ปริ1
# - : มาน3
# - : แดง13
# - : เหี้ย30
# - : ป่ะ1
# - : นนนนนน2
# - : ล่วง8
# - : บู1
# - : โร1
# - : ประวัติ3
# - : ยุติธรรม2
# - : อิค2
# - : วัย2
# - : พะโต๊ะ1
# - : uni1
# - : lover1
# - : 6502
# - : 6mbps5
# - : อั้น3
# - : เดี๋ยวๆ1
# - : ค่ายๆ1
# - : ช่ะ1
# - : ก่1
# - : เนี้ย3
# - : ค่ต1
# - : แร่1
# - : ว3
# - : อิก2
# - : ร่ะ1
# - : fuh14icocg1
# - : เป็นไร7
# - : กล่ะะ1
# - : 3วัน1
# - : ดี4วัน1
# - : ผี3
# - : ห่า5
# - : ยยย3
# - : อ่อ4
# - : มะ2
# - : เว่อ5
# - : 08660830251
# - : ประมาณ30บาท1
# - : 1เดือน1
# - : ตก13
# - : 1000บาท1
# - : ฆวย1
# - : โมโห5
# - : โบนัส7
# - : ทรู320mb3
# - : 24ชม.ยัง3
# - : จอื่น1
# - : 09734663501
# - : สัญญา1ปี2
# - : ปรับ8,0002
# - : ยุ2
# - : ที่1,6ร้อย1
# - : กว่าๆ5
# - : สัญญา12เดือน5
# - : ไหร3
# - : ค่าsmsไป1
# - : จิงๆ2
# - : replied14
# - : doilyhipster1
# - : 55555555555555551
# - : หวย1
# - : 5555555555551
# - : ขยัน1
# - : โว้ย5
# - : 16862
# - : trueh4
# - : dl1
# - : 20m1
# - : ul1
# - : 0.8m1
# - : เอาชนะ8
# - : achach2
# - : พิมพ์15
# - : บี้1
# - : สิบ2
# - : สมัย3
# - : จบ9
# - : ดอก2
# - : เทพๆ1
# - : ลับๆ1
# - : เหรอ1
# - : เชอะ1
# - : สน5
# - : เด็ด1
# - : 55555
# - : ท่าน15
# - : คล้ายๆ1
# - : โชค3
# - : ลวดลาย1
# - : ทุย1
# - : เรเน1
# - : unlimited9
# - : ใช้4gเดือน1
# - : ละ799ขอ1
# - : วิ่ง4mbไม่1
# - : นี้4gมาๆ1
# - : ดับๆ3
# - : เป็นh2
# - : พี่10
# - : ใช้aisวิ่ง4gตลอด1
# - : ใช้599เอง1
# - : pepsi2
# - : man2
# - : เทรน5
# - : หู5
# - : ปาก5
# - : มอม4
# - : ทรุย4
# - : แจ้2
# - : งอ่ะ5
# - : สุดๆ8
# - : งี้4
# - : สั้นๆ3
# - : ง่ายๆ4
# - : ดอง2
# - : แทง2
# - : กั๊ก2
# - : เผลอ5
# - : ลืม6
# - : แถ2
# - : มึนๆ2
# - : หนู4
# - : ถุ้ย2
# - : ผมม2
# - : ดิส3
# - : เพื่อน13
# - : กลุ่ม7
# - : โค6
# - : รต4
# - : มอง5
# - : ช็2
# - : อบ4
# - : เลยย2
# - : พพ2
# - : เห็นๆ2
# - : สวิง3
# - : อ้อ2
# - : สอน2
# - : เม้า2
# - : ป้าย2
# - : หมู่บ้าน4
# - : รอด6
# - : แตกหัก2
# - : แผนที่9
# - : ทรูซื้่อ2
# - : ประปา2
# - : ไฟฟ้า2
# - : แหม่2
# - : กรู5
# - : วิศวะ2
# - : มานะ2
# - : สำเนา3
# - : ทะเบียน9
# - : หึๆ2
# - : ใบปลิว2
# - : 3bb8
# - : บรีบๆ2
# - : สร้าง8
# - : โชว1
# - : กูล1
# - : เกิ้ลโชว1
# - : g8
# - : แถว11
# - : tc1
# - : green1
# - : condo1
# - : พระราม91
# - : ฟิว2
# - : เจอร์1
# - : เกือบ21
# - : ให่1
# - : 05
# - : กู้2
# - : อือ1
# - : หรอก3
# - : ว๊อย1
# - : เปย1
# - : มา4g1
# - : ทัน6
# - : กุ8
# - : ได้2อาทิตย์1
# - : ชิ3
# - : trueonline5
# - : อ่อน4
# - : อัพ2
# - : บ่อ2
# - : แก้ว4
# - : นา4
# - : น่าน1
# - : ติ้วๆ3
# - : พอควร1
# - : เที่ยว2
# - : อับ6
# - : 901
# - : 1391
# - : มอ2
# - : กอะ3
# - : นึก6
# - : ปะ9
# - : เนี่ย11
# - : พอก2
# - : ลับ8
# - : กรุงเทพ1
# - : ไหล2
# - : อิเวง1
# - : สมัครinternetแบบ1
# - : เลท1
# - : 6mb1
# - : 30วัน1
# - : วิ่ง8
# - : xx1
# - : mb1
# - : ง่าย6
# - : ยินยอม1
# - : ฝาก4
# - : ธนาคาร3
# - : ถอน1
# - : กรณี6
# - : พนง.ตั้งแต่1
# - : แล้วไป1
# - : บัญชี8
# - : เทพ2
# - : มอื่น2
# - : แน่7
# - : แปลก7
# - : จร้า1
# - : ขัด1
# - : ใจจจจ1
# - : อิ๊1
# - : ส้ม1
# - : ละนะ1
# - : สภาพ1
# - : สล๊อ1
# - : ตมาก1
# - : อีtrue1
# - : รวย7
# ...
# 0 : 4q612
# 0 : 3q613
# 0 : 33.31
# 0 : q9
# 0 : trueonline2
# 0 : บรอดแบนด์1
# 0 : arpu5
# 0 : 2071
# 0 : addition1
# 0 : paid3
# 0 : ตํ่า1
# 0 : รุนแรง1
# 0 : ทั้ง21
# 0 : ได้ท่า1
# 0 : gpm1
# 0 : 26.81
# 0 : เป็น24.51
# 0 : 343.11
# 0 : y2
# 0 : 10,291ลบ1
# 0 : dif2
# 0 : สิน้1
# 0 : 2q611
# 0 : 7932
# 0 : กดดัน2
# 0 : ต้นทาง2
# 0 : เหลือก1
# 0 : ช่วง11
# 0 : upside1
# 0 : dcf1
# 0 : พิพาท1
# 0 : แพ็1
# 0 : อายุ16ปี1
# 0 : ทุกที1
# 0 : kijrawe1
# 0 : 8406091
# 0 : kidz1
# 0 : เฟี่1
# 0 : ยง2
# 0 : จรี1
# 0 : 5qjrxewl0e1
# 0 : ไว้06410819931
# 0 : ให้หา2
# 0 : ตาลาย2
# 0 : 2ซิม1
# 0 : trueสำหรับ1
# 0 : 1200บาท1
# 0 : 100บาท1
# 0 : จ่าย4001
# 0 : อิด1
# 0 : 6xqrsj4zep1
# 0 : นมาม่า1
# 0 : กำเเนิ1
# 0 : หนด1
# 0 : นครั2
# 0 : 49918661
# 0 : xt07btuuzh8
# 0 : ammmmmmpi1
# 0 : tookkata_ta1
# 0 : ram_baaa1
# 0 : พป.ไม่1
# 0 : พซต.truemove1
# 0 : hเนอะ1
# 0 : ขิง1
# 0 : ฉิบหาย1
# 0 : ล้วนี่1
# 0 : 69wjlcshrv1
# 0 : 21.201
# 0 : psyrypkbfw1
# 0 : พน.จะ1
# 0 : นัง1
# 0 : ครับ.ผม1
# 0 : ทรู8991
# 0 : ครับ.แล้ว1
# 0 : ตการ1
# 0 : แล้ว.เช็ค1
# 0 : 43jssuczti1
# 0 : 7eleven2
# 0 : note93
# 0 : ไมร์1
# 0 : cilfiuvapm1
# 0 : education4plus1
# 0 : รพิ1
# 0 : เศษๆ1
# 0 : trueh1
# 0 : ไปละ1
# 0 : 08660326461
# 0 : 45116881
# 0 : หนังสือเดินทาง2
# 0 : อากร1
# 0 : แสตมป์1
# 0 : 46232711
# 0 : 49985761
# 0 : เหอะ2
# 0 : ad5f8thkkr1
# 0 : 22yn265qph1
# 0 : jc1rpwtorw1
# 0 : iconsi3
# 0 : fvusvuojq43
# 0 : ทม1
# 0 : เบอ09431689921
# 0 : แยาก1
# 0 : เบอร์true1
# 0 : ไช้1
# 0 : ติดต่อtrueshopแล้ว1
# 0 : รอ31
# 0 : 4you1
# 0 : zero7
# 0 : base1
# 0 : วนว1
# 0 : mymo1
# 0 : 06469585451
# 0 : 395730011
# 0 : เวลา121
# 0 : ที่121
# 0 : 61ต้องการ1
# 0 : หมายเลข08361374591
# 0 : babyoopsshop1
# 0 : q_02lisa1
# 0 : จอ5.0ค่ะ1
# 0 : buuuaesqqs1
# 0 : เนอะ1
# 0 : งืมๆๆ1
# 0 : vp0telp2gh1
# 0 : 10840871
# 0 : ลังเล1
# 0 : 24623461
# 0 : หมาป่า1
# 0 : 49995371
# 0 : ว้1
# 0 : ทั้ง3bb1
# 0 : m43961
# 0 : vibe1
# 0 : p1m1
# 0 : คล้อง1
# 0 : ซื้อ1แถม11
# 0 : 259บ1
# 0 : kz5t4w8ir41
# 0 : กระแทกlenovop1m1
# 0 : lenovop1mเคส1
# 0 : ประดับlenovop1m2
# 0 : หินlenovop1m1
# 0 : หิน1
# 0 : อ่อนlenovop1m1
# 0 : เคสlenovop1mประกบ1
# 0 : หนังlenovop1m1
# 0 : 0lqoiohf8c1
# 0 : ที่3ว่า1
# 0 : ซื้อsimที่1
# 0 : โน้น1
# 0 : ราคาsimก็1
# 0 : ซื้อ10rm1
# 0 : ทรูwalletจาก2
# 0 : เบอ10
# 0 : ลมาเบอ2
# 0 : ไว้.wajinate5113151
# 0 : 2.09681793032
# 0 : แลตเบอ2
# 0 : ลมา2
# 0 : วอลเล้ต4
# 0 : ราะเบอ4
# 0 : เเก้2
# 0 : เเล้2
# 0 : เก้อ1
# 0 : lagrange3
# 0 : ล่าช้า2
# 0 : bao2
# 0 : onnet1
# 0 : hrs1
# 0 : mbps.คับ1
# 0 : 40356081
# 0 : munchkin_tiger1
# 0 : คลับ1
# 0 : เคี้ยว1
# 0 : 521
# 0 : โสด3
# 0 : เลา1
# 0 : ยม๊1
# 0 : อกๆ1
# 0 : 06481866211
# 0 : 06481466211
# 0 : 0621
# 0 : 5611
# 0 : 72531
# 0 : ทรศ2
# 0 : ถถถถถถถถถถถถถ1
# 0 : สลัก1
# 0 : เขื่อน1
# 0 : เชี่ยว1
# 0 : 49915881
# 0 : นมี2
# 0 : ถึง2ขีด2
# 0 : รอ3วัน1
# 0 : แยะ1
# 0 : ib0hbtgvuy1
# 0 : ฟรีๆ1สิทธิ์1
# 0 : vorpxtpzly1
# 0 : 49949302
# 0 : คั้ง1
# 0 : ยกฏ1
# 0 : หมย1
# 0 : 8684950319345191
# 0 : 0971
# 0 : 29456201
# 0 : wajinate5113151
# 0 : multisim1
# 0 : เริ่มๆ2
# 0 : modem1
# 0 : ตย1
# 0 : 2.75g1
# 0 : แพงๆ2
# 0 : หรูๆ1
# 0 : vowifi1
# 0 : สู1
# 0 : งมากๆ1
# 0 : modulate1
# 0 : เทคโนโลยี่1
# 0 : เหลือเฟือ2
# 0 : 49931991
# 0 : coordiinatesที่1
# 0 : แห่1
# 0 : หากว่า1
# 0 : ทางใน1
# 0 : กรู1
# 0 : ณา1
# 0 : restart1
# 0 : via3
# 0 : redeem1
# 0 : เเบ1
# 0 : บนี้1
# 0 : 0861
# 0 : 30510501
# 0 : ท็อปส1
# 0 : เล่นfacebook2
# 0 : iamframenan2
# 0 : เด๋1
# 0 : วนี้1
# 0 : สำนึก1
# 0 : อิสั2
# 0 : วอ่ะ1
# 0 : ดุด1
# 0 : 48393281
# 0 : อับ4
# 0 : 4ปี1
# 0 : โม้1
# 0 : จับ4gกัน1
# 0 : โปร4gมา1
# 0 : โปร4gบลาๆ1
# 0 : คืด1
# 0 : inline1
# 0 : 0px1
# 0 : hidden1
# 0 : mce1
# 0 : bookmark1
# 0 : mce_selres_start1
# 0 : oreo1
# 0 : คลี1
# 0 : ท้อ1
# 0 : apps3
# 0 : ips1
# 0 : 15201
# 0 : 7201
# 0 : micro3
# 0 : sd2
# 0 : nano3
# 0 : slot2
# 0 : 2d1
# 0 : f3
# 0 : 2.01
# 0 : 1.12um1
# 0 : lens1
# 0 : 2.42
# 0 : 1.75um1
# 0 : sensor1
# 0 : portrait5
# 0 : cinemagraph1
# 0 : 2.2พร้อม1
# 0 : beautification1
# 0 : photo1
# 0 : action1
# 0 : แค่1300ใช้ได้3เดือน7
# 0 : ถ้า6mbpsให้1
# 0 : แต่10mbpsใช้1
# 0 : ลำลูกกา1
# 0 : ถ้า10mbpsเหลือ11
# 0 : ทำไม4mbpsหรือ6mbpsใช้1
# 0 : กวาง4
# 0 : โจว3
# 0 : ไชนา1
# 0 : codes1
# 0 : cmcc1
# 0 : 49776911
# 0 : xiaomi5
# 0 : mi4
# 0 : mix4
# 0 : เวอร์ชั่น4
# 0 : มวล1
# 0 : soc2
# 0 : สัญชาติ1
# 0 : partner1
# 0 : x502
# 0 : 2gbps1
# 0 : แน่ชัด1
# 0 : www.gizchina.com1
# 0 : มายด์1
# 0 : sugar1
# 0 : paradise1
# 0 : gateway1
# 0 : bangsue1
# 0 : โผล่1
# 0 : แม่5551
# 0 : เหม่อ1
# 0 : ตั้งแต่29พย1
# 0 : วดฟฟฟฟ1
# 0 : soeaijnjzf1
# 0 : z80yv12m0o1
# 0 : ใด้2
# 0 : แล้ว70บาท2
# 0 : ชม.นึง1
# 0 : เอ้1
# 0 : เหอะๆ1
# 0 : blacklist1
# 0 : ชำ1
# 0 : มุฟ1
# 0 : minor1
# 0 : ban2
# 0 : account1
# 0 : นวน1
# 0 : ณ.ที่1
# 0 : เทส1
# 0 : 10.231
# 0 : 100mbps1
# 0 : 49973691
# 0 : 5gtruemove2
# 0 : รัตน3
# 0 : อุปถัมภ์3
# 0 : ก็มี1
# 0 : adx8
# 0 : rsi8
# 0 : ema10
# 0 : macd16
# 0 : technical1
# 0 : 10,254
# 0 : backtesting3
# 0 : aeonts1
# 0 : aj1
# 0 : ama1
# 0 : ap1
# 0 : bct1
# 0 : bfit1
# 0 : cbg3
# 0 : centel1
# 0 : cimbt1
# 0 : cwt1
# 0 : ee1
# 0 : gcap1
# 0 : gland1
# 0 : gunkul1
# 0 : harn1
# 0 : ihl1
# 0 : jsp1
# 0 : jts1
# 0 : prin1
# 0 : pttgc1
# 0 : j1
# 0 : s50future2
# 0 : set501
# 0 : sgp1
# 0 : spcg1
# 0 : tasco1
# 0 : tfi1
# 0 : tgpro1
# 0 : tmw1
# 0 : tpa1
# 0 : trc1
# 0 : tsf1
# 0 : ukem1
# 0 : amata2
# 0 : apure2
# 0 : hft1
# 0 : rs1
# 0 : simat2
# 0 : twpc2
# 0 : umi2
# 0 : gpsc1
# 0 : ci1
# 0 : ea1
# 0 : hana1
# 0 : irpc1
# 0 : ivl1
# 0 : mk1
# 0 : moong1
# 0 : sta1
# 0 : di4
# 0 : rsi301
# 0 : rsi701
# 0 : www.maomate.com6
# 0 : โชว์ๆ1
# 0 : มอื่น1
# 0 : ผ่านๆ1
# 0 : cmpzg54cgc1
# 0 : lxkrto8kue1
# 0 : 35370191
# 0 : rsifhfmj0b1
# 0 : dailynewstwit1
# 0 : congress1
# 0 : สเปน1
# 0 : fzmaapuoep1
# 0 : smartcityexpoworldcongress20181
# 0 : จั1
# 0 : xx6z8ffnwu1
# 0 : employer1
# 0 : นายจ้าง1
# 0 : q4tm6yfryv1
# 0 : true_online4
# 0 : เรก1
# 0 : zyuf1
# 0 : อิจฉา1
# 0 : ซื้่อ1
# 0 : ตัดพ้อ1
# 0 : เปลี2
# 0 : คัฟ1
# 0 : เครื่องหมาย1
# 0 : าาา2
# 0 : 3bb1
# 0 : zprzrzge4d1
# 0 : v3jppcfhmu1
# 0 : bad1
# 0 : รือ1
# 0 : mammaamp1
# 0 : นขอ1
# 0 : 14209711
# 0 : 8637550306898922
# 0 : แอพพลิเคชัน1
# 0 : ปอร์ต1
# 0 : 31869081
# 0 : 42704041
# 0 : เม็ด1
# 0 : ที่ๆ2
# 0 : www.ais.co.th1
# 0 : 4gmax1
# 0 : www.hotdeal.ais.co.th1
# 0 : package.html1
# 0 : hotdeal1
# 0 : redirect1
# 0 : packagehotdeal1
# 0 : xzlyok7uog2
# 0 : ซัม1
# 0 : ซุง1
# 0 : รีเซ็ต1
# 0 : ไปมา2รอบ1
# 0 : 49955711
# 0 : หร1
# 0 : ข้อหา1
# 0 : คุณmawin0071
# 0 : ราชา1
# 0 : jul9e5q5ob1
# 0 : 19935451
# 0 : decimal4
# 0 : latitude4
# 0 : longitude4
# 0 : ศักดา3
# 0 : ลค์3
# 0 : เรซ3
# 0 : nav1
# 0 : header1
# 0 : items1
# 0 : kpufbxsy9m1
# 0 : kg3xfdh5lb1
# 0 : เขย2
# 0 : petesow1
# 0 : pinklao1
# 0 : จาณา1
# 0 : กราบ1
# 0 : เ3
# 0 : yxr9yocjzb3
# 0 : mbs2
# 0 : hd22
# 0 : 10085141
# 0 : ku1
# 0 : 3hd1
# 0 : 7hd1
# 0 : ในwalletถูก1
# 0 : log1
# 0 : 64gbครับ1
# 0 : คุณaerun1
# 0 : 47683761
# 0 : เมมเบอร์2
# 0 : 19001
# 0 : ชก1
# 0 : ว้างๆ1
# 0 : 43651191
# 0 : dyacถึง1
# 0 : ดิล1
# 0 : bnk48journal1
# 0 : ynfwa5ogzn1
# 0 : enxdddyfxq1
# 0 : 9axyiyixog1
# 0 : athlts1
# 0 : ชเเละ1
# 0 : 9biqlebzyw1
# 0 : 1kpdqghu4l1
# 0 : ruul3dhgfc1
# 0 : 8519871
# 0 : เจ้าค่ะ2
# 0 : เยาะ1
# 0 : เย้ย1
# 0 : โฮ๊ะๆๆๆ1
# 0 : fyi1
# 0 : mlgjyajnwc1
# 0 : ช้วย1
# 0 : 49964991
# 0 : สมัครtrue1
# 0 : walletแล้ว1
# 0 : 49955581
# 0 : 12จังหวัด1
# 0 : 45320641
# 0 : 50017731
# 0 : palitworld04071
# 0 : babielovepalit1
# 0 : เอไอ1
# 0 : toyubomm2
# 0 : นทาง1
# 0 : bzkqyywfcmร่วม1
# 0 : dd8pegarjb1
# 0 : www.เช็ค1
# 0 : พัสดุ.com1
# 0 : a0rahxshwj1
# 0 : ptyl3mq0ry1
# 0 : 6w0x4lxauq1
# 0 : ย่า1
# 0 : ยยยยยยยยย1
# 0 : 15.302
# 0 : ป.ล1
# 0 : จดด1
# 0 : อนึ่ง1
# 0 : รื้อฟื้น1
# 0 : chssde9iep2
# 0 : หมายเลข08290227281
# 0 : 59dlhxyldd1
# 0 : ปรืดดด1
# 0 : mamaredcarpet1
# 0 : 38734411
# 0 : เดิมที1
# 0 : พาสเวิร์ด1
# 0 : สิงคโปร์4
# 0 : jaymart2
# 0 : ปชช.ตรง1
# 0 : ทางjaymart1
# 0 : อีเมล์3
# 0 : แอปเปิล1
# 0 : 50033581
# 0 : คูลๆ1
# 0 : p39ll3ulwc1
# 0 : เร1
# 0 : จูดครั1
# 0 : 34613371
# 0 : gamer1
# 0 : pack1
# 0 : 28791981
# 0 : bsbctqvtu71
# 0 : งานbike1
# 0 : 7hluswwbpg1
# 0 : htv3
# 0 : hero2
# 0 : intel2
# 0 : 47372442
# 0 : ต่อwifi1
# 0 : เล็ต1
# 0 : รถเเจ้ง1
# 0 : 10669101
# 0 : 44992
# 0 : rollover1
# 0 : lover2
# 0 : 1.802
# 0 : shoppee1
# 0 : คนจน1
# 0 : ลงชื่อ1
# 0 : พก็1
# 0 : บราวเซอร์1
# 0 : ทรู320mb2
# 0 : 24ชม.ยัง2
# 0 : 24552441
# 0 : ศํพท์1
# 0 : disconnect1
# 0 : connectใหม่1
# 0 : พ์2
# 0 : notebook1
# 0 : windows1
# 0 : inssider1
# 0 : www.techspot.com1
# 0 : downloads1
# 0 : 59361
# 0 : inssider.html1
# 0 : 2.4ghz1
# 0 : กราฟ1
# 0 : play.google.com1
# 0 : details1
# 0 : com.farproc.wifi.analyzer1
# 0 : postimage.org1
# 0 : tinypic.com1
# 0 : 321431751
# 0 : chrome1
# 0 : desktop1
# 0 : ping3
# 0 : กาา1
# 0 : กละ1
# 0 : ติดใจ1
# 0 : ลูกไก่1
# 0 : ประหลาด3
# 0 : แสลง1
# 0 : 49973621
# 0 : 25492
# 0 : vodafone2
# 0 : 6902
# 0 : gsm4
# 0 : cdma2
# 0 : ที่ราบ2
# 0 : ฟาร์2
# 0 : อีส2
# 0 : ฮัท2
# 0 : พีที2
# 0 : แซท2
# 0 : บีเค2
# 0 : อินโดนีเซีย2
# 0 : เคที2
# 0 : คอร์เปอเรชั่น2
# 0 : เกาหลีใต้2
# 0 : อิงค์4
# 0 : ฟิลิปปินส์2
# 0 : ตาร์ฮับ2
# 0 : เกี1
# 0 : whljewswli1
# 0 : l84aamvyda1
# 0 : devil1
# 0 : girl1
# 0 : intiligent1
# 0 : bualuang1
# 0 : mbanking2
# 0 : 09368330691
# 0 : ที่131
# 0 : 200บาท1
# 0 : 09640518091
# 0 : จากบ.ช1
# 0 : 7441
# 0 : 172481
# 0 : นึกถึง1
# 0 : เทป2
# 0 : พากย์1
# 0 : sqx2muwwos1
# 0 : งืมมมมม1
# 0 : กทม1
# 0 : คชจ3
# 0 : ลูก31
# 0 : อยู่1
# 0 : 11011341
# 0 : พลาซ่า1
# 0 : 4pm5d22cx71
# 0 : คุณbutterfield1
# 0 : 08097050191
# 0 : 6811
# 0 : bundle1
# 0 : 2ctyuwo1
# 0 : 4442
# 0 : 444p1
# 0 : เห็น31
# 0 : h31
# 0 : 3p1
# 0 : commentsp1
# 0 : itispramote1
# 0 : sports1
# 0 : meball1
# 0 : ดอท1
# 0 : olqwfxn6hn1
# 0 : ผัน3
# 0 : ได้ๆ3
# 0 : 888.203
# 0 : ทั้งหมด1331.733
# 0 : เกิน193
# 0 : พฤศจิกายน25613
# 0 : ที่19นี้3
# 0 : 46642592
# 0 : ทรูมูฝ1
# 0 : 09177375701
# 0 : 1191
# 0 : ต.บางปะกง1
# 0 : อ.บางปะกง1
# 0 : จ.ฉะเชิงเทรา1
# 0 : 241301
# 0 : พรหม1
# 0 : เคราะห์1
# 0 : 36389641
# 0 : ชยัง1
# 0 : 771
# 0 : 96.501
# 0 : วาร์1
# 0 : ขาดตอน1
# 0 : สัมปทาน1
# 0 : ขยะ1
# 0 : coach_wk1
# 0 : ใหท่1
# 0 : 1kpdqgqifl1
# 0 : o0gbsbo0dk1
# 0 : 09675405211
# 0 : ตะคริว1
# 0 : ยุวะ1
# 0 : เนตร1
# 0 : ร.ร1
# 0 : ครีบ1
# 0 : ส่ส1
# 0 : แฮร่1
# 0 : สทช.ให้1
# 0 : ตุกติก2
# 0 : งงี่1
# 0 : เง่า1
# 0 : เจ๋งๆ1
# 0 : 7038621
# 0 : ไว้4g1
# 0 : promptpay1
# 0 : amuro_ray1
# 0 : version1
# 0 : promtpay2
# 0 : ยการป1
# 0 : ทรูช๊อ1
# 0 : ปก่อ1
# 0 : 48800001
# 0 : นทางใหน1
# 0 : พิซซ่า1
# 0 : พนง2
# 0 : นี้2แถม11
# 0 : noa5pwjohq2
# 0 : 4qdsundkkt1
# 0 : rodbenz_111
# 0 : สัญจร1
# 0 : ริ์ต1
# 0 : k5lt2jx8091
# 0 : ราวๆ1201
# 0 : มนั่นๆ1
# 0 : ip1
# 0 : ทรูเเน่1
# 0 : connecorn1
# 0 : 94811
# 0 : ข้าพเจ้า1
# 0 : airpods10
# 0 : กาย8
# 0 : บอุ2
# 0 : ecg1
# 0 : วงแหวน1
# 0 : activity1
# 0 : ring1
# 0 : ล้วน1
# 0 : siri2
# 0 : หายใจ2
# 0 : พอื่นๆ1
# 0 : studio2
# 0 : เด่นๆ1
# 0 : 6.11
# 0 : a121
# 0 : อึ1
# 0 : ดมากๆ1
# 0 : คอรัล1
# 0 : บลูทูธ1
# 0 : 6,9001
# 0 : 22gb1
# 0 : ลิมิเตด1
# 0 : เเท1
# 0 : รุป1
# 0 : 36047402
# 0 : อ้อนวอน1
# 0 : e6i9d5gzad1
# 0 : คุณiboxza1
# 0 : 49911301
# 0 : 19886482
# 0 : ufnielgxro1
# 0 : promotion2u1
# 0 : เมกะไบต์1
# 0 : นิวซีแลนด์1
# 0 : ะะ1
# 0 : 90i6omlftz1
# 0 : ชั่ยป่ะ1
# 0 : vreeview1
# 0 : เพราะtrue1
# 0 : เลือกtrue1
# 0 : คูล1
# 0 : 23643501
# 0 : 44650691
# 0 : afmgjlztdp1
# 0 : psynkh5jgp1
# 0 : เหมื1
# 0 : ปน1
# 0 : it24hrs1
# 0 : โซน8
# 0 : ยกับบบ1
# 0 : บังคับ3
# 0 : บกับ1
# 0 : สุดา1
# 0 : 10.00น1
# 0 : 21.00น1
# 0 : ปล.เปลี่ยน1
# 0 : มา4เดือน1
# 0 : ง่วง1
# 0 : ระยอง6
# 0 : ปลวกแดง5
# 0 : บรรดา1
# 0 : trueมี1
# 0 : cached1
# 0 : ตาร์ต1
# 0 : จาก4g1
# 0 : ที่5แล้ว1
# 0 : กู๊1
# 0 : ขาs1
# 0 : ขาl1
# 0 : put1
# 0 : ultimate1
# 0 : changtrixget1
# 0 : pchang1
# 0 : ชิคๆ1
# 0 : f1rrdm8swn1
# 0 : tallyxiaxy1
# 0 : transaction1
# 0 : wbmpwvqzaz1
# 0 : su5epf3psq1
# 0 : 0841
# 0 : 92791
# 0 : 89660025169151
# 0 : 50029111
# 0 : คุณhuayraกรุณา1
# 0 : kajirun3141
# 0 : eastern1
# 0 : seaboard1
# 0 : ปลวก1
# 0 : แเดง1
# 0 : ป๊า1
# 0 : คชุด1
# 0 : นกุก1
# 0 : ทำตัว1
# 0 : จีน12วัน1
# 0 : ปิดปาก1
# 0 : ซัว1
# 0 : เถา1
# 0 : แอ็1
# 0 : ดมิต1
# 0 : 2คน1
# 0 : บุหรี่1
# 0 : งดงาม1
# 0 : 2361941
# 0 : 963431กรุณา1
# 0 : บัวตูม1
# 0 : บัว1
# 0 : 99601
# 0 : รุ๊1
# 0 : งกะ1
# 0 : ริ๊ง1
# 0 : 88191
# 0 : h.comใน1
# 0 : 17971
# 0 : พนัน2
# 0 : 49937461
# 0 : ธารณู1
# 0 : โภค1
# 0 : walletของ1
# 0 : 2562น่ะ1
# 0 : งอุต3
# 0 : วสา2
# 0 : ธา1
# 0 : ยุโรป2
# 0 : เดม1
# 0 : keysight1
# 0 : brian1
# 0 : shen2
# 0 : บุกเบิก1
# 0 : structured1
# 0 : light1
# 0 : ubiquitous1
# 0 : ตัวกลาง1
# 0 : devices3
# 0 : health1
# 0 : ทุ่มเท1
# 0 : levin1
# 0 : liu1
# 0 : สถาบันวิจัย1
# 0 : cloud1
# 0 : abc1
# 0 : smartphones1
# 0 : forerunner1
# 0 : initiative1
# 0 : ออสเตรเลีย1
# 0 : 4,0201
# 0 : โปร10mbps1
# 0 : 10วัน1
# 0 : วิทยาทาน1
# 0 : 27087961
# 0 : 18993
# 0 : มายา1
# 0 : kdrgp5umrk1
# 0 : gilte2
# 0 : อกัน1
# 0 : ด้อย1
# 0 : บอด1
# 0 : หย่อมๆ1
# 0 : คลอด1
# 0 : กี้1
# 0 : ชั่นชั่1
# 0 : นอิน1
# 0 : เน็ตtrue2
# 0 : pon1
# 0 : 46353581
# 0 : 48388321
# 0 : ตะไคร่1
# 0 : ข่า่1
# 0 : 2ul7q4rxj41
# 0 : truemoveh5gdigitalthailand1
# 0 : ฉับไว1
# 0 : 6qw1kv6pa61
# 0 : vkwe4hbv1n1
# 0 : c67wdi59my1
# 0 : อินทร์1
# 0 : ตั่ง1
# 0 : ฉดใฉ1
# 0 : cnr0xjohtr1
# 0 : 13.5816281
# 0 : 100.5235081
# 0 : สารสาสน์1
# 0 : วิเทศ1
# 0 : สมุทร2
# 0 : เกลือ1
# 0 : เจดีย์1
# 0 : 102901
# 0 : กะพัน1
# 0 : 1,2841
# 0 : 08699838891
# 0 : job1
# 0 : iwifi1
# 0 : mifi1
# 0 : แชรwi1
# 0 : fiประมาณ31
# 0 : noutipziii1
# 0 : นว3
# 0 : ดวงใจ1
# 0 : เลิ๊ฟฟฟฟ1
# 0 : ร่อย1
# 0 : นทุ1
# 0 : คูปอง2
# 0 : นพ้อย1
# 0 : kfc1
# 0 : chester’s1
# 0 : pizza2
# 0 : hut2
# 0 : sizzler1
# 0 : plaza2
# 0 : au2
# 0 : bon2
# 0 : pain2
# 0 : oro1
# 0 : chester's1
# 0 : ข้าวยำ1
# 0 : ไก่4
# 0 : ซี่1
# 0 : 1491
# 0 : สำอาง1
# 0 : ของใช้1
# 0 : โซะ1
# 0 : garmin1
# 0 : aldo1
# 0 : oriental1
# 0 : princess1
# 0 : charles1
# 0 : keith1
# 0 : แคชเชียร์1
# 0 : cineplex2
# 0 : sf2
# 0 : cinema2
# 0 : ป๊1
# 0 : คอร์น1
# 0 : ดก1
# 0 : thuemoveh3
# 0 : nuyguitar1
# 0 : ซือ1
# 0 : เสิ1
# 0 : ในwallet1
# 0 : เอาเลย1
# 0 : ok1
# 0 : 45331491
# 0 : 49938451
# 0 : พิกัด13.7724891
# 0 : 100.5120041
# 0 : หรือuser1
# 0 : 49938311
# 0 : 770133กรุณา1
# 0 : 34946921
# 0 : 14951951
# 0 : กการร1
# 0 : counter3
# 0 : banking1
# 0 : dataคือ1
# 0 : อะไรtrue1
# 0 : อยู่3ที่1
# 0 : เครื่องsamsung1
# 0 : box2
# 0 : สลี1
# 0 : ฟก1
# 0 : ล่อง1
# 0 : random3
# 0 : สีชมพู1
# 0 : วอลเปเปอร์1
# 0 : logo1
# 0 : scan1
# 0 : สลีฟ1
# 0 : youngksmyday1
# 0 : สล1
# 0 : มด้วย1
# 0 : ในmassengerนะคะ1
# 0 : แกจ1
# 0 : แกง1
# 0 : ดูๆ1
# 0 : จี๊ด1
# 0 : pqbtqaor0y1
# 0 : ๑๔2
# 0 : ๔๐1
# 0 : pกลุ่ม1
# 0 : pppนาย1
# 0 : pppภายใน1
# 0 : p11
# 0 : pร่วม1
# 0 : p21
# 0 : pพบ2
# 0 : p31
# 0 : pสัมผัส1
# 0 : p41
# 0 : p51
# 0 : pสาธิต2
# 0 : p61
# 0 : pแสดง1
# 0 : p71
# 0 : pท้า1
# 0 : p81
# 0 : pเป่า1
# 0 : p91
# 0 : pพิสูจน์1
# 0 : p101
# 0 : ppp1
# 0 : cc63e065705fe938a4dda49092966f1
# 0 : innity_cat1
# 0 : tech_news1
# 0 : innity_zone1
# 0 : 246071
# 0 : innity_country1
# 0 : 4774b7a04c5a457804543fa1ecb587864
# 0 : คช้อป2
# 0 : inspired2
# 0 : incube2
# 0 : fast2
# 0 : fashion3
# 0 : pomelo2
# 0 : สาโรช1
# 0 : เฟื่อง1
# 0 : ฟู1
# 0 : เต้2
# 0 : บางกอก4
# 0 : คติ1
# 0 : เวชั่1
# 0 : buy1
# 0 : horror2
# 0 : gamess1
# 0 : pacific2
# 0 : polymold1
# 0 : offering1
# 0 : beta1
# 0 : dark1
# 0 : eden1
# 0 : games1
# 0 : purchase1
# 0 : whizz1
# 0 : wings1
# 0 : instant1
# 0 : intern1
# 0 : truetruemove2
# 0 : italthai1
# 0 : 23926231
# 0 : คุณjjbb801
# 0 : 47585181
# 0 : ละลาย2
# 0 : ช๊อ1
# 0 : 45125791
# 0 : 27158281
# 0 : นร่ว1
# 0 : มรา1
# 0 : ยกา1
# 0 : รดัง1
# 0 : 09726303621
# 0 : 10873221
# 0 : 9351
# 0 : t4xmcdbplb2
# 0 : ปกัน1
# 0 : กระจุย1
# 0 : euc1lycrok1
# 0 : vc7ehybovv1
# 0 : วิต1
# 0 : ตั้ง1ปี1
# 0 : บริการsmsเสีย1
# 0 : party1
# 0 : ยินยอม2
# 0 : garfiwld1
# 0 : ล่อ1
# 0 : we2bjgxncg1
# 0 : wyw72pflq31
# 0 : เล้ย1
# 0 : movie2free1
# 0 : rxcxpbcqat1
# 0 : ต้า1
# 0 : บุรีรัมย์1
# 0 : ษ์1
# 0 : tpl1
# 0 : ijube1
# 0 : pkaplcz9fe1
# 0 : n5iz0u8htl1
# 0 : 34367541
# 0 : คุณcommax1
# 0 : 44487601
# 0 : 19608361
# 0 : 08227475xxย้าย1
# 0 : 62u9eduqpw1
# 0 : ikfqlwzork1
# 0 : wemall1
# 0 : 9ven8irudb1
# 0 : weloveshopping2
# 0 : vf8ybucd4o1
# 0 : mxuzbuahbu1
# 0 : jormmarn1
# 0 : los1
# 0 : 49936661
# 0 : น๊า1
# 0 : อร์เด1
# 0 : 938682
# 0 : เเม่เเละ2
# 0 : โดนๆ1
# 0 : หิ้ว1
# 0 : hooray2
# 0 : มันเทศ1
# 0 : บดx61
# 0 : 140g1
# 0 : 6m1
# 0 : 3481
# 0 : www.babykidsbestbuyonline.com1
# 0 : thailandbabybestbuy1
# 0 : bbbonline1
# 0 : babykidsbestbuyonline1
# 0 : shoppingonline1
# 0 : mother1
# 0 : baby1
# 0 : babyproducts1
# 0 : stroller1
# 0 : carseat1
# 0 : เข็น1
# 0 : himachanhan1
# 0 : แว๊ว1
# 0 : ตุก1
# 0 : คนี่1
# 0 : อดเว1
# 0 : สดี1
# 0 : สูสี1
# 0 : 4137611กรุณา1
# 0 : ราชปรารภ1
# 0 : vrzp5ebpuy1
# 0 : ธัน1
# 0 : pjcnwbrelu1
# 0 : superfun1
# 0 : กระดาษ1
# 0 : 06427233991
# 0 : 40472251
# 0 : 17642811
# 0 : ญาต1
# 0 : 2601
# 0 : ptloz4qxej1
# 0 : ขอห1
# 0 : บัก1
# 0 : 2402
# 0 : 8651
# 0 : 8751
# 0 : bandwith1
# 0 : amc1
# 0 : tcm1
# 0 : 49927041
# 0 : 9470641
# 0 : teletalk1
# 0 : u7c2ik5q11
# 0 : มิต5501
# 0 : เป็น7001
# 0 : ใช้699อยู่1
# 0 : ค่ะ55551
# 0 : storeดี1
# 0 : 20840662
# 0 : 383431241
# 0 : เเพิ่ม1
# 0 : mahanakorn3
# 0 : skywalk3
# 0 : รีย์1
# 0 : triple6
# 0 : ซอฟท์แวร์3
# 0 : กลมกล่อม1
# 0 : อป2
# 0 : ทฤษฏี1
# 0 : เค้น2
# 0 : แส1
# 0 : น้อยห2
# 0 : อินฟราเรด1
# 0 : วัตถุ3
# 0 : pi6
# 0 : wide2
# 0 : 2.551
# 0 : pixel1
# 0 : pddaf1
# 0 : 20mp1
# 0 : 25mp1
# 0 : angle1
# 0 : beauty1
# 0 : เนียน1
# 0 : เเอ1
# 0 : วัณ1
# 0 : นอยส์1
# 0 : 781
# 0 : ตกดิน1
# 0 : sunset1
# 0 : proo4
# 0 : ชัตเตอร์2
# 0 : ทำเอา1
# 0 : แสงจันทร์3
# 0 : สาด1
# 0 : bokeh1
# 0 : ไปปป1
# 0 : food3
# 0 : ขอตัว1
# 0 : ปุ๊1
# 0 : จำแนก1
# 0 : ชนิด1
# 0 : prooo2
# 0 : เว้1
# 0 : ป้2
# 0 : อุทาน1
# 0 : เฮ้ย1
# 0 : amazing1
# 0 : จ้าน1
# 0 : จับจอง1
# 0 : โปป้1
# 0 : รนด์ช้อปป1
# 0 : v91
# 0 : 24mp1
# 0 : zenfone1
# 0 : จบบบ1
# 0 : aiss1
# 0 : brother3
# 0 : 3600w1
# 0 : dcp1
# 0 : l5600dn1
# 0 : ศศ1
# 0 : shoppping1
# 0 : โปa3sที่1
# 0 : 49998361
# 0 : ชิก1
# 0 : แสะ1
# 0 : register1
# 0 : แน้ว1
# 0 : ชิบ1
# 0 : ที่aisไม่มี1
# 0 : รับ55555551
# 0 : imkajxsikr1
# 0 : gunnarxdaniel1
# 0 : ติดต่อcall1
# 0 : พระราม91
# 0 : เอซๆๆๆๆๆๆ1
# 0 : เฮา1
# 0 : โปร่ง1
# 0 : ว๊าวว๊าว1
# 0 : aisนี่1
# 0 : sukkasame1
# 0 : purissapan1
# 0 : ไฟฟ1
# 0 : มโน1
# 0 : ขนม1
# 0 : ขนมปัง1
# 0 : yamazaki1
# 0 : ฟกาแฟ1
# 0 : เผ็ด1
# 0 : ฉัตร1
# 0 : หนีบ1
# 0 : insurance1
# 0 : เบี้ย1
# 0 : พริต1
# 0 : ตี้1
# 0 : mg1
# 0 : dayang1
# 0 : เซลล์1
# 0 : makro1
# 0 : มันๆ1
# 0 : 24shopping1
# 0 : ซักรีด1
# 0 : cp2
# 0 : เจีย1
# 0 : ไต๋1
# 0 : จรวด1
# 0 : เก๋1

# %% [markdown]
# ##  ตรวจสอบจำนวนคำซ้ำ
#
# - Function : check_pos(),check_neg(),check_neu()

# %%
def check_pos(word): 

    file = open("dictionary/"+project_name+"/dic_positive.txt","r")

    for line in file:

        value = line.split(":")

        if word == value[0] :
            
            try :
            
                return value[1]
            
            except :
                
                return 0
            
def check_neg(word): 

    file = open("dictionary/"+project_name+"/dic_negative.txt","r")

    for line in file:

        value = line.split(":")

        if word == value[0] :
            
            try :
            
                return value[1]
            
            except :
                
                return 0

def check_neu(word): 

    file = open("dictionary/"+project_name+"/dic_neutral.txt","r")

    for line in file:

        value = line.split(":")

        if word == value[0] :
            
            try :
            
                return value[1]
            
            except :
                
                return 0

# %% [markdown]
# ## หาผลลัพธ์ของคำ
#
#  - fraction() : รวมผลลัพธ์ของคำทั้งหมด แบ่งออกเป็น positive,negative,neutral ตัวอย่าง positive=52,negative=43,neutral=89
#  - lex_summary() : รวมคะแนนของแต่ละคำ
#  - lex_division () : นับจำนวนคำในแต่ละด้าน เช่น สวัสดี : postive=4,negative=2,neutral=8
#  - pos_summary(),neg_summary(),neu_summary() : แยกผลลัพธ์ของ lexicon ออกเป็น 3 ส่วน คือ 1.Positive,2.Neagative,3.Neutral

# %%
def fraction(params):
    
    file = open(dir_lex+"/"+project_name+"/dic_"+params+".txt","r")

    total = 0
    for line in file:

        value = line.split(":")

        try:

            total = total+int(value[1])

        except:

            total = 0
             
    return total

# %%
# ---------------- Term Score ---------------- #

def lex_summary(list_word):

    ppos = check_pos(list_word)
    pneg = check_neg(list_word)
    pneu = check_neu(list_word)
    
#     fix 

    fraction_pos = fraction('positive')
    fraction_neg = fraction('negative')
    fraction_neu = fraction('neutral') 
    
    if ppos is None :
        
        ppos = 0
    
    if pneg is None :
        
        pneg = 0
    
    if pneu is None :
        
        pneu = 0
 
        
    xx = (int(ppos)/fraction_pos)-(int(pneg)/fraction_neg)
    xy = (int(ppos)/fraction_pos)+(int(pneg)/fraction_neg)+(int(pneu)/fraction_neu)
    
    try:
        
        p_total = xx/xy

        return p_total
        
    except ZeroDivisionError:
            
        return 0
    
    except :
    
        return 0 


def lex_division(list_word):

    ppos = check_pos(list_word)
    pneg = check_neg(list_word)
    pneu = check_neu(list_word)
    
    if ppos is None :
        
        ppos = 0
    
    if pneg is None :
        
        pneg = 0
    
    if pneu is None :
        
        pneu = 0
        
    total = int(ppos),int(pneg),int(pneu)
        
    return total

# %%
def pos_summary() :

    filename = open(dir_lex+"/"+project_name+"/dic_positive.txt","r")

    for line in filename:

            value = line.split(":") 

            try:

                if lex_summary(value[0].strip()) != 0 :

                        with open(dir_lex+'/'+project_name+'/dic_positive_summary.txt', 'a') as the_file:  

                            the_file.write(str(lex_summary(value[0].strip()) )+"||"+str(lex_division(value[0].strip()) )+"||"+str(value[0])+"\n")
            except :
                
                continue          
            
def neg_summary() :

    filename = open(dir_lex+"/"+project_name+"/dic_negative.txt","r")

    for line in filename:

            value = line.split(":") 

            try:

                if lex_summary(value[0].strip()) != 0 :

                        with open(dir_lex+'/'+project_name+'/dic_negative_summary.txt', 'a') as the_file:  

                            the_file.write(str(lex_summary(value[0].strip()) )+"||"+str(lex_division(value[0].strip()) )+"||"+str(value[0])+"\n")
            except :
                
                continue
            
def neu_summary() :

    filename = open(dir_lex+"/"+project_name+"/dic_neutral.txt","r")

    for line in filename:

            value = line.split(":") 

            try:

                if lex_summary(value[0].strip()) != 0 :

                        with open(dir_lex+'/'+project_name+'/dic_neutral_summary.txt', 'a') as the_file:  

                            the_file.write(str(lex_summary(value[0].strip()) )+"||"+str(lex_division(value[0].strip()) )+"||"+str(value[0])+"\n")
            except :
                
                continue

# %%
# -------------- summary ---------------- # 
print (pos_summary())
print (neg_summary())
print (neu_summary())
# Out:
# None
# None
# None

# %% [markdown]
# ## การรวมผลลัพธ์ของ Lexicon
#  - create_lexicon() : รวมข้อมูลของ lexicon ทั้งหมด จาก positive_summary,negative_summary,neutral_summary
#  - classified() :

# %%
# --- Create file empty lexicon

def create_lexicon():

    file = open(dir_lex+"/"+project_name+"/lexicon.txt","a")

    file_pos = open(dir_lex+"/"+project_name+"/dic_positive_summary.txt","r")

    for line in file_pos: 

        with open(dir_lex+'/'+project_name+'/lexicon.txt', 'a') as the_file:  

            the_file.write(line)

    file_pos.close()

    file_neg = open(dir_lex+"/"+project_name+"/dic_negative_summary.txt","r")

    for line in file_neg: 

        with open(dir_lex+'/'+project_name+'/lexicon.txt', 'a') as the_file:  

            the_file.write(line)

    file_neg.close()

    file_neu = open(dir_lex+"/"+project_name+"/dic_neutral_summary.txt","r")

    for line in file_neu: 

        with open(dir_lex+'/'+project_name+'/lexicon.txt', 'a') as the_file:  

            the_file.write(line)

    file_neu.close()
    file.close() 
    
# -------- call -------#
create_lexicon()

# %%
# -------------- final lexicon ------------------- #
from collections import Counter

list = [] 

def classified():
 
    file = open(dir_lex+'/'+project_name+'/lexicon.txt',"r")

    i = 1
    
    for line in file: 
    
        value_o = line.split("||")

        print (str(i)+' '+value_o[0]+'||'+value_o[1]+'||'+value_o[2])
        
        final = open(dir_lex+'/'+project_name+'/lexicon.txt',"r")
        
        i+=1 
        
        list.append(value_o[0].strip()+'||'+value_o[1]+'||'+value_o[2].strip()) 
    
    myset = set(list) 
    
    open(dir_lex+'/'+project_name+'/lexicon.txt', 'w').close()
     
    for z in myset: 
        
        xy = z.split("||")
        
        print (xy[0]+"||"+xy[1]+"||"+xy[2])

        with open(dir_lex+'/'+project_name+'/lexicon.txt', 'a') as the_file:  
                
            the_file.write(xy[0]+"||"+xy[1]+"||"+xy[2]+"\n")

# ---------- call func -----------#

print (classified())
# Out:
# 1 -0.11608913652926833||(16, 93, 247)||อยาก
#
# 2 -0.2850050453262058||(72, 740, 3131)||ได้
#
# 3 0.9844108604338978||(2, 0, 1)||โปรdtacที่
#
# 4 0.2930654277701273||(5, 6, 190)||คุ้ม
#
# 5 0.3227007917137937||(52, 103, 403)||กว่า
#
# 6 -0.2677154069965779||(45, 446, 2065)||นี้
#
# 7 -0.014831689614778662||(23, 105, 581)||หรือ
#
# 8 0.13625131184758887||(49, 146, 1032)||โปร
#
# 9 0.08288103034852791||(72, 263, 388)||ย้าย
#
# 10 -0.02514076782718966||(61, 283, 560)||ค่าย
#
# 11 -0.13197149983393147||(30, 205, 1594)||ของ
#
# 12 0.5138999981237131||(83, 98, 398)||ais
#
# 13 0.18706763611800822||(81, 210, 1509)||true
#
# 14 0.47620887092917447||(199, 198, 2487)||-
#
# 15 0.9844108604338978||(2, 0, 1)||hก็ได้
#
# 16 -0.1170291004116355||(63, 386, 2005)||ครับ
#
# 17 -0.1086770041265071||(23, 134, 513)||[
#
# 18 0.523926364253221||(33, 35, 213)||dtac
#
# 19 -0.1135755621094617||(53, 320, 1594)||,
#
# 20 0.034984303730275106||(1, 4, 18)||app
#
# 21 1.0||(3, 0, 0)||reward
#
# 22 0.8502324946457424||(3, 1, 1)||trinet
#
# 23 -0.10848021651103149||(23, 134, 517)||]
#
# 24 -0.28547593471007887||(18, 177, 634)||คือ
#
# 25 -0.1425484534390627||(70, 458, 2142)||ใช้
#
# 26 0.6282911719153331||(1, 1, 0)||โปร699
#
# 27 1.0||(1, 0, 0)||เน็ต6mbps
#
# 28 -0.3495023337995339||(93, 990, 1943)||ไม่
#
# 29 -0.10176451853126145||(2, 14, 207)||จำกัด
#
# 30 -0.2790657196306665||(47, 404, 721)||ผม
#
# 31 -0.3706536100816697||(17, 201, 475)||โทร
#
# 32 -0.17513422820656618||(16, 120, 684)||ด้วย
#
# 33 -0.40662074975618306||(41, 531, 1107)||ก็
#
# 34 0.06897433316082924||(6, 20, 323)||ก็ได้
#
# 35 -0.3171566780417895||(4, 55, 329)||ซึ่ง
#
# 36 -0.18658967731827023||(16, 106, 118)||เคย
#
# 37 -0.14818056931559867||(16, 107, 519)||ขอ
#
# 38 1.0||(1, 0, 0)||โปรdtacที
#
# 39 -0.14354220939114076||(2, 13, 56)||เพื่อน
#
# 40 -0.3443868932454898||(4, 43, 97)||เขา
#
# 41 -0.5992949136334074||(6, 174, 333)||แจ้ง
#
# 42 -0.4198461522522429||(36, 498, 1116)||ว่า
#
# 43 -0.23990687513010148||(25, 204, 579)||ต้อง
#
# 44 0.009314133634860663||(14, 60, 153)||รอ
#
# 45 -0.029703405811587667||(7, 33, 108)||ช่วง
#
# 46 0.05417588955648897||(51, 182, 2587)||ใน
#
# 47 0.04562948404144783||(47, 172, 2629)||การ
#
# 48 0.04576438353788513||(3, 10, 328)||จัด
#
# 49 0.25365255034180634||(12, 27, 153)||นาน
#
# 50 -0.21516507554670558||(19, 141, 319)||มาก
#
# 51 -0.39314083111488274||(6, 66, 63)||จน
#
# 52 -0.5376158129129079||(5, 93, 125)||คิด
#
# 53 -0.2586034631635226||(51, 479, 2061)||จะ
#
# 54 -0.37088429507091053||(37, 447, 1147)||แล้ว
#
# 55 -0.18195614089170448||(19, 143, 737)||นะ
#
# 56 -0.16153121208197854||(19, 130, 550)||ตอน
#
# 57 0.9132286184871249||(1, 0, 3)||โปร899
#
# 58 -0.42887426682039864||(10, 162, 503)||จ่าย
#
# 59 1.0||(1, 0, 0)||629บ
#
# 60 -0.04177403385450245||(70, 351, 2914)||.
#
# 61 1.0||(1, 0, 0)||เน้ต30gb
#
# 62 1.0||(1, 0, 0)||โทร400นาที
#
# 63 -0.6151200231106286||(12, 339, 534)||เรา
#
# 64 -0.26067294720413475||(66, 592, 2024)||ไป
#
# 65 -0.2457304760443182||(7, 60, 207)||ออก
#
# 66 -0.19845099145722575||(4, 33, 198)||ทราบ
#
# 67 -0.10929828661547944||(58, 350, 1972)||มี
#
# 68 -0.0959273376255756||(117, 697, 5143)||ที่
#
# 69 0.2844069998328198||(29, 36, 1132)||ราคา
#
# 70 0.24337503931195673||(66, 150, 955)||ดี
#
# 71 -0.27777975644477176||(3, 28, 89)||มั้ย
#
# 72 0.003920915085603151||(6, 26, 144)||แนะนำ
#
# 73 -0.3299094103194614||(6, 62, 144)||หน่อย
#
# 74 0.21783884316540852||(5, 13, 43)||ตก
#
# 75 -0.14190812378626042||(34, 225, 1168)||เดือน
#
# 76 -0.1546856453432598||(12, 78, 244)||ละ
#
# 77 1.0||(1, 0, 0)||เกือบ1พัน
#
# 78 -0.42476972590377227||(7, 124, 469)||เพราะ
#
# 79 -0.4321870277462082||(10, 171, 573)||อีก
#
# 80 -0.18173662091370132||(18, 136, 718)||ราย
#
# 81 0.06318275049220079||(18, 69, 58)||ตัด
#
# 82 -0.7054058715670037||(2, 66, 46)||บิล
#
# 83 0.23133270155492974||(2, 5, 18)||ทุกๆ
#
# 84 -0.2537113945801734||(24, 231, 1153)||วัน
#
# 85 0.4907563123717152||(6, 4, 109)||16
#
# 86 0.06368310394324518||(13, 46, 497)||ผ่าน
#
# 87 -0.25281721098902443||(60, 539, 2094)||มา
#
# 88 -0.24143243822941263||(41, 324, 681)||แต่
#
# 89 -0.02929397685712616||(5, 25, 424)||เต็ม
#
# 90 -0.04562206091980756||(15, 74, 303)||ไหม
#
# 91 0.0859319913641543||(109, 343, 5366)||?
#
# 92 0.34829565013203123||(4, 7, 41)||online
#
# 93 -0.3354346346652494||(18, 188, 422)||เบอร์
#
# 94 0.011428794194110652||(19, 81, 223)||เดิม
#
# 95 1.0||(1, 0, 0)||ผมมี
#
# 96 -0.12414879155113631||(5, 30, 96)||ลอง
#
# 97 -0.11377698846541948||(13, 92, 1147)||ซื้อ
#
# 98 -0.4581169642390199||(5, 77, 154)||เอา
#
# 99 -0.21488943233326624||(2, 21, 196)||ซิม
#
# 100 -0.3514525945735572||(6, 118, 841)||เติม
#
# 101 -0.4295051578069219||(17, 264, 741)||เงิน
#
# 102 0.10525219380897771||(2, 7, 7)||ปราก
#
# 103 0.10525219380897771||(2, 7, 7)||ฎ
#
# 104 -0.27579708425030813||(43, 375, 817)||เน็ต
#
# 105 0.26769426309782496||(13, 29, 133)||มากๆ
#
# 106 0.7083476147446484||(2, 0, 26)||ย่าน
#
# 107 -0.183727288146092||(23, 166, 637)||อยู่
#
# 108 -0.06354930649888528||(4, 22, 223)||ทำงาน
#
# 109 0.45823156909326784||(7, 11, 9)||แถว
#
# 110 0.9619176575127999||(4, 0, 5)||รถไฟฟ้า
#
# 111 0.11152118855360312||(12, 40, 145)||ตลอด
#
# 112 0.09179799010007232||(5, 15, 276)||7
#
# 113 0.04270363681935452||(23, 89, 616)||ปี
#
# 114 -0.15672672839258636||(1, 9, 116)||ระหว่าง
#
# 115 0.3965750227074053||(7, 6, 184)||บน
#
# 116 0.544109864401379||(1, 1, 6)||bts
#
# 117 0.04550929215333656||(7, 23, 827)||+
#
# 118 0.6124975345512074||(1, 1, 1)||แอร์
#
# 119 0.8875570999102018||(1, 0, 4)||พอร์ต
#
# 120 0.29087250354856825||(1, 2, 13)||ลิงค์
#
# 121 -0.3565180123267295||(3, 44, 212)||ตั้งแต่
#
# 122 1.0||(1, 0, 0)||พญาไท
#
# 123 0.5893500635159308||(1, 0, 22)||ยัน
#
# 124 0.6282911719153331||(1, 1, 0)||สุวรรณภูมิ
#
# 125 0.5212436658794396||(1, 0, 29)||เส้น
#
# 126 0.525949689094015||(7, 9, 11)||เสถียร
#
# 127 -0.242870337309518||(43, 351, 939)||เลย
#
# 128 -0.07312903304018888||(6, 31, 52)||ย
#
# 129 0.6282911719153331||(1, 1, 0)||บ่นๆ
#
# 130 -0.12534823021768246||(68, 427, 2200)||ให้
#
# 131 0.5534245279257969||(5, 6, 6)||cc
#
# 132 -0.12324075784404212||(1, 10, 225)||ฟัง
#
# 133 -0.03650390660616862||(19, 94, 849)||รับ
#
# 134 -0.27166123226348443||(14, 127, 385)||เรื่อง
#
# 135 -0.24717394952068963||(4, 37, 175)||ไว้
#
# 136 -0.126513254684797||(17, 100, 197)||ไม่มี
#
# 137 -0.3394580395427276||(3, 30, 47)||ไร
#
# 138 0.0973671320708249||(1, 3, 49)||เปลี่ยนแปลง
#
# 139 -0.02303028724549098||(6, 28, 146)||หลาย
#
# 140 -0.29893982087761584||(7, 79, 375)||ครั้ง
#
# 141 -0.41064234210961637||(2, 23, 21)||เลิก
#
# 142 0.2995785959432553||(7, 14, 79)||ปัจจุบัน
#
# 143 -0.382602835213188||(13, 151, 273)||สัญญาณ
#
# 144 -0.5103761411653134||(8, 123, 103)||เหมือน
#
# 145 -0.040547387033502226||(2, 10, 85)||ล่าสุด
#
# 146 -0.44239441289306697||(12, 169, 300)||บอก
#
# 147 -0.2250417445732004||(8, 78, 561)||คุณ
#
# 148 0.0011644087476790027||(19, 83, 229)||ลูกค้า
#
# 149 0.8875570999102018||(1, 0, 4)||รถไฟ
#
# 150 0.04258907910639735||(2, 8, 8)||วิ่ง
#
# 151 0.2363757008959128||(10, 20, 266)||ความเร็ว
#
# 152 0.1657741558594005||(4, 11, 78)||อาจ
#
# 153 0.1361886467440461||(1, 2, 80)||จับ
#
# 154 0.5813501456654661||(3, 2, 29)||นัก
#
# 155 0.028021436713407063||(24, 95, 1164)||(
#
# 156 0.1898627647738575||(14, 36, 260)||ใจ
#
# 157 -0.006739216257011824||(18, 80, 85)||ทำไม
#
# 158 -0.5792736020141422||(6, 151, 274)||มัน
#
# 159 0.09282561185117989||(1, 3, 54)||เกี่ยว
#
# 160 1.0||(1, 0, 0)||มั๊ง
#
# 161 0.05646687482899175||(27, 97, 1164)||)
#
# 162 -0.10522555618724663||(9, 61, 754)||เมื่อ
#
# 163 0.03647472845190909||(4, 15, 264)||6
#
# 164 -0.4829925263400365||(2, 32, 53)||อ
#
# 165 -0.045632404605629825||(24, 122, 1027)||กัน
#
# 166 -0.3325908092400315||(3, 27, 11)||ห่วย
#
# 167 -0.6331913672151622||(1, 31, 48)||หัก
#
# 168 -0.10058602062767925||(2, 11, 18)||ทิ้ง
#
# 169 -0.24423713893799137||(9, 101, 805)||ขึ้น
#
# 170 0.7416239846018334||(1, 0, 11)||แผน
#
# 171 -0.2088664892787034||(6, 48, 214)||เห็น
#
# 172 0.18744105866705363||(6, 17, 45)||ร
#
# 173 -0.17009922682796427||(91, 661, 3480)||ทรู
#
# 174 0.16809390679392092||(1, 3, 6)||เท่ากับ
#
# 175 -0.06912169463570554||(32, 184, 2233)||และ
#
# 176 -0.5292484281859907||(4, 102, 289)||สมัคร
#
# 177 -0.14100831554327414||(13, 83, 323)||ก่อน
#
# 178 0.16227077726938535||(1, 0, 163)||31
#
# 179 0.7781809468387362||(1, 0, 9)||ธันวา
#
# 180 0.25655501785750423||(10, 23, 103)||สนใจ
#
# 181 -0.19696751513864974||(5, 58, 745)||อย่าง
#
# 182 0.27741901493771687||(13, 27, 173)||แรง
#
# 183 -0.18295171593150913||(7, 48, 116)||ถาม
#
# 184 -0.29694293377767444||(4, 40, 131)||ปกติ
#
# 185 -0.30217824977498214||(5, 47, 102)||รอบ
#
# 186 -0.12548130323604656||(3, 24, 356)||เกิด
#
# 187 0.20188817681302154||(1, 2, 39)||19
#
# 188 -0.5895626750914982||(4, 85, 86)||เสีย
#
# 189 -0.1777460267892086||(33, 230, 765)||ค่า
#
# 190 -0.09148094681586201||(36, 199, 683)||บริการ
#
# 191 -0.11821234420160016||(3, 17, 18)||รึ
#
# 192 -0.07035930370287644||(9, 51, 534)||แค่
#
# 193 -0.25610515342630225||(6, 60, 327)||3
#
# 194 0.16274670846628186||(9, 26, 123)||ขอบคุณ
#
# 195 0.8403134587661258||(1, 0, 6)||ปล
#
# 196 -0.20503613468591153||(1, 8, 38)||ลับ
#
# 197 -0.18150124762164366||(11, 93, 762)||เครื่อง
#
# 198 -0.023117535862416615||(11, 52, 467)||ใหม่
#
# 199 0.29846193950875205||(2, 4, 23)||samsung
#
# 200 0.48945982108271446||(1, 1, 11)||smartphone
#
# 201 0.036892833351323207||(46, 183, 844)||truemove
#
# 202 0.19093396383817873||(51, 133, 844)||h
#
# 203 0.09882179238087116||(62, 205, 1422)||จาก
#
# 204 0.12732592872114096||(4, 13, 36)||แทค
#
# 205 -0.11789494321501008||(8, 55, 571)||เพื่อ
#
# 206 0.11236278398420181||(15, 49, 245)||ไหน
#
# 207 1.0||(2, 0, 0)||คุ้มๆ
#
# 208 -0.28567812447825874||(9, 83, 217)||บ้าง
#
# 209 -0.40991128429761436||(10, 141, 377)||คะ
#
# 210 0.9132286184871249||(1, 0, 3)||j4
#
# 211 -0.22387875417017492||(14, 118, 532)||ถ้า
#
# 212 0.01863225389803668||(5, 21, 40)||ออนไลน์
#
# 213 -0.10188929776126973||(10, 63, 588)||หน้า
#
# 214 -0.075446611530692||(3, 19, 328)||เค้า
#
# 215 -0.16413577532183452||(1, 7, 33)||เตอร์
#
# 216 0.3844342811073255||(5, 5, 123)||สะดวก
#
# 217 -0.18203013989909383||(26, 182, 564)||ค่ะ
#
# 218 0.4933687008424962||(3, 4, 10)||มั๊ย
#
# 219 1.0||(2, 0, 0)||โปร249
#
# 220 0.6124975345512074||(1, 1, 1)||เอ่ย
#
# 221 -0.4497447801197915||(2, 30, 61)||ยอม
#
# 222 -0.44102555014705513||(1, 16, 43)||ดีๆ
#
# 223 -0.3004042813383664||(2, 17, 12)||มาบ
#
# 224 -0.13925643881167332||(4, 24, 36)||อก
#
# 225 -0.433140173908889||(8, 108, 183)||หมด
#
# 226 -0.14315273242063178||(3, 31, 581)||เพิ่ม
#
# 227 -0.43948266423622057||(3, 48, 131)||เดียว
#
# 228 -0.3093536286542048||(14, 174, 929)||แบบ
#
# 229 -0.17313309541046712||(12, 107, 1116)||ความ
#
# 230 -0.2815950643011709||(3, 26, 47)||รู้สึก
#
# 231 0.8632894087266927||(1, 0, 5)||ใช้ais
#
# 232 -0.2038140424124393||(17, 117, 124)||บ้าน
#
# 233 1.0||(1, 0, 0)||ของaisfibre
#
# 234 0.5974784504061477||(5, 5, 10)||สน
#
# 235 0.343241120630092||(1, 2, 4)||แคร์
#
# 236 -0.13654145377704768||(3, 18, 32)||เก่า
#
# 237 -0.5304058005064995||(1, 16, 11)||อะ
#
# 238 0.11941366910779687||(28, 87, 641)||ถึง
#
# 239 0.07271601293064053||(18, 65, 336)||เวลา
#
# 240 0.6124975345512074||(1, 1, 1)||สินะ
#
# 241 0.17147028791168784||(15, 43, 171)||น่า
#
# 242 0.4063772271167306||(5, 7, 56)||ครั
#
# 243 0.29588850176756126||(1, 2, 12)||ปลด
#
# 244 0.31326222827100797||(1, 1, 39)||ล็อค
#
# 245 0.4161982929813675||(2, 3, 15)||ด่วน
#
# 246 0.3575461251229868||(1, 2, 2)||แจ้
#
# 247 0.03841393077282564||(1, 4, 11)||งก
#
# 248 0.043954019584499876||(1, 4, 2)||สทช
#
# 249 1.0||(1, 0, 0)||08004242xx
#
# 250 0.9693003027331258||(1, 0, 1)||ปฎิ
#
# 251 1.0||(1, 0, 0)||เสธ
#
# 252 0.8875570999102018||(1, 0, 4)||ยื้อ
#
# 253 0.343241120630092||(1, 2, 4)||ว่าง
#
# 254 -0.35641501035395423||(6, 64, 112)||ติดต่อ
#
# 255 1.0||(2, 0, 0)||359
#
# 256 -0.03623210349570546||(16, 83, 1465)||บาท
#
# 257 0.07940569253413123||(8, 27, 283)||4
#
# 258 0.5090090207078518||(3, 1, 70)||gb
#
# 259 -0.5644818532789656||(5, 99, 113)||พอ
#
# 260 -0.27589780746805154||(7, 95, 775)||ต่อ
#
# 261 -0.24343045674140504||(3, 27, 121)||เท่า
#
# 262 -0.5902916770570888||(1, 23, 30)||ไหร่
#
# 263 -0.4379069237576164||(10, 146, 314)||ทำ
#
# 264 -0.593517790897998||(1, 35, 88)||อย่างไร
#
# 265 -0.024882875357697447||(6, 28, 106)||mobile
#
# 266 0.11448121614982232||(3, 10, 31)||internet
#
# 267 0.5831783046344657||(1, 1, 3)||สมมุติ
#
# 268 0.9404294047077318||(1, 0, 2)||special
#
# 269 -0.0038176736231815976||(2, 9, 323)||unlimited
#
# 270 0.2239901703620983||(2, 2, 140)||plus
#
# 271 0.4870696119812311||(4, 0, 133)||300
#
# 272 0.06060168684361756||(1, 3, 111)||อั้น
#
# 273 -0.05904822438008212||(1, 5, 8)||6mbps
#
# 274 0.2281569486479946||(175, 218, 10234)||/
#
# 275 0.4308261892984138||(5, 7, 41)||นอก
#
# 276 1.0||(1, 0, 0)||เครือ200นาที
#
# 277 1.0||(1, 0, 0)||ราคา300บาท
#
# 278 -0.09714636747885223||(6, 36, 272)||ส
#
# 279 0.07373724529911643||(4, 12, 327)||สมา
#
# 280 0.31411686314696585||(4, 5, 125)||รถ
#
# 281 -0.20136026543044794||(6, 43, 99)||ศูนย์
#
# 282 0.5322248795787595||(2, 2, 14)||ป่าว
#
# 283 -0.11219008119464104||(8, 54, 576)||เครือ
#
# 284 -0.10824544273081597||(8, 53, 561)||ข่าย
#
# 285 -0.35261772025972726||(5, 54, 109)||อื่น
#
# 286 -0.012039419409021698||(4, 18, 30)||operator
#
# 287 -0.0675410800224828||(1, 6, 98)||24
#
# 288 -0.062346456236031064||(1, 5, 4)||ธค
#
# 289 0.3970938920100501||(10, 15, 99)||ครบ
#
# 290 -0.17794330445456996||(8, 54, 126)||สัญญา
#
# 291 0.07724894909892122||(13, 39, 983)||พร้อม
#
# 292 -0.051948767802050086||(3, 15, 55)||แพค
#
# 293 0.15536460803000526||(4, 11, 97)||เก
#
# 294 0.9132286184871249||(1, 0, 3)||จนี้
#
# 295 -0.2638704778024188||(3, 25, 49)||น้อย
#
# 296 0.03937904529749486||(4, 16, 37)||แพง
#
# 297 0.025467134244590565||(10, 40, 473)||ส่วน
#
# 298 0.02617182563311854||(5, 20, 222)||ใหญ่
#
# 299 0.5695466823134859||(1, 1, 4)||ถูกใจ
#
# 300 -0.24618633384521557||(4, 33, 89)||เบ
#
# 301 -0.4906494801081446||(2, 37, 85)||บอร์
#
# 302 0.08989065671347368||(2, 6, 115)||อิน
#
# 303 -0.10927227245332137||(2, 12, 64)||เต
#
# 304 0.22273685204112073||(6, 16, 28)||อินเตอร์เน็ต
#
# 305 -0.12828770705222942||(6, 36, 97)||เกิน
#
# 306 0.33003673483776763||(2, 4, 12)||500
#
# 307 0.14742272383040203||(3, 8, 99)||เกจ
#
# 308 0.2168102013483336||(3, 7, 59)||ทันที
#
# 309 -0.19156101587451493||(8, 53, 41)||พนักงาน
#
# 310 0.5565377745912723||(4, 4, 20)||สา
#
# 311 0.4139588151056769||(3, 5, 11)||ขา
#
# 312 0.7225863667108775||(3, 2, 2)||ฟิว
#
# 313 0.8420515582856642||(3, 1, 2)||เจอร์
#
# 314 0.29587653967833744||(10, 13, 341)||เลือก
#
# 315 -0.34660515529154673||(4, 42, 80)||ผิด
#
# 316 0.783962325375656||(2, 1, 1)||เกือบ2
#
# 317 0.09326714238853163||(5, 18, 14)||อาทิตย์
#
# 318 -0.4200915111044713||(15, 219, 578)||ยัง
#
# 319 -0.01767478021444771||(11, 50, 32)||แก้
#
# 320 -0.11316182160784297||(8, 57, 735)||4g
#
# 321 0.2681441674003447||(1, 2, 18)||รังสิต
#
# 322 0.2512685603003821||(3, 7, 31)||โบนัส
#
# 323 -0.11582468095697558||(4, 32, 544)||ฟรี
#
# 324 0.03999645085246385||(11, 39, 1027)||1
#
# 325 -0.23032664506633593||(2, 27, 313)||แรก
#
# 326 0.052100940523911454||(6, 23, 99)||เข้าไป
#
# 327 -0.010446983593381944||(10, 45, 184)||หา
#
# 328 0.09967974663719752||(4, 13, 107)||สาขา
#
# 329 0.36277149006541226||(5, 4, 169)||ชั้น
#
# 330 -0.6208867772105028||(2, 52, 64)||แก้ไข
#
# 331 1.0||(1, 0, 0)||รอไป
#
# 332 -0.09386688163669506||(11, 68, 684)||2
#
# 333 -0.17791569369068622||(11, 77, 265)||ตาม
#
# 334 1.0||(1, 0, 0)||จี้
#
# 335 -0.04645365852482936||(2, 10, 57)||เรียบร้อย
#
# 336 -0.3266810545810213||(3, 30, 61)||เช็ค
#
# 337 -0.06684438791919728||(16, 85, 490)||ดู
#
# 338 -0.6098225181740693||(1, 30, 55)||สอง
#
# 339 0.48945982108271446||(2, 2, 22)||ล่าง
#
# 340 1.0||(1, 0, 0)||เด๋ว
#
# 341 -0.37241318793821465||(7, 99, 388)||ส่ง
#
# 342 -0.22064340253291462||(1, 8, 29)||หน่วย
#
# 343 0.17588684390654333||(41, 88, 1825)||งาน
#
# 344 0.4546434422431952||(5, 6, 51)||กลาง
#
# 345 -0.5559967751160879||(1, 19, 21)||สาม
#
# 346 0.1341111151376874||(1, 3, 21)||สัปดาห์
#
# 347 0.46777167152866406||(2, 3, 4)||คืบ
#
# 348 -0.4190148060888733||(1, 12, 13)||ใดๆ
#
# 349 -0.07800812904302781||(1, 7, 160)||กลุ่ม
#
# 350 -0.06823312470959353||(8, 41, 81)||เจอ
#
# 351 0.33984195036556913||(2, 4, 9)||สาเหตุ
#
# 352 -0.1603885459008507||(15, 95, 158)||ปัญหา
#
# 353 -0.6101994180060166||(1, 27, 41)||สรุป
#
# 354 0.04540934703347699||(1, 4, 0)||โยน
#
# 355 1.0||(1, 0, 0)||คีบ
#
# 356 -0.018337449687741366||(26, 120, 714)||คน
#
# 357 -0.11582468095697558||(1, 8, 136)||ภายใน
#
# 358 0.21414715564695078||(1, 1, 75)||องค์กร
#
# 359 -0.44299241635182507||(2, 27, 39)||ไม่ใช่
#
# 360 1.0||(1, 0, 0)||เกี่ยง
#
# 361 -0.42664214607874834||(8, 100, 124)||ใคร
#
# 362 -0.4248976133350311||(19, 357, 1471)||เป็น
#
# 363 -0.04719014550460638||(1, 5, 27)||สิ
#
# 364 -0.05096053212333352||(1, 5, 20)||ที่ไหน
#
# 365 -0.19434404236658406||(2, 16, 90)||โอ
#
# 366 0.5974784504061479||(1, 1, 2)||เคร
#
# 367 -0.49325390451515344||(2, 35, 68)||คับ
#
# 368 -0.3307268958028021||(6, 67, 215)||ช่วย
#
# 369 0.2649834711366658||(5, 12, 25)||ขอบ
#
# 370 0.4616397425522295||(1, 1, 14)||มายัง
#
# 371 -0.24186156761843514||(1, 12, 109)||30
#
# 372 0.027386940574793534||(4, 16, 159)||10
#
# 373 0.8111930990125972||(6, 1, 28)||599
#
# 374 -0.08821409071338877||(3, 17, 98)||สี
#
# 375 0.12725091586851545||(1, 3, 25)||เขียว
#
# 376 0.06173859493783791||(2, 7, 92)||ใกล้
#
# 377 0.7083476147446484||(1, 0, 13)||เคียง
#
# 378 0.0534122941432942||(3, 11, 115)||50
#
# 379 -0.07343806702351466||(1, 8, 266)||20
#
# 380 -0.11895224732841969||(2, 13, 100)||ยิ่ง
#
# 381 0.35648128285202096||(20, 35, 180)||ถูก
#
# 382 0.5745941117295121||(2, 1, 27)||ฟ้า
#
# 383 0.1906582724988321||(4, 10, 86)||100
#
# 384 1.0||(1, 0, 0)||590
#
# 385 0.18360168913604058||(1, 3, 1)||fibre
#
# 386 0.48945982108271446||(1, 1, 11)||คำถาม
#
# 387 0.3564812828520211||(4, 7, 36)||ปรับ
#
# 388 -0.3915277208028267||(1, 11, 11)||ขาด
#
# 389 1.0||(1, 0, 0)||อีก4
#
# 390 -0.6511105512839506||(6, 193, 265)||อะไร
#
# 391 0.7625878192796112||(2, 1, 3)||ง้อ
#
# 392 -0.8018520582018742||(3, 188, 122)||ยกเลิก
#
# 393 0.16614074215598806||(26, 68, 680)||ตัว
#
# 394 0.16298306728541134||(3, 8, 75)||จ
#
# 395 -0.2536989090527307||(2, 20, 112)||คุย
#
# 396 -0.17164436652591844||(19, 158, 1401)||กับ
#
# 397 0.06565655368513716||(11, 37, 614)||โดย
#
# 398 -0.059914006590263635||(1, 6, 120)||เสนอ
#
# 399 1.0||(1, 0, 0)||ข้อแม้
#
# 400 0.6124975345512074||(1, 1, 1)||คล้าย
#
# 401 -0.46814337759577235||(1, 16, 32)||ชาว
#
# 402 0.364861782956883||(1, 1, 28)||ขยาย
#
# 403 0.5212436658794396||(1, 0, 29)||ฉลาด
#
# 404 0.18036727928692148||(6, 17, 59)||แถม
#
# 405 0.1870530673692134||(1, 3, 0)||มัด
#
# 406 -0.34816637351053487||(3, 38, 146)||ตอบ
#
# 407 -0.3148310151718838||(1, 10, 25)||สงสัย
#
# 408 -0.45589348056317963||(1, 13, 11)||ทน
#
# 409 -0.5755701675634184||(2, 44, 61)||เรียก
#
# 410 -0.6228365798511949||(1, 83, 280)||ติด
#
# 411 -0.3404010618950073||(1, 20, 155)||ตั้ง
#
# 412 0.2684026625958858||(1, 1, 52)||สบาย
#
# 413 -0.2938616277675727||(2, 22, 103)||เปล่า
#
# 414 0.24871032028835013||(2, 4, 46)||ฝาก
#
# 415 0.9693003027331258||(1, 0, 1)||ข้อคิด
#
# 416 0.9132286184871249||(1, 0, 3)||สัมพันธ์
#
# 417 0.04054317068082011||(4, 16, 29)||ยาก
#
# 418 0.15541356536554823||(1, 1, 118)||รักษา
#
# 419 0.20728353790650592||(5, 13, 58)||tweeted
#
# 420 -0.6020599744205055||(2, 38, 13)||กู
#
# 421 -0.05679481867529124||(1, 5, 11)||เวอร์
#
# 422 0.9404294047077318||(1, 0, 2)||ฟ
#
# 423 1.0||(1, 0, 0)||ลิก
#
# 424 0.25772407815726184||(2, 5, 6)||กระตุก
#
# 425 -0.1419264731983925||(1, 7, 51)||ชัด
#
# 426 1.0||(1, 0, 0)||ระดับultrahd
#
# 427 -0.4242453149862559||(3, 110, 758)||มูฟ
#
# 428 -0.01277059479996773||(2, 10, 564)||เอช
#
# 429 -0.0870780113215872||(5, 28, 145)||ต้องการ
#
# 430 -0.4215871290233173||(5, 96, 417)||หลัง
#
# 431 0.9132286184871249||(1, 0, 3)||เสียใจ
#
# 432 1.0||(1, 0, 0)||กับdtacมา
#
# 433 1.0||(1, 0, 0)||เกือบ10ปี
#
# 434 0.7978450847576598||(2, 0, 16)||แนะ
#
# 435 -0.1304207083380848||(4, 29, 299)||นำ
#
# 436 -0.32187341311444895||(2, 18, 14)||พึ่ง
#
# 437 -0.2295515894683296||(9, 84, 510)||เข้า
#
# 438 -0.31791520203041623||(1, 17, 132)||เร็ว
#
# 439 -0.11178742860218534||(2, 15, 231)||ละเอียด
#
# 440 -0.21479836311050912||(3, 25, 123)||ประมาณ
#
# 441 -0.034714907907236615||(1, 5, 61)||200
#
# 442 0.9693003027331258||(1, 0, 1)||2,400
#
# 443 0.47982123411879085||(1, 1, 12)||กระเป๋า
#
# 444 0.05225929344508019||(9, 34, 219)||เยอะ
#
# 445 -0.3500435845537932||(4, 42, 75)||คง
#
# 446 -0.11421528381968046||(8, 58, 778)||สามารถ
#
# 447 -0.3331618185165256||(9, 94, 219)||เปลี่ยน
#
# 448 -0.025540314779632926||(5, 24, 261)||โม
#
# 449 0.042072518403956045||(5, 18, 381)||ชั่น
#
# 450 0.7231546162950788||(2, 1, 7)||แท
#
# 451 0.9844108604338978||(2, 0, 1)||ครา
#
# 452 0.7416239846018334||(2, 0, 22)||699
#
# 453 0.9693003027331258||(4, 0, 4)||เม็ก
#
# 454 0.3544349110010835||(8, 13, 102)||อัน
#
# 455 0.22186625347619257||(2, 5, 23)||ลิ
#
# 456 0.317810651764995||(2, 4, 16)||มิต
#
# 457 0.7843801195068295||(5, 1, 27)||mb
#
# 458 0.3120311158215203||(1, 2, 9)||เต็มๆ
#
# 459 0.32380832885722866||(1, 2, 7)||ฮะ
#
# 460 0.4411348068228126||(1, 0, 40)||บอล
#
# 461 0.18451938946717383||(1, 2, 47)||ผ่า
#
# 462 -0.3317019620112466||(2, 24, 95)||นท
#
# 463 -0.20046925586226494||(5, 38, 147)||รู
#
# 464 0.19636263899855688||(7, 17, 158)||ไอ
#
# 465 0.9404294047077318||(1, 0, 2)||ลื่นๆ
#
# 466 0.9693003027331258||(1, 0, 1)||กี้
#
# 467 0.9693003027331258||(1, 0, 1)||แท็ค
#
# 468 0.08713560781340177||(1, 3, 61)||สมัย
#
# 469 0.17930848383466125||(2, 5, 52)||สู้
#
# 470 -0.30422727432465796||(1, 9, 13)||ปะ
#
# 471 0.8875570999102018||(1, 0, 4)||d
#
# 472 1.0||(1, 0, 0)||tac
#
# 473 -0.2891092496779679||(1, 8, 1)||3bb
#
# 474 0.9693003027331258||(1, 0, 1)||มา4
#
# 475 -0.2295562051572361||(5, 45, 243)||ลด
#
# 476 0.17098228552369937||(1, 3, 5)||หัน
#
# 477 -0.35751624116239167||(4, 73, 466)||ซิ
#
# 478 0.8632894087266927||(1, 0, 5)||มดี
#
# 479 0.6124975345512074||(1, 1, 1)||เเค่
#
# 480 0.04258907910639735||(1, 4, 4)||2000
#
# 481 -0.14329736536031548||(3, 19, 63)||ใช้ได้
#
# 482 -0.2374651848939775||(13, 117, 569)||มือ
#
# 483 -0.2879249241421154||(10, 107, 495)||ถือ
#
# 484 0.5208480032914299||(1, 1, 8)||พก
#
# 485 0.3028519412089662||(3, 6, 32)||ปล่อย
#
# 486 -0.045275970458018726||(1, 5, 31)||ไวไฟ
#
# 487 0.37748247876412333||(3, 4, 51)||คอม
#
# 488 0.30108053402925633||(1, 2, 11)||ช
#
# 489 -0.6918336875952086||(1, 39, 48)||โหลด
#
# 490 0.004300751774940263||(3, 13, 49)||หนัง
#
# 491 -0.3659719338722071||(7, 82, 199)||เล่น
#
# 492 -0.23665598768846496||(1, 8, 21)||เกมส์
#
# 493 0.01546140589490721||(1, 4, 117)||ยู
#
# 494 0.35024762053789676||(1, 2, 3)||ทูป
#
# 495 -0.05679481867529124||(1, 5, 11)||เฟส
#
# 496 0.2527029500018107||(3, 7, 30)||ไลน์
#
# 497 -0.3702916391768015||(5, 63, 188)||กด
#
# 498 1.0||(1, 0, 0)||ปรึ๊ดๆ
#
# 499 0.364861782956883||(1, 1, 28)||รวดเร็ว
#
# 500 1.0||(1, 0, 0)||ทันใจ
#
# 501 0.43681207401107947||(1, 1, 17)||555
#
# 502 0.9546466215932474||(2, 0, 3)||โปรais
#
# 503 0.47391100711312134||(15, 21, 55)||move
#
# 504 0.7614296472244564||(15, 8, 15)||เอาชนะ
#
# 505 0.14171965812473772||(16, 52, 40)||ทั้งๆ
#
# 506 0.35014967029778976||(18, 30, 221)||ขาย
#
# 507 -0.07734202373168793||(18, 95, 252)||โทรศัพท์
#
# 508 -0.131799778136593||(13, 85, 511)||ทั้ง
#
# 509 0.15369893420052377||(9, 26, 158)||ขนาด
#
# 510 0.8184695728651504||(5, 1, 19)||กรุงเทพ
#
# 511 0.9693003027331258||(4, 0, 4)||ตจว.คง
#
# 512 0.2194139769494526||(5, 11, 121)||พูด
#
# 513 0.5762818926675364||(2, 2, 7)||ยอมรับ
#
# 514 0.3895456391578219||(5, 9, 16)||ไว
#
# 515 0.30972969206755335||(5, 8, 108)||สุดๆ
#
# 516 0.3575461251229868||(2, 4, 4)||หลังๆ
#
# 517 0.021320079284913602||(4, 16, 273)||เริ่ม
#
# 518 0.03230601808284599||(2, 8, 49)||ขั้น
#
# 519 0.4496039352967426||(3, 4, 23)||ง่ายๆ
#
# 520 -0.12929154883692137||(2, 14, 128)||ทำให้
#
# 521 0.16668600564271244||(2, 6, 13)||ยุ่ง
#
# 522 0.9693003027331258||(2, 0, 2)||พยาม
#
# 523 0.8292780797431875||(2, 0, 13)||ยาม
#
# 524 0.6318393589617761||(24, 9, 274)||ที่สุด
#
# 525 0.004431405306258751||(3, 13, 42)||คุณภาพ
#
# 526 -0.2576951937566721||(3, 24, 36)||เข้าใจ
#
# 527 0.5671520456293592||(6, 5, 45)||9
#
# 528 -0.16638601598149594||(2, 15, 99)||พิมพ์
#
# 529 0.6707284690053994||(2, 0, 31)||ครอบคลุม
#
# 530 0.3562747400257021||(4, 5, 91)||ทั่ว
#
# 531 0.0668366834817276||(3, 10, 172)||ประเทศ
#
# 532 -0.0063067043557886076||(2, 9, 145)||คลื่น
#
# 533 0.1739208058495053||(6, 12, 316)||สำหรับ
#
# 534 0.9132286184871249||(2, 0, 6)||core
#
# 535 0.9693003027331258||(2, 0, 2)||competency
#
# 536 0.38709900897152444||(4, 6, 45)||อื่นๆ
#
# 537 0.4476026316104759||(2, 3, 8)||แข่ง
#
# 538 -0.32360092310463934||(3, 37, 170)||รู้
#
# 539 0.5565377745912723||(1, 1, 5)||ยุ่
#
# 540 -0.11510337659020115||(1, 7, 82)||เจ้าของ
#
# 541 -0.6490289112980232||(1, 76, 216)||นั้น
#
# 542 0.9404294047077318||(1, 0, 2)||สมอง
#
# 543 0.2842584372225626||(2, 0, 159)||เก่ง
#
# 544 -0.13925643881167332||(1, 6, 9)||ตาย
#
# 545 0.6575077789926518||(3, 2, 13)||ก็ตาม
#
# 546 0.9693003027331258||(1, 0, 1)||ยถากรรม
#
# 547 0.2334115079289275||(4, 9, 72)||เมือง
#
# 548 0.9546466215932474||(2, 0, 3)||เมือ
#
# 549 0.7731273663148577||(2, 1, 2)||งก้
#
# 550 -0.5186251472382221||(3, 44, 17)||กาก
#
# 551 0.6935673585393792||(4, 3, 3)||ตจว
#
# 552 -0.16008912459847643||(4, 26, 68)||บาง
#
# 553 -0.09873963339627954||(2, 11, 21)||แทบ
#
# 554 0.371513952244076||(2, 3, 27)||ไร้
#
# 555 0.3081370171664939||(19, 35, 276)||น
#
# 556 -0.3004429124731453||(10, 112, 513)||ทุก
#
# 557 -0.12468168362400224||(2, 16, 240)||พื้นที่
#
# 558 0.2529151465222633||(2, 5, 8)||มั่ว
#
# 559 0.5086018276674807||(3, 4, 6)||ลา
#
# 560 0.5681403543848249||(1, 0, 24)||แบ่ง
#
# 561 0.28739760937365816||(1, 1, 46)||ทางการ
#
# 562 0.12973963506055808||(2, 6, 47)||ตลาด
#
# 563 0.05327380889007915||(6, 23, 89)||หนึ่ง
#
# 564 0.9132286184871249||(1, 0, 3)||truetrue
#
# 565 -0.5386731017189865||(2, 89, 369)||นี่
#
# 566 0.19067079057989345||(1, 2, 44)||trueid
#
# 567 0.12367993128293113||(4, 10, 240)||12
#
# 568 0.343241120630092||(1, 2, 4)||พ่วง
#
# 569 -0.11238868798739624||(2, 13, 115)||เช่น
#
# 570 0.6124975345512074||(1, 1, 1)||truevision
#
# 571 0.1341111151376874||(1, 3, 21)||แพ้
#
# 572 0.2523684190788804||(2, 4, 44)||ใด
#
# 573 -0.28871981228378096||(4, 34, 40)||เห
#
# 574 -0.15194583662146313||(1, 6, 2)||ตุ
#
# 575 0.14380169660862446||(1, 3, 16)||บบ
#
# 576 0.343241120630092||(1, 2, 4)||แง่
#
# 577 -0.6047156761709356||(1, 25, 34)||call
#
# 578 -0.5689242492891803||(1, 24, 44)||center
#
# 579 0.47055492788012415||(1, 1, 13)||เอาใจ
#
# 580 0.10911140879076328||(2, 6, 76)||ใส่
#
# 581 -0.20151923076014958||(2, 17, 109)||ทำการ
#
# 582 0.7504373947776715||(2, 0, 21)||ท่อง
#
# 583 0.9693003027331258||(1, 0, 1)||ตำรา
#
# 584 -0.014443804287379175||(2, 10, 483)||แบ
#
# 585 -0.3293624497067476||(1, 11, 34)||บท
#
# 586 0.14356244394369772||(3, 5, 278)||ด้าน
#
# 587 0.3651552773622082||(1, 2, 1)||พอๆ
#
# 588 0.2695136784375506||(6, 11, 140)||ต่าง
#
# 589 -0.13068150114052263||(2, 12, 29)||จังหวัด
#
# 590 0.1770674293141221||(1, 3, 3)||อร์เน็ท
#
# 591 0.25583285624327046||(3, 4, 134)||ไฟ
#
# 592 0.9132286184871249||(1, 0, 3)||ไฟเบอร์
#
# 593 0.2606050546357777||(4, 5, 184)||ประสบการณ์
#
# 594 -0.5693175767469225||(4, 71, 39)||ช้า
#
# 595 0.9693003027331258||(1, 0, 1)||lost
#
# 596 0.6779292040676349||(1, 0, 15)||signal
#
# 597 -0.183413171552984||(1, 8, 53)||ขณะ
#
# 598 0.5831783046344657||(2, 2, 6)||สิบ
#
# 599 0.7594628002539004||(1, 0, 10)||vpn
#
# 600 -0.3915277208028267||(2, 22, 22)||หลุด
#
# 601 0.22544683926310763||(3, 8, 12)||ช่าง
#
# 602 -0.035829244081788995||(2, 10, 114)||สิทธิ
#
# 603 0.01225041188211768||(2, 8, 327)||พิเศษ
#
# 604 -0.5131792946571432||(1, 24, 71)||พวก
#
# 605 0.1906582724988321||(2, 5, 43)||เซ
#
# 606 0.8632894087266927||(1, 0, 5)||เรเนด
#
# 607 -0.1423473471301727||(4, 27, 159)||บัตร
#
# 608 -0.5034469438830613||(1, 21, 55)||ค่อย
#
# 609 0.9404294047077318||(1, 0, 2)||นๆ
#
# 610 0.19572107094344315||(6, 14, 162)||ท่าน
#
# 611 0.282919777605122||(2, 3, 62)||แลก
#
# 612 0.544109864401379||(2, 2, 12)||ห่าง
#
# 613 0.03841393077282564||(1, 4, 11)||เรื่อยๆ
#
# 614 0.15998604428702975||(1, 3, 9)||หรอก
#
# 615 0.6018969344061342||(7, 1, 127)||อันดับ
#
# 616 0.9693003027331258||(5, 0, 5)||nperf
#
# 617 0.5898908605621356||(3, 2, 27)||spoil
#
# 618 0.5893500635159308||(3, 0, 66)||แอป
#
# 619 0.7083476147446484||(1, 0, 13)||พลิ
#
# 620 0.9132286184871249||(1, 0, 3)||เคชั่
#
# 621 0.6932801793805103||(6, 3, 31)||นที่
#
# 622 0.3998735374340406||(7, 3, 256)||ทดสอบ
#
# 623 0.9045080173477101||(3, 0, 10)||ดาวน์โหลด
#
# 624 -0.2002883106613362||(6, 62, 649)||ผู้
#
# 625 0.7830055454138395||(4, 0, 35)||มากมาย
#
# 626 -0.20676857834066723||(13, 113, 729)||ทาง
#
# 627 -0.02392076564544652||(3, 14, 63)||ยก
#
# 628 0.10275089956173894||(2, 4, 242)||ประเทศไทย
#
# 629 -0.0055007776597879995||(2, 9, 185)||ผล
#
# 630 0.9693003027331258||(1, 0, 1)||kpi
#
# 631 0.06370555340142647||(1, 3, 103)||สำคัญ
#
# 632 0.9693003027331258||(1, 0, 1)||5.5
#
# 633 0.41451864768691066||(1, 1, 20)||แสน
#
# 634 0.09360933202175992||(2, 7, 22)||ครึ่ง
#
# 635 -0.014282091624290278||(1, 5, 245)||2018
#
# 636 0.1733351485814609||(1, 2, 53)||แต่ละ
#
# 637 0.8875570999102018||(1, 0, 4)||success
#
# 638 0.7978450847576598||(1, 0, 8)||ratio
#
# 639 0.23190306070748395||(1, 2, 28)||อัตรา
#
# 640 -0.13247228238437317||(2, 24, 593)||ข้อมูล
#
# 641 0.023975671108912976||(1, 4, 54)||สำเร็จ
#
# 642 0.9693003027331258||(1, 0, 1)||88.16
#
# 643 -0.2589493139953014||(5, 87, 1027)||%
#
# 644 0.7246039588180919||(1, 0, 12)||download
#
# 645 0.9693003027331258||(2, 0, 2)||bitrate
#
# 646 0.633123376061418||(2, 1, 18)||เฉลี่ย
#
# 647 0.9693003027331258||(1, 0, 1)||15.73
#
# 648 0.8185287869513556||(3, 0, 21)||s
#
# 649 0.9404294047077318||(1, 0, 2)||upload
#
# 650 0.8632894087266927||(1, 0, 5)||อัพโหลด
#
# 651 0.9693003027331258||(1, 0, 1)||8.41
#
# 652 0.4411348068228126||(1, 0, 40)||latency
#
# 653 0.3689643419408242||(1, 0, 54)||สนอง
#
# 654 -0.059839628498605996||(1, 5, 7)||ปิง
#
# 655 0.9693003027331258||(1, 0, 1)||52.50
#
# 656 0.8185287869513557||(1, 0, 7)||ms
#
# 657 0.23508029560957905||(1, 2, 27)||streaming
#
# 658 0.4018347975182508||(2, 0, 94)||ประสิทธิภาพ
#
# 659 -0.06997032912629693||(1, 6, 92)||เนื่อง
#
# 660 0.9693003027331258||(1, 0, 1)||71.26
#
# 661 0.9693003027331258||(1, 0, 1)||browsing
#
# 662 -0.14300145125945352||(1, 7, 50)||เว็บ
#
# 663 0.9693003027331258||(1, 0, 1)||53.18
#
# 664 0.9693003027331257||(3, 0, 3)||ookla
#
# 665 0.9693003027331258||(1, 0, 1)||speedtestttt
#
# 666 -0.05404486294012766||(1, 5, 15)||ฝั่ง
#
# 667 0.19764507265297837||(2, 2, 169)||รางวัล
#
# 668 0.9404294047077318||(2, 0, 4)||speedtest
#
# 669 -0.06455286139422206||(2, 12, 212)||โลก
#
# 670 0.1752513527934292||(4, 10, 111)||ล้าน
#
# 671 0.9693003027331258||(1, 0, 1)||190
#
# 672 -0.5003571612220833||(3, 66, 191)||ยอด
#
# 673 -0.32475668049663586||(1, 15, 96)||5
#
# 674 -0.20741133894411856||(1, 7, 9)||คนใช้
#
# 675 0.28579356516929266||(3, 4, 107)||ประจำ
#
# 676 0.9132286184871249||(1, 0, 3)||2.8
#
# 677 0.021205300514594735||(2, 7, 485)||ร่วม
#
# 678 -0.3623415414683228||(4, 67, 375)||ม
#
# 679 -0.29818796045096846||(1, 15, 117)||8
#
# 680 -0.5322797826139342||(3, 56, 82)||ที
#
# 681 0.9693003027331258||(1, 0, 1)||source
#
# 682 0.26919899675408676||(52, 50, 2758)||https
#
# 683 0.8875570999102018||(1, 0, 4)||droidsans.com
#
# 684 0.9404294047077318||(1, 0, 2)||vs
#
# 685 0.7594628002539004||(1, 0, 10)||award
#
# 686 -0.04148936832783138||(1, 5, 40)||นั่ง
#
# 687 0.5831783046344657||(1, 1, 3)||นว
#
# 688 0.2681441674003447||(1, 2, 18)||นคร
#
# 689 -0.5547394444497217||(2, 42, 66)||เนต
#
# 690 0.10452673349865166||(1, 3, 42)||ชิ
#
# 691 -0.22823286039466126||(2, 21, 172)||บ
#
# 692 -0.8057088884127905||(1, 62, 37)||หาย
#
# 693 0.2713921794630342||(1, 1, 51)||เขต
#
# 694 0.2694833103469128||(6, 10, 174)||เท่านั้น
#
# 695 -0.4378133352874704||(2, 25, 24)||ล่ะ
#
# 696 -0.39103715931055627||(2, 34, 157)||ลง
#
# 697 0.9693003027331258||(1, 0, 1)||ทันตา
#
# 698 0.8403134587661258||(1, 0, 6)||6,990
#
# 699 0.9404294047077318||(1, 0, 2)||โปรtruemove
#
# 700 0.6123322610610007||(2, 1, 21)||package
#
# 701 0.13935255282499556||(2, 0, 390)||3,990
#
# 702 0.038784496408754664||(3, 11, 224)||ธ.ค
#
# 703 0.23539167795261223||(5, 7, 248)||2561
#
# 704 0.058165789356751256||(1, 2, 249)||–
#
# 705 0.08563581202434992||(2, 6, 126)||15
#
# 706 0.28047080305479133||(2, 0, 162)||ม.ค
#
# 707 0.2724042658963019||(2, 1, 135)||2562
#
# 708 0.11806253017827516||(3, 10, 25)||เพ
#
# 709 0.05116269638780281||(4, 14, 269)||ค
#
# 710 0.0935310405549407||(1, 0, 306)||fun
#
# 711 -0.5814556797096411||(3, 83, 173)||ชำระ
#
# 712 0.012195942439972702||(2, 8, 329)||ล่วง
#
# 713 0.1763163813763738||(2, 0, 295)||1,000
#
# 714 0.020794772251940544||(2, 8, 143)||ส่วนลด
#
# 715 0.7083476147446484||(1, 0, 13)||hot
#
# 716 0.8875570999102018||(1, 0, 4)||deal
#
# 717 -0.37278408146702335||(1, 10, 5)||บ่น
#
# 718 -0.05827748032462436||(2, 10, 18)||จัง
#
# 719 -0.1722296061669396||(6, 38, 27)||อย่า
#
# 720 1.0||(1, 0, 0)||งงู้น
#
# 721 -0.4077336867563559||(3, 32, 8)||แย่
#
# 722 0.9693003027331258||(1, 0, 1)||งงี้
#
# 723 -0.3947672885794118||(1, 11, 10)||เนี่ย
#
# 724 -0.21207083756421227||(1, 7, 7)||ซ้ำ
#
# 725 0.2860237360498475||(1, 2, 14)||1mbps
#
# 726 -0.36239380619448425||(2, 27, 105)||ปีด
#
# 727 -0.5152184828784039||(1, 19, 36)||เกม
#
# 728 0.2860237360498475||(1, 2, 14)||หน่วง
#
# 729 -0.09819903857506417||(1, 11, 375)||แพ็คเกจ
#
# 730 -0.0963807090392909||(2, 11, 25)||แหละ
#
# 731 -0.3973716107436017||(1, 14, 42)||ยืนยัน
#
# 732 0.4084801002040276||(355, 114, 13398)||#
#
# 733 0.9693003027331258||(1, 0, 1)||ติ่ง
#
# 734 -0.21157086519744622||(2, 17, 95)||กำลัง
#
# 735 1.0||(1, 0, 0)||aisแม่
#
# 736 0.17000852623161822||(3, 9, 16)||ง
#
# 737 0.6282911719153331||(1, 1, 0)||เหี้
#
# 738 0.716142537666317||(3, 2, 3)||สอน
#
# 739 0.7681410343184284||(3, 1, 12)||เทคนิค
#
# 740 1.0||(2, 0, 0)||ซอยผม
#
# 741 1.0||(2, 0, 0)||บ๊
#
# 742 0.5797095888921804||(4, 4, 13)||อบ
#
# 743 0.7960916018777313||(3, 1, 8)||ทุย
#
# 744 0.1085164501244242||(2, 6, 77)||ต่ำ
#
# 745 0.1273220124778535||(2, 1, 369)||one
#
# 746 1.0||(2, 0, 0)||length
#
# 747 1.0||(1, 0, 0)||bob
#
# 748 1.0||(1, 0, 0)||ปรมาจารย์
#
# 749 0.2990672648099667||(3, 0, 222)||by
#
# 750 1.0||(1, 0, 0)||อ่าง
#
# 751 1.0||(1, 0, 0)||ศิลา
#
# 752 0.5831783046344657||(1, 1, 3)||ชลบุรี
#
# 753 0.8875570999102018||(1, 0, 4)||อนุ
#
# 754 0.6282911719153331||(1, 1, 0)||ญาติ
#
# 755 1.0||(2, 0, 0)||อาจารย์
#
# 756 0.8238683724132932||(4, 0, 27)||channel
#
# 757 0.9693003027331258||(1, 0, 1)||วิทยาทาน
#
# 758 0.2224372641366662||(6, 2, 583)||ชม
#
# 759 0.7772231529283052||(20, 0, 181)||โฟกัส
#
# 760 0.7154816982972965||(18, 0, 226)||พลอย
#
# 761 0.7371350749575762||(27, 0, 304)||ใส
#
# 762 0.41054304444404316||(3, 0, 136)||ฉลอง
#
# 763 0.7687079430561661||(2, 0, 19)||อันดับ1ใน
#
# 764 0.46552536194786315||(4, 0, 145)||เอเชีย
#
# 765 0.5299932389900449||(4, 0, 112)||แปซิฟิก
#
# 766 0.4910751831898387||(4, 1, 109)||ซ้อน
#
# 767 0.3415275697136742||(3, 2, 126)||กิจกรรม
#
# 768 -0.3000879229155835||(7, 66, 152)||ปิด
#
# 769 0.29386977109407336||(2, 1, 120)||โรง
#
# 770 0.43356283256727635||(4, 0, 165)||ภาพยนตร์
#
# 771 0.3374200347320143||(2, 0, 124)||4dx
#
# 772 0.46043384035809043||(4, 0, 148)||aquaman
#
# 773 0.6707284690053994||(2, 0, 31)||meet
#
# 774 0.04532162181272496||(5, 10, 1663)||&
#
# 775 0.6852862267506707||(2, 0, 29)||greet
#
# 776 0.656776355704504||(2, 0, 33)||af
#
# 777 0.42338852364367796||(1, 0, 43)||ชิด
#
# 778 0.5821063682687629||(3, 0, 68)||13
#
# 779 0.07884990875868156||(4, 12, 292)||ธันวาคม
#
# 780 1.0||(1, 0, 0)||2561ที่
#
# 781 0.22502446808317686||(2, 2, 139)||พา
#
# 782 0.08037074040322478||(2, 4, 335)||รา
#
# 783 0.539041566879283||(2, 0, 54)||กอน
#
# 784 0.5511416617159746||(4, 3, 42)||ซี
#
# 785 0.6583475816048254||(3, 1, 31)||นี
#
# 786 0.6928046810715266||(2, 0, 28)||เพล็
#
# 787 0.6928046810715266||(2, 0, 28)||กซ์
#
# 788 0.6894488246153492||(12, 1, 153)||truemoveh4gno1asiapacific
#
# 789 0.7718398804875564||(9, 0, 84)||กัส
#
# 790 0.5930399394777346||(12, 0, 260)||true5gleader
#
# 791 -0.080266514822167||(9, 55, 718)||truemoveh
#
# 792 0.7958340626640994||(10, 0, 81)||ผู้นำ5gตัว
#
# 793 -0.02398486549307||(11, 52, 424)||จริง
#
# 794 0.7671514865184086||(12, 0, 115)||4gที่
#
# 795 0.29896746787003364||(56, 60, 2267)||@
#
# 796 0.7083476147446484||(1, 0, 13)||japaikin
#
# 797 0.6928046810715266||(1, 0, 14)||coffee
#
# 798 0.4291431483963529||(1, 0, 42)||เมนู
#
# 799 0.7083476147446484||(1, 0, 13)||1แถม1
#
# 800 0.3004432646387635||(5, 8, 118)||สิทธิ์
#
# 801 0.13976213188154143||(1, 3, 18)||black
#
# 802 0.32827664384446553||(3, 5, 48)||card
#
# 803 0.7083476147446484||(1, 0, 13)||frosty
#
# 804 0.7083476147446484||(1, 0, 13)||วิป
#
# 805 0.7083476147446484||(1, 0, 13)||ครีม
#
# 806 0.7136847392710263||(3, 0, 38)||สดใส
#
# 807 0.35947885478080294||(1, 1, 29)||ช็อค
#
# 808 0.7083476147446484||(1, 0, 13)||เบลเยียม
#
# 809 0.6928046810715266||(1, 0, 14)||145
#
# 810 0.4534846340496352||(4, 2, 106)||฿
#
# 811 0.4530560920885161||(2, 2, 30)||ต้อ
#
# 812 0.7083476147446484||(1, 0, 13)||นรับค
#
# 813 0.12902022802090274||(1, 2, 87)||ริ
#
# 814 0.7083476147446484||(1, 0, 13)||สมาส
#
# 815 0.7083476147446484||(1, 0, 13)||strawberry
#
# 816 0.7083476147446484||(1, 0, 13)||chocolate
#
# 817 0.7083476147446484||(1, 0, 13)||ช็อคฯ
#
# 818 0.600560061289726||(2, 0, 42)||นม
#
# 819 0.09459041386607288||(1, 3, 52)||ตอ
#
# 820 0.7083476147446484||(1, 0, 13)||รเบ
#
# 821 0.41451864768691066||(1, 1, 20)||อรี่
#
# 822 0.8672414450845||(6, 0, 29)||หวาน
#
# 823 0.6122047774217003||(1, 0, 20)||อม
#
# 824 0.7083476147446484||(1, 0, 13)||เปรี้ยว
#
# 825 0.7083476147446484||(1, 0, 13)||mocha
#
# 826 0.7083476147446484||(1, 0, 13)||brown
#
# 827 0.2681441674003447||(1, 2, 18)||มอ
#
# 828 0.5299932389900449||(1, 0, 28)||เจ้ม
#
# 829 0.5299932389900449||(1, 0, 28)||จ้น
#
# 830 0.7781809468387362||(2, 0, 18)||ปั่น
#
# 831 0.7083476147446484||(1, 0, 13)||หอมๆ
#
# 832 0.4123301833747483||(1, 0, 45)||อร่อย
#
# 833 0.7083476147446484||(1, 0, 13)||aroii
#
# 834 0.539041566879283||(1, 0, 27)||siam
#
# 835 0.7083476147446484||(1, 0, 13)||square
#
# 836 -0.09544868445969829||(1, 11, 389)||รี
#
# 837 0.13976213188154143||(1, 3, 18)||โน
#
# 838 0.7083476147446484||(1, 0, 13)||เวท
#
# 839 0.29174847885544164||(49, 37, 2575)||t.co
#
# 840 0.7083476147446484||(1, 0, 13)||0z15qhxovq
#
# 841 1.0||(1, 0, 0)||ฝืน
#
# 842 -0.37445977170716505||(3, 66, 447)||เอง
#
# 843 1.0||(1, 0, 0)||กิตติคุณ
#
# 844 -0.13497660517414706||(1, 13, 335)||ลูก
#
# 845 -0.08708604896877929||(1, 11, 437)||ค้า
#
# 846 0.9546466215932474||(2, 0, 3)||สารคดี
#
# 847 0.9132286184871249||(1, 0, 3)||โรงงาน
#
# 848 0.35646747055964123||(1, 0, 57)||ผลิต
#
# 849 0.9693003027331258||(2, 0, 2)||ไม้
#
# 850 1.0||(1, 0, 0)||เบสบอล
#
# 851 0.7147618299009589||(10, 0, 126)||hd
#
# 852 1.0||(1, 0, 0)||ctbน้า
#
# 853 1.0||(1, 0, 0)||หงื
#
# 854 -0.3157682296157253||(1, 9, 9)||สาร
#
# 855 0.9693003027331258||(1, 0, 1)||คดี
#
# 856 0.3881083150599288||(1, 1, 24)||ใหม่ๆ
#
# 857 0.2429079332798074||(5, 8, 197)||ช่อง
#
# 858 0.4411348068228126||(1, 0, 40)||bit.ly
#
# 859 1.0||(1, 0, 0)||2pxypva
#
# 860 0.6421613442042063||(7, 5, 31)||ติดตาม
#
# 861 0.4447858205692684||(1, 1, 16)||น่ะ
#
# 862 -0.10348881278853195||(4, 22, 27)||ชอบ
#
# 863 0.2724011702375306||(1, 2, 17)||วิชั่น
#
# 864 0.8875570999102018||(1, 0, 4)||เคเบิ้
#
# 865 1.0||(1, 0, 0)||ลดังๆ
#
# 866 1.0||(1, 0, 0)||fox
#
# 867 1.0||(1, 0, 0)||movies
#
# 868 1.0||(1, 0, 0)||axn
#
# 869 1.0||(1, 0, 0)||hob
#
# 870 1.0||(1, 0, 0)||nba
#
# 871 0.544109864401379||(1, 1, 6)||ture
#
# 872 0.20927532448250089||(1, 2, 36)||x
#
# 873 1.0||(1, 0, 0)||ztye
#
# 874 1.0||(1, 0, 0)||discovry
#
# 875 0.9404294047077318||(1, 0, 2)||national
#
# 876 1.0||(1, 0, 0)||geographic
#
# 877 1.0||(3, 0, 0)||explore
#
# 878 1.0||(2, 0, 0)||wild
#
# 879 0.4008789671458633||(1, 1, 22)||life
#
# 880 0.2563472854622158||(23, 39, 729)||เปิด
#
# 881 -0.250232791295363||(1, 13, 123)||เฉพาะ
#
# 882 0.04688192144576053||(1, 2, 320)||สมาชิก
#
# 883 0.9132286184871249||(1, 0, 3)||ลิ้งค์
#
# 884 0.5299932389900449||(1, 0, 28)||ป้องกัน
#
# 885 0.9693003027331258||(1, 0, 1)||ลิขสิทธิ์
#
# 886 0.1930238679493602||(1, 0, 132)||cherprangfc
#
# 887 0.27319048706331944||(1, 0, 84)||event
#
# 888 0.3173867905942429||(24, 3, 1540)||5g
#
# 889 0.07166478044720741||(1, 0, 409)||digital
#
# 890 0.08756495244845212||(1, 0, 329)||thailand
#
# 891 0.34424267220814936||(3, 3, 96)||ศุกร์
#
# 892 0.11289152771558318||(2, 4, 212)||14
#
# 893 0.12705065801106388||(1, 1, 153)||สถาน
#
# 894 0.11712426517185062||(1, 0, 238)||รน
#
# 895 0.13346210070861197||(1, 0, 205)||ดิ้ง
#
# 896 0.18686699418188646||(2, 1, 229)||ช้อป
#
# 897 0.12210685760018908||(1, 0, 227)||ไอคอน
#
# 898 0.2029496576290252||(2, 0, 248)||สยาม
#
# 899 0.2168910345090781||(1, 0, 114)||11.15
#
# 900 0.12864941871405916||(2, 3, 238)||ได้ที่
#
# 901 0.27084698509525457||(1, 0, 85)||ar0fkivogy
#
# 902 0.17881273941462877||(1, 0, 145)||cherprangbnk48
#
# 903 0.27084698509525457||(1, 0, 85)||xbyn5gx0ci
#
# 904 0.7718398804875565||(3, 0, 28)||psk48official
#
# 905 0.7718398804875565||(3, 0, 28)||อุ๋ง
#
# 906 0.606326514282666||(22, 0, 451)||showcase
#
# 907 0.3732453906569139||(4, 4, 106)||ณ
#
# 908 0.14601170251713308||(3, 0, 554)||iconsiam
#
# 909 0.2548675261744045||(3, 6, 64)||ห้า
#
# 910 0.6583475816048254||(3, 1, 31)||โมง
#
# 911 0.20586973746422652||(5, 9, 229)||เช้า
#
# 912 0.41557558243211923||(3, 4, 35)||งับ
#
# 913 0.2788196190499552||(3, 0, 245)||ornbnk48
#
# 914 0.5685495770829477||(25, 0, 599)||bnk48
#
# 915 0.7718398804875565||(3, 0, 28)||psk48
#
# 916 0.5647529376692421||(3, 0, 73)||goอร
#
# 917 0.7718398804875565||(3, 0, 28)||zpqdyjqr1y
#
# 918 0.25499159096350976||(7, 10, 291)||พี่
#
# 919 1.0||(1, 0, 0)||อ้น
#
# 920 0.9693003027331258||(1, 0, 1)||พิธีกร
#
# 921 -0.4439472986988229||(1, 25, 123)||สาย
#
# 922 0.9693003027331258||(1, 0, 1)||ฮา
#
# 923 0.521530391705444||(25, 6, 598)||แท้
#
# 924 0.47982123411879085||(1, 1, 12)||เหนือ
#
# 925 -0.18764057571446366||(1, 9, 81)||สิ่ง
#
# 926 1.0||(1, 0, 0)||วอแว
#
# 927 0.8875570999102018||(1, 0, 4)||ควงแขน
#
# 928 0.2724011702375306||(1, 2, 17)||โอ้
#
# 929 1.0||(1, 0, 0)||อ้อน
#
# 930 1.0||(1, 0, 0)||ชิป่
#
# 931 -0.26556495130295965||(1, 8, 9)||ะ
#
# 932 1.0||(2, 0, 0)||เจมส์
#
# 933 0.8403134587661258||(2, 0, 12)||จิ
#
# 934 0.9693003027331258||(1, 0, 1)||jirayu_jj
#
# 935 1.0||(1, 0, 0)||jamesjigallery
#
# 936 1.0||(1, 0, 0)||mario_mm38
#
# 937 1.0||(1, 0, 0)||ohnsri1000
#
# 938 1.0||(1, 0, 0)||vyyrthqkp9
#
# 939 -0.04393923912050398||(1, 5, 34)||จำ
#
# 940 0.23490494604303735||(2, 3, 92)||ขับ
#
# 941 0.6914769237538357||(3, 2, 7)||หลง
#
# 942 -0.5619633960407188||(3, 70, 130)||กลับ
#
# 943 0.7594628002539004||(1, 0, 10)||ทุ่ง
#
# 944 0.036865071516561||(1, 4, 14)||นา
#
# 945 0.9693003027331258||(1, 0, 1)||ต้นไม้
#
# 946 1.0||(1, 0, 0)||แมพ
#
# 947 -0.2798066507648805||(1, 8, 4)||หมุน
#
# 948 0.01946654488615646||(4, 16, 322)||จ้า
#
# 949 0.26791225170350097||(2, 5, 2)||าาา
#
# 950 0.4530560920885161||(1, 1, 15)||ตำแหน่ง
#
# 951 0.7978450847576598||(1, 0, 8)||จอด
#
# 952 -0.14842348343995784||(2, 13, 49)||ข้าง
#
# 953 -0.1360111111452051||(1, 6, 11)||คนละ
#
# 954 -0.18149173062885954||(1, 7, 22)||อำเภอ
#
# 955 0.3575461251229868||(1, 2, 2)||ดีใจ
#
# 956 1.0||(1, 0, 0)||เย้
#
# 957 -0.42878667280378846||(6, 140, 713)||!
#
# 958 1.0||(1, 0, 0)||vlgvxmdths
#
# 959 1.0||(4, 0, 0)||room
#
# 960 0.6295606945910929||(4, 2, 37)||service
#
# 961 0.8875570999102019||(6, 0, 24)||news
#
# 962 1.0||(1, 0, 0)||081261
#
# 963 0.9693003027331258||(4, 0, 4)||แต้ว
#
# 964 1.0||(2, 0, 0)||ณฐพร
#
# 965 0.3733269833971064||(2, 0, 106)||ยิ้ม
#
# 966 -0.26829611774614154||(1, 8, 8)||รับคำ
#
# 967 0.18316833550381414||(6, 14, 193)||ภาพ
#
# 968 0.9844108604338978||(2, 0, 1)||ทริป
#
# 969 0.544109864401379||(1, 1, 6)||ทะเล
# 970 0.9266294378999714||(2, 0, 5)||ภูเก็ต
#
# 971 -0.4704781548870556||(1, 15, 23)||เพิ่ง
#
# 972 1.0||(1, 0, 0)||ควง
#
# 973 -0.13483153409993784||(2, 14, 116)||ต้น
#
# 974 -0.45470448304497996||(1, 14, 20)||อา
#
# 975 1.0||(1, 0, 0)||ชว์
#
# 976 1.0||(1, 0, 0)||กระชับ
#
# 977 0.45119178477237115||(9, 9, 137)||รัก
#
# 978 0.5831783046344657||(1, 1, 3)||เกาะ
#
# 979 1.0||(1, 0, 0)||ท่อน
#
# 980 1.0||(1, 0, 0)||เซต
#
# 981 0.4023311663380478||(4, 5, 62)||สวย
#
# 982 0.4889553266083066||(1, 0, 33)||ชุด
#
# 983 0.6124975345512074||(1, 1, 1)||ว่าย
#
# 984 0.16630863069956275||(3, 7, 121)||น้ำ
#
# 985 0.0512397807694226||(1, 3, 141)||โชว์
#
# 986 0.9404294047077318||(1, 0, 2)||เซ็กซี่
#
# 987 1.0||(1, 0, 0)||สวี
#
# 988 0.7083476147446484||(2, 0, 26)||ท
#
# 989 0.7373697242022406||(12, 3, 84)||คู่
#
# 990 0.8875570999102018||(1, 0, 4)||อวด
#
# 991 0.9002098760543301||(2, 0, 7)||แฟนๆ
#
# 992 0.9266294378999714||(2, 0, 5)||เพียบ
#
# 993 0.9132286184871249||(1, 0, 3)||ณฐ
#
# 994 0.8080545978032916||(2, 0, 15)||พร
#
# 995 1.0||(1, 0, 0)||taewaew_natapohn
#
# 996 1.0||(2, 0, 0)||roomservicenews
#
# 997 1.0||(2, 0, 0)||trueinsidehd
#
# 998 0.7231546162950788||(2, 1, 7)||truevisions
#
# 999 -0.007357748636206642||(2, 9, 106)||รายการ
#
# 1000 0.2489904894338491||(2, 3, 82)||ข่าว
#
# 1001 0.34961791454711094||(2, 3, 34)||บันเทิง
#
# 1002 0.7266886168206373||(8, 0, 95)||inside
#
# 1003 0.9198802249828025||(4, 0, 11)||good
#
# 1004 0.9066725162525426||(4, 0, 13)||morning
#
# 1005 0.9844108604338978||(2, 0, 1)||07.30
#
# 1006 0.9693003027331258||(2, 0, 2)||entertainment
#
# 1007 0.5831783046344657||(2, 2, 6)||day
#
# 1008 0.9693003027331258||(2, 0, 2)||12.00
#
# 1009 0.17865699973249602||(2, 6, 5)||เสาร์
#
# 1010 0.7878903406924757||(2, 0, 17)||10.00
#
# 1011 1.0||(2, 0, 0)||tonight
#
# 1012 1.0||(2, 0, 0)||19.55
#
# 1013 1.0||(2, 0, 0)||19.25
#
# 1014 1.0||(2, 0, 0)||22.25
#
# 1015 0.9693003027331258||(2, 0, 2)||visions
#
# 1016 0.12235020796987077||(4, 8, 377)||หมายเลข
#
# 1017 1.0||(2, 0, 0)||113
#
# 1018 1.0||(2, 0, 0)||335
#
# 1019 0.9693003027331258||(2, 0, 2)||sd
#
# 1020 0.7004899392968293||(2, 0, 27)||38
#
# 1021 0.9546466215932474||(2, 0, 3)||fanpage
#
# 1022 0.4043192647302009||(2, 1, 68)||facebook
#
# 1023 0.748657994401449||(5, 0, 53)||cussaifamily
#
# 1024 0.5681403543848249||(1, 0, 24)||ready
#
# 1025 0.5359913234149907||(3, 0, 82)||ploysaiaf12
#
# 1026 0.6928046810715266||(1, 0, 14)||5qgtl52tfp
#
# 1027 0.8403134587661258||(2, 0, 12)||ml3l0ubn4k
#
# 1028 0.9460651712514045||(5, 0, 9)||pamoo98371736
#
# 1029 0.5849823730732611||(5, 0, 112)||สัมภาษณ์
#
# 1030 0.2654782900967364||(6, 6, 318)||>
#
# 1031 0.4829718073466613||(5, 0, 169)||<
#
# 1032 0.9132286184871249||(5, 0, 15)||เดี่ยว
#
# 1033 0.6662639817859152||(5, 3, 25)||หนู
#
# 1034 0.9404294047077317||(5, 0, 10)||จิ้
#
# 1035 0.9404294047077317||(5, 0, 10)||wevj8kkulb
#
# 1036 0.25981664250491165||(2, 2, 110)||ป้าย
#
# 1037 0.020794772251940544||(4, 16, 286)||น้อง
#
# 1038 0.5322248795787595||(2, 2, 14)||ฝัน
#
# 1039 0.2571060913559215||(3, 7, 27)||า
#
# 1040 0.7781809468387362||(2, 0, 18)||focus_kittikun
#
# 1041 0.8292780797431875||(2, 0, 13)||evn9orxmr
#
# 1042 1.0||(1, 0, 0)||opv
#
# 1043 0.5893500635159308||(1, 0, 22)||สตางค์
#
# 1044 -0.04300438167383215||(1, 7, 357)||รุ่น
#
# 1045 1.0||(1, 0, 0)||ที่2
#
# 1046 0.2767955202108366||(1, 2, 16)||เด็ก
#
# 1047 0.24085509266375335||(4, 8, 101)||สร้าง
#
# 1048 0.09882179238087116||(62, 205, 1422)||จาก
#
# 1049 1.0||(1, 0, 0)||parade
#
# 1050 0.5831783046344657||(1, 1, 3)||youtu.be
#
# 1051 1.0||(1, 0, 0)||8k_ngonkgt4
#
# 1052 1.0||(1, 0, 0)||ทำopvของ
#
# 1053 1.0||(1, 0, 0)||bnk48มี
#
# 1054 -0.2975666922209377||(2, 25, 150)||ชื่อ
#
# 1055 0.9404294047077318||(1, 0, 2)||เมมเบอร์
#
# 1056 -0.06322940075292927||(1, 5, 3)||คนใน
#
# 1057 1.0||(2, 0, 0)||ทำopv
#
# 1058 0.1103211148451365||(1, 3, 37)||ประกอบ
#
# 1059 1.0||(1, 0, 0)||คลิปopv
#
# 1060 0.3064580325888553||(1, 2, 10)||เม้น
#
# 1061 0.9404294047077318||(1, 0, 2)||ไลค์
#
# 1062 1.0||(1, 0, 0)||donate
#
# 1063 0.17892037500776628||(6, 17, 62)||wallet
#
# 1064 1.0||(1, 0, 0)||0638742690
#
# 1065 0.5283777633321652||(3, 3, 22)||คลิป
#
# 1066 0.33003673483776763||(1, 2, 6)||สำรอง
#
# 1067 1.0||(1, 0, 0)||m.youtube.com
#
# 1068 1.0||(1, 0, 0)||ucnxrtuavrd7qn6yez5viz4q
#
# 1069 -0.39539565376837343||(1, 20, 109)||หลัก
#
# 1070 -0.12995403502252553||(1, 6, 15)||ลืม
#
# 1071 0.7594628002539004||(1, 0, 10)||ฝา
#
# 1072 1.0||(1, 0, 0)||กกดไลค์
#
# 1073 -0.17723245400715154||(2, 14, 49)||แชร์
#
# 1074 1.0||(1, 0, 0)||121261
#
# 1075 1.0||(5, 0, 0)||ปู
#
# 1076 0.6597527689332607||(4, 1, 47)||ยา
#
# 1077 0.32693828829476657||(2, 0, 130)||ประกาศ
#
# 1078 0.7781809468387362||(1, 0, 9)||แต่ง
#
# 1079 1.0||(3, 0, 0)||แม
#
# 1080 0.9693003027331257||(3, 0, 3)||ทธิ
#
# 1081 0.5441098644013789||(3, 3, 18)||ว
#
# 1082 0.43681207401107947||(1, 1, 17)||หนัก
#
# 1083 1.0||(1, 0, 0)||บราก
#
# 1084 -0.52445366605415||(1, 50, 235)||บริษัท
#
# 1085 0.8403134587661258||(1, 0, 6)||โป
#
# 1086 1.0||(1, 0, 0)||รดักชั่น
#
# 1087 1.0||(1, 0, 0)||เฮ้าส์
#
# 1088 0.4530560920885161||(1, 1, 15)||ตนเอง
#
# 1089 0.29350703006984885||(1, 0, 76)||มกราคม
#
# 1090 1.0||(2, 0, 0)||รีส์
#
# 1091 1.0||(1, 0, 0)||strang
#
# 1092 0.9693003027331258||(1, 0, 1)||girl
#
# 1093 0.43505636040035983||(1, 0, 41)||a
#
# 1094 1.0||(1, 0, 0)||strange
#
# 1095 1.0||(1, 0, 0)||land
#
# 1096 1.0||(1, 0, 0)||ประเดิม
#
# 1097 1.0||(1, 0, 0)||นางเอก
#
# 1098 -0.022479776806182204||(1, 5, 131)||ธุรกิจ
#
# 1099 0.34424267220814947||(1, 1, 32)||นับ
#
# 1100 -0.2533077348432524||(1, 9, 35)||เป็นการ
#
# 1101 0.9693003027331258||(1, 0, 1)||รากฐาน
#
# 1102 0.05402157872676769||(1, 3, 131)||ชีวิต
#
# 1103 1.0||(1, 0, 0)||แต่งงาน
#
# 1104 1.0||(1, 0, 0)||prayalundberg
#
# 1105 1.0||(1, 0, 0)||mrbrag
#
# 1106 0.5831783046344657||(1, 1, 3)||บรา
#
# 1107 0.22680787718790266||(3, 7, 50)||ก
#
# 1108 0.041937912782306595||(1, 4, 5)||มาส
#
# 1109 0.4994935836628514||(1, 1, 10)||นาม
#
# 1110 0.44655683743203395||(3, 4, 24)||บิน
#
# 1111 -0.5444155179546627||(1, 18, 19)||กิน
#
# 1112 0.6057020520077911||(2, 1, 22)||สนาม
#
# 1113 0.9498600259056532||(3, 0, 5)||เซล
#
# 1114 0.9221190118849634||(3, 0, 8)||ฟี่
#
# 1115 0.7297110867217907||(3, 1, 18)||สะดุด
#
# 1116 0.9895529534671136||(3, 0, 1)||ข้าพเจ้า
#
# 1117 0.45582460902249416||(3, 4, 21)||มั่นใจ
#
# 1118 0.979321931676216||(3, 0, 2)||bikeอุ่น
#
# 1119 1.0||(3, 0, 0)||mu6p5wsmb1
#
# 1120 -0.2289248740326632||(3, 27, 147)||รบกวน
#
# 1121 0.9693003027331258||(2, 0, 2)||หลักๆ
#
# 1122 0.6124975345512074||(1, 1, 1)||กทม
#
# 1123 0.14380169660862446||(1, 3, 16)||700
#
# 1124 0.9693003027331258||(1, 0, 1)||ใจจ
#
# 1125 -0.27065168781820786||(1, 10, 46)||ระ
#
# 1126 0.17397166246805815||(1, 3, 4)||สมควร
#
# 1127 0.1550017936953102||(1, 3, 11)||400
#
# 1128 0.0020610507947443368||(3, 13, 307)||นาที
#
# 1129 0.0838912688999176||(3, 11, 10)||เนท
#
# 1130 1.0||(1, 0, 0)||16gb
#
# 1131 -0.0982879912632589||(2, 13, 154)||wifi
#
# 1132 -0.034714907907236615||(1, 5, 61)||กำหนด
#
# 1133 1.0||(1, 0, 0)||16g
#
# 1134 -0.3119183520810042||(1, 22, 217)||ไมค์
#
# 1135 0.5381017544556435||(2, 2, 13)||หัวข้อ
#
# 1136 0.37309534175010883||(1, 2, 0)||งการร
#
# ...
# -0.43666738699149316||(1, 13, 17)||รีบ
# -0.13925643881167332||(4, 24, 36)||อก
# -1.0||(0, 1, 0)||ไป3ปี
# -0.9805650553039407||(0, 7, 1)||เน่า
# -1.0||(0, 6, 0)||เวน
# -0.2555217102970765||(0, 2, 42)||18
# -1.0||(0, 1, 0)||ลงค
# -0.9730009673084001||(0, 5, 1)||เท็จ
# -0.24618633384521557||(4, 33, 89)||เบ
# -0.4900620850219885||(0, 6, 45)||กรณี
# -0.9153368139906317||(0, 3, 2)||คืนให้
# 0.9266294378999714||(2, 0, 5)||ภูเก็ต
# -1.0||(0, 2, 0)||กำนัน
# -0.24677326559633522||(0, 1, 22)||แบรนด์
# -0.8781627844091628||(0, 2, 2)||คุม
# -1.0||(0, 1, 0)||ทนี้
# -1.0||(0, 1, 0)||เดือน6mbมี
# -1.0||(0, 1, 0)||ใจเย็น
# 0.7772231529283052||(20, 0, 181)||โฟกัส
# -1.0||(0, 1, 0)||เปลี่
# 0.2194139769494526||(5, 11, 121)||พูด
# -0.025540314779632926||(5, 24, 261)||โม
# -0.8781627844091628||(0, 1, 1)||green
# -1.0||(0, 1, 0)||เบียดเบียน
# -0.6431016436108518||(0, 4, 16)||โฆษณา
# -0.13718185713165024||(0, 3, 136)||http
# -0.9153368139906317||(0, 3, 2)||พอได้
# -0.8781627844091628||(0, 1, 1)||ของais
# 0.2334115079289275||(4, 9, 72)||เมือง
# -0.8781627844091628||(0, 3, 3)||29
# -0.7370485820021029||(0, 7, 18)||นั่น
# -0.37445977170716505||(3, 66, 447)||เอง
# 1.0||(1, 0, 0)||เครือ200นาที
# -0.8781627844091628||(0, 1, 1)||กิโล
# 0.544109864401379||(1, 1, 6)||bts
# -0.19156101587451493||(8, 53, 41)||พนักงาน
# -0.7913846882223523||(0, 20, 38)||นึง
# -0.935129576306047||(0, 2, 1)||พิทักษ์
# 1.0||(1, 0, 0)||เหนี่ยว
# -0.1122849199267277||(1, 14, 485)||ไทย
# -0.42593608723698684||(0, 7, 68)||ชั่วโมง
# -0.2536989090527307||(2, 20, 112)||คุย
# -1.0||(0, 1, 0)||t_t
# -1.0||(0, 1, 0)||0955243685
# -1.0||(0, 1, 0)||ปานนี้
# 0.14380169660862446||(1, 3, 16)||บบ
# -1.0||(0, 1, 0)||8888
# -0.27166123226348443||(14, 127, 385)||เรื่อง
# -0.4379521263786543||(0, 4, 37)||จี
# -0.7827898488344065||(0, 1, 2)||เงียบกริบ
# 0.9693003027331258||(2, 0, 2)||พยาม
# -0.1947615792025853||(0, 5, 149)||ระดับ
# -0.18149173062885954||(1, 7, 22)||ซะ
# 0.47055492788012415||(1, 1, 13)||แอด
# -0.9057513397214974||(0, 4, 3)||รณ์
# -0.7212442325298911||(0, 14, 39)||เชื่อ
# -1.0||(0, 4, 0)||อ้ะ
# -1.0||(0, 1, 0)||ก่
# -1.0||(0, 1, 0)||สล๊อ
# -0.49006208502198845||(0, 2, 15)||แรกๆ
# -1.0||(0, 1, 0)||48gหมุน
# -1.0||(0, 1, 0)||ควาน
# 0.6583475816048254||(3, 1, 31)||นี
# 1.0||(1, 0, 0)||ผมมี
# -0.8781627844091628||(0, 1, 1)||สัญาณ
# -1.0||(0, 1, 0)||มสิ๊
# -0.6331913672151622||(1, 31, 48)||หัก
# -1.0||(0, 1, 0)||xllodasflls
# 0.6018969344061342||(7, 1, 127)||อันดับ
# 0.9404294047077318||(2, 0, 4)||speedtest
# 0.1870530673692134||(1, 3, 0)||มัด
# 1.0||(1, 0, 0)||นางเอก
# -1.0||(0, 1, 0)||0866083025
# -1.0||(0, 1, 0)||ก็จบ
# -1.0||(0, 1, 0)||สนง.กฎหมาย
# -0.16121780324520596||(0, 2, 75)||watch
# -0.6156366787629312||(0, 2, 9)||ร้าย
# -1.0||(0, 1, 0)||มา600กว่า
# -1.0||(0, 1, 0)||แ้ว
# -1.0||(0, 1, 0)||เพิง
# -0.2250417445732004||(8, 78, 561)||คุณ
# 1.0||(2, 0, 0)||อาจารย์
# 0.4123301833747483||(1, 0, 45)||อร่อย
# -0.8781627844091628||(0, 1, 1)||xxx
# -0.5792736020141422||(6, 151, 274)||มัน
# -0.32455777165455507||(0, 3, 45)||สตาร์ท
# 1.0||(1, 0, 0)||ลิก
# -0.6431016436108518||(0, 1, 4)||นอ
# -1.0||(0, 1, 0)||centerก็
# -1.0||(0, 2, 0)||ติดต่อcallบริษัท
# -0.8781627844091628||(0, 1, 1)||ปอน
# -1.0||(0, 3, 0)||สวิง
# 0.08756495244845212||(1, 0, 329)||thailand
# -0.7827898488344065||(0, 2, 4)||เปย์
# -0.7827898488344065||(0, 1, 2)||66
# 0.7978450847576598||(1, 0, 8)||advanced
# -0.800170361349093||(0, 5, 9)||5555
# -1.0||(0, 2, 0)||บิล27
# -0.21516507554670558||(19, 141, 319)||มาก
# -1.0||(0, 1, 0)||racha
# -1.0||(0, 1, 0)||ตู๊ดดๆๆๆ
# -0.37524966573678215||(0, 1, 12)||b1
# -0.1464745716844608||(0, 1, 42)||เกียรติ
# 0.539041566879283||(2, 0, 54)||กอน
# 1.0||(2, 0, 0)||335
# -0.4313989676635798||(0, 2, 19)||6s
# -0.9557972334730145||(0, 3, 1)||หาด
# 0.8185287869513557||(1, 0, 7)||we
# -0.6431016436108518||(0, 1, 4)||tags
# -0.39585909067163527||(0, 1, 11)||เวป
# -0.8277381299155259||(0, 8, 12)||โดยที่
# -1.0||(0, 1, 0)||0826983603
# -1.0||(0, 1, 0)||ดดดดดดดดดดดด
# 0.9693003027331258||(1, 0, 1)||มา4
# -1.0||(0, 1, 0)||พนักงาน2
# -0.0959273376255756||(117, 697, 5143)||ที่
# -1.0||(0, 2, 0)||ค้าน
# 0.35646747055964123||(1, 0, 57)||ผลิต
# -0.7061034322099705||(0, 1, 3)||b
# -0.8781627844091628||(0, 1, 1)||นน
# -0.8277381299155259||(0, 8, 12)||g
# -0.812192594886208||(0, 3, 5)||เสียดาย
# 0.7504373947776715||(2, 0, 21)||ท่อง
# -0.33986156169175796||(0, 1, 14)||10.30
# 0.9693003027331258||(1, 0, 1)||แท็ค
# 0.7083476147446484||(1, 0, 13)||เบลเยียม
# -0.5904215255954082||(0, 1, 5)||บำรุง
# -1.0||(0, 1, 0)||242902684
# -0.7827898488344065||(0, 1, 2)||ทูร
# -0.878162784409163||(0, 7, 7)||พยายาม
# -0.8781627844091628||(0, 1, 1)||จนท.ก็
# -0.8781627844091628||(0, 10, 10)||320mb
# -0.23860404093413803||(0, 2, 46)||เที่ยว
# -0.8046367578090434||(0, 4, 7)||แก้ว
# -0.7061034322099705||(0, 1, 3)||แบ้
# -0.8963645444508701||(0, 6, 5)||ฟ้อง
# -0.4357457303320534||(0, 6, 56)||fi
# -1.0||(0, 1, 0)||mydtac
# -0.5904215255954082||(0, 1, 5)||พลัส
# -0.7061034322099705||(0, 1, 3)||1973
# -0.8781627844091628||(0, 1, 1)||เว้
# -1.0||(0, 2, 0)||ถ้า3gหมด
# -1.0||(0, 1, 0)||ประมาณ399บาท
# -0.10448363581975198||(1, 10, 284)||ร์ท
# -1.0||(0, 1, 0)||0637905578
# 1.0||(1, 0, 0)||ท่อน
# -0.1777460267892086||(33, 230, 765)||ค่า
# -0.4188638918062388||(0, 1, 10)||มีชื่อ
# 0.8644712324599765||(20, 0, 99)||bnk
# -1.0||(0, 2, 0)||สืบสวน
# -1.0||(0, 1, 0)||ดมาก้
# -1.0||(0, 1, 0)||ประชากร
# -0.51771974402103||(0, 14, 94)||เลข
# -1.0||(0, 1, 0)||18.50
# -0.26829611774614154||(1, 8, 8)||รับคำ
# 1.0||(1, 0, 0)||cxqdzmluem
# -0.34816637351053487||(3, 38, 146)||ตอบ
# -0.8781627844091628||(0, 1, 1)||เด็กๆ
# 0.9404294047077318||(1, 0, 2)||noeybnk48
# -1.0||(0, 1, 0)||ฟับ
# -1.0||(0, 4, 0)||รต
# -0.8781627844091628||(0, 1, 1)||อีก1000บาท
# 0.1770674293141221||(1, 3, 3)||กกก
# 1.0||(1, 0, 0)||ข้อแม้
# 0.9693003027331258||(1, 0, 1)||girl
# -1.0||(0, 1, 0)||หอย
# -0.43948266423622057||(3, 48, 131)||เดียว
# -1.0||(0, 1, 0)||กรึ
# -0.16681464957402936||(0, 3, 108)||แห่ง
# -0.6431016436108518||(0, 1, 4)||กุล
# -0.19371468986732335||(0, 1, 30)||music
# -0.7827898488344065||(0, 1, 2)||สูงๆ
# -1.0||(0, 1, 0)||ชือ
# -1.0||(0, 3, 0)||gt
# 0.30108053402925633||(1, 2, 11)||ช
# 0.9132286184871249||(1, 0, 3)||โล่
# 0.3562747400257021||(4, 5, 91)||ทั่ว
# -0.8781627844091628||(0, 1, 1)||ลงชื่อ
# -0.42878667280378846||(6, 140, 713)||!
# -0.8781627844091628||(0, 1, 1)||เฮีย
# -1.0||(0, 2, 0)||23.09
# -0.3119183520810042||(1, 22, 217)||ไมค์
# 0.3970938920100501||(10, 15, 99)||ครบ
# -1.0||(0, 1, 0)||millions4winner
# -0.7827898488344065||(0, 1, 2)||โจร
# 0.9266294378999714||(2, 0, 5)||presented
# -0.44470744732878187||(0, 1, 9)||ดาต้า
# -0.28593170240865357||(0, 1, 18)||หอ
# -1.0||(0, 1, 0)||ฉะเชิงเทรา
# -1.0||(0, 1, 0)||besidedoyoungx
# -1.0||(0, 1, 0)||เบิร์น
# -0.44470744732878187||(0, 1, 9)||เหตุการณ์
# -1.0||(0, 1, 0)||popeyesumittra
# 0.3467089763244745||(2, 4, 7)||คุน
# 0.8502324946457424||(3, 1, 1)||trinet
# -1.0||(0, 2, 0)||มกฏ
# 0.08037074040322478||(2, 4, 335)||รา
# -0.9505451428451962||(0, 8, 3)||137
# -0.8781627844091628||(0, 3, 3)||ทะลุ
# -1.0||(0, 1, 0)||แปปๆ
# -0.8781627844091628||(0, 1, 1)||ยิน
# -0.9474215031715469||(0, 5, 2)||บ่าย
# -0.09544868445969829||(1, 11, 389)||รี
# 1.0||(1, 0, 0)||ub4f7lhqpg
# 0.9132286184871249||(5, 0, 15)||เดี่ยว
# -1.0||(0, 1, 0)||วชั่น
# -0.6731315882979984||(0, 2, 7)||แปะ
# -1.0||(0, 1, 0)||ช่
# 0.47391100711312134||(15, 21, 55)||move
# 1.0||(1, 0, 0)||ทำopvของ
# 0.7083476147446484||(1, 0, 13)||chocolate
# -0.7827898488344065||(0, 1, 2)||10,000
# -0.18764057571446366||(1, 9, 81)||สิ่ง
# 0.22680787718790266||(3, 7, 50)||ก
# 0.544109864401379||(1, 1, 6)||ture
# -0.04562206091980756||(15, 74, 303)||ไหม
# -0.0675410800224828||(1, 6, 98)||24
# -0.7546882573274918||(0, 35, 82)||เหลือ
# 0.9844108604338978||(2, 0, 1)||hก็ได้
# -1.0||(0, 1, 0)||เวฟ
# -1.0||(0, 2, 0)||movieอะไร
# 0.9404294047077318||(1, 0, 2)||เมมเบอร์
# -1.0||(0, 1, 0)||ถ้าๆ
# -1.0||(0, 1, 0)||530
# -0.07570474715686763||(0, 1, 88)||นิ
# -1.0||(0, 2, 0)||เเค่6mbps
# -0.49853616815973856||(0, 4, 29)||แม้
# -0.0870780113215872||(5, 28, 145)||ต้องการ
# -0.3794010242800584||(2, 21, 18)||มาท
# -0.4109041832105222||(0, 9, 93)||ทะเบียน
# -0.8781627844091628||(0, 2, 2)||8a
# -1.0||(0, 1, 0)||คบ.รบกวน
# -1.0||(0, 1, 0)||ค่ะ0834299499
# -0.32187341311444895||(2, 18, 14)||พึ่ง
# 1.0||(1, 0, 0)||tac
# -1.0||(0, 1, 0)||ประมาท
# -0.7299397416275113||(0, 3, 8)||ครอบ
# -0.22036642109344706||(0, 2, 51)||25
# -1.0||(0, 1, 0)||แชมป
# -0.6731315882979984||(0, 8, 28)||กุ
# -0.18150124762164366||(11, 93, 762)||เครื่อง
# -1.0||(0, 1, 0)||พระคุณ
# 0.9693003027331258||(1, 0, 1)||ตำรา
# 0.2681441674003447||(1, 2, 18)||มอ
# 1.0||(1, 0, 0)||mrbrag
# -0.8781627844091628||(0, 2, 2)||มหา
# -0.10848021651103149||(23, 134, 517)||]
# -0.14272900966085036||(1, 13, 310)||รวม
# 1.0||(2, 0, 0)||tonight
# -0.5904215255954081||(0, 3, 15)||สะ
# -1.0||(0, 1, 0)||คร่าว
# -0.8781627844091628||(0, 1, 1)||แถวๆ
# -0.04177403385450245||(70, 351, 2914)||.
# 0.5516703213090701||(20, 8, 351)||แสดง
# -1.0||(0, 1, 0)||นกันอะ
# 0.17098228552369937||(1, 3, 5)||หนี
# -1.0||(0, 1, 0)||ไข้
# 0.04532162181272496||(5, 10, 1663)||&
# -0.7061034322099705||(0, 2, 6)||งาม
# -1.0||(0, 2, 0)||แก่ๆ
# -1.0||(0, 1, 0)||ซ๊า
# 0.14380169660862446||(1, 3, 16)||700
# -1.0||(0, 1, 0)||ทล
# -1.0||(0, 1, 0)||ไหวๆ
# -1.0||(0, 1, 0)||กำกวม
# -0.7827898488344065||(0, 2, 4)||สั้น
# 0.05225929344508019||(9, 34, 219)||เยอะ
# -1.0||(0, 1, 0)||สีกัน
# -1.0||(0, 1, 0)||มา923.40ถ้า
# -1.0||(0, 1, 0)||ยากๆ
# -0.8277381299155259||(0, 2, 3)||อีเมล์
# 0.4063772271167306||(5, 7, 56)||ครั
# -0.05827748032462436||(2, 10, 18)||จัง
# -0.11421528381968046||(8, 58, 778)||สามารถ
# -1.0||(0, 1, 0)||แผง
# 1.0||(1, 0, 0)||ศูนย์trueได้
# 0.5299932389900449||(4, 0, 112)||แปซิฟิก
# -1.0||(0, 1, 0)||คื
# -0.7827898488344065||(0, 1, 2)||line.me
# -0.935129576306047||(0, 2, 1)||พน
# -1.0||(0, 1, 0)||ตนี่
# -1.0||(0, 1, 0)||พร่อง
# -1.0||(0, 1, 0)||ตะกี้
# 0.45823156909326784||(7, 11, 9)||แถว
# 0.9693003027331258||(1, 0, 1)||ทันตา
# 1.0||(1, 0, 0)||4วัน
# -1.0||(0, 1, 0)||เหลือ1บา
# -0.3623415414683228||(4, 67, 375)||ม
# -1.0||(0, 1, 0)||ค่ด
# -0.8781627844091628||(0, 1, 1)||เห็นใจ
# -1.0||(0, 1, 0)||เกือบ2ชม.ไม่มี
# -0.06354930649888528||(4, 22, 223)||ทำงาน
# 0.29587653967833744||(10, 13, 341)||เลือก
# 0.1361886467440461||(1, 2, 80)||จับ
# 0.27084698509525457||(1, 0, 85)||xbyn5gx0ci
# 1.0||(1, 0, 0)||452kmpcgdg
# -1.0||(0, 1, 0)||ฟู่
# -0.007357748636206642||(2, 9, 106)||รายการ
# 0.4023311663380478||(4, 5, 62)||สวย
# -0.06723094167088098||(0, 1, 100)||ipad
# -1.0||(0, 1, 0)||เป็น299
# -0.935129576306047||(0, 4, 2)||ชา
# 0.08713560781340177||(1, 3, 61)||สมัย
# -0.7827898488344065||(0, 1, 2)||truecorp.co.th
# -0.4739497550297092||(0, 2, 16)||ดาว
# -1.0||(0, 2, 0)||สคริปต์
# -1.0||(0, 1, 0)||10เน่า
# -0.13197149983393147||(30, 205, 1594)||ของ
# -1.0||(0, 1, 0)||กราก
# -0.7827898488344065||(0, 2, 4)||otp
# -0.034714907907236615||(1, 5, 61)||200
# -0.9730009673084001||(0, 5, 1)||โปร10mbps
# -0.35668000313799325||(0, 3, 39)||วัด
# -1.0||(0, 1, 0)||new_package
# -0.825481004494044||(0, 21, 32)||เอกสาร
# -0.014443804287379175||(2, 10, 483)||แบ
# -0.8781627844091628||(0, 1, 1)||ลักษณ์
# -1.0||(0, 2, 0)||15.9g
# 0.1637701844931051||(1, 1, 110)||sim
# -0.8781627844091628||(0, 1, 1)||information
# -1.0||(0, 1, 0)||ฟีค
# -0.07902485147860909||(0, 2, 168)||ดมา
# 1.0||(1, 0, 0)||อ้อน
# 0.9132286184871249||(1, 0, 3)||bluesherbet_
# -0.9497995523501617||(0, 42, 16)||จดหมาย
# -1.0||(0, 4, 0)||จ.ม
# -0.8781627844091628||(0, 1, 1)||support
# -1.0||(0, 1, 0)||๒
# -1.0||(0, 1, 0)||0638511882
# -0.7827898488344065||(0, 1, 2)||ก้ม
# 0.42338852364367796||(1, 0, 43)||ชิด
# -1.0||(0, 1, 0)||ชูส
# -0.8781627844091628||(0, 1, 1)||ตุณ
# -0.12015442044420312||(1, 12, 339)||สุด
# 1.0||(1, 0, 0)||เฮ้าส์
# 0.7614296472244564||(15, 8, 15)||เอาชนะ
# -0.8781627844091628||(0, 1, 1)||บู
# 0.3998735374340406||(7, 3, 256)||ทดสอบ
# -0.9366114881126442||(0, 41, 20)||ร้อง
# 0.6914769237538357||(3, 2, 7)||หลง
# 0.9132286184871249||(1, 0, 3)||ณฐ
# -1.0||(0, 1, 0)||มี1ขีด
# 0.021205300514594735||(2, 7, 485)||ร่วม
# -0.7827898488344065||(0, 1, 2)||โปรด
# -1.0||(0, 1, 0)||อิผี
# -0.5457186067167582||(0, 1, 6)||บาล
# 0.29588850176756126||(1, 2, 12)||ปลด
# -1.0||(0, 2, 0)||ใส่ใจ
# -0.10188929776126973||(10, 63, 588)||หน้า
# 0.2860237360498475||(1, 2, 14)||หน่วง
# -1.0||(0, 1, 0)||ด้านๆ
# -0.41151036343472347||(1, 40, 304)||สอบ
# -0.5194966445509183||(0, 3, 20)||application
# -1.0||(0, 1, 0)||ใช้599เอง
# -1.0||(0, 1, 0)||เคลีย
# 0.9066725162525426||(4, 0, 13)||morning
# -1.0||(0, 1, 0)||pad
# -0.7827898488344065||(0, 2, 4)||เร็วๆ
# -1.0||(0, 1, 0)||เส้า
# -1.0||(0, 1, 0)||note9
# -0.7424717486445882||(0, 2, 5)||81
# -0.17723245400715154||(2, 14, 49)||แชร์
# -0.7827898488344065||(0, 1, 2)||ทกับ
# -0.9664774780519949||(0, 8, 2)||วะ
# -1.0||(0, 1, 0)||เด้วย
# -1.0||(0, 1, 0)||โฟลเดอ
# -0.33986156169175796||(0, 1, 14)||กรอก
# -1.0||(0, 1, 0)||เบิก
# -1.0||(0, 1, 0)||บริการsmsก็
# -1.0||(0, 1, 0)||งิน900หมด
# -0.5902916770570888||(1, 23, 30)||ไหร่
# 0.33003673483776763||(1, 2, 6)||48
# 0.042072518403956045||(5, 18, 381)||ชั่น
# -0.8277381299155259||(0, 2, 3)||แอน
# 0.9693003027331258||(5, 0, 5)||nperf
# 0.5212436658794396||(1, 0, 29)||ฉลาด
# -1.0||(0, 1, 0)||โวะ
# 1.0||(1, 0, 0)||ไก
# -0.2677154069965779||(45, 446, 2065)||นี้
# -1.0||(0, 1, 0)||ลดspeed
# -0.7827898488344065||(0, 1, 2)||ช่วงๆ
# -1.0||(0, 1, 0)||ในwallet
# -1.0||(0, 1, 0)||เนต320เบอ0641902199ให้
# -1.0||(0, 1, 0)||ฟอแมต
# -0.7061034322099705||(0, 1, 3)||แมน
# -0.9773991057096996||(0, 12, 2)||หงุดหงิด
# -1.0||(0, 1, 0)||คือ2ทุ่ม
# -1.0||(0, 1, 0)||จม.อะไร
# -1.0||(0, 1, 0)||ที่20ธันวาคม
# -1.0||(0, 2, 0)||ร้องไห้
# -0.4188638918062388||(0, 1, 10)||มลูก
# 0.7978450847576598||(1, 0, 8)||จอด
# 0.15369893420052377||(9, 26, 158)||ขนาด
# 0.25772407815726184||(2, 5, 6)||กระตุก
# 1.0||(2, 0, 0)||wild
# -0.9098347064911007||(0, 14, 10)||กฎหมาย
# -0.20241909202130598||(0, 5, 142)||11
# -1.0||(0, 5, 0)||งอ่ะ
# -1.0||(0, 1, 0)||หมอชิต
# -1.0||(0, 1, 0)||สมใจ
# -0.09386688163669506||(11, 68, 684)||2
# -1.0||(0, 1, 0)||1073.38
# -1.0||(0, 1, 0)||กมากๆ
# -0.6431016436108518||(0, 1, 4)||ศัพ
# 0.29350703006984885||(1, 0, 76)||มกราคม
# -0.6868776249282393||(0, 7, 23)||ประเด็น
# -1.0||(0, 3, 0)||งบ้ง
# -1.0||(0, 2, 0)||ชาย2
# -0.3659719338722071||(7, 82, 199)||เล่น
# -1.0||(0, 1, 0)||massanger
# -0.9231525173195156||(0, 5, 3)||เว่อ
# -0.3266810545810213||(3, 30, 61)||เช็ค
# -1.0||(0, 1, 0)||เน้ย
# -0.14190812378626042||(34, 225, 1168)||เดือน
# -1.0||(0, 1, 0)||คsmsเลย
# -0.8277381299155258||(0, 6, 9)||ทุน
# -0.2309583557691331||(0, 2, 48)||ไฟฟ้า
# -1.0||(0, 1, 0)||ดร.ปิย
# -0.7827898488344065||(0, 1, 2)||สส
# -1.0||(0, 1, 0)||จม.ส่ง
# -0.32360092310463934||(3, 37, 170)||รู้
# 0.8875570999102018||(1, 0, 4)||droidsans.com
# 0.5831783046344657||(1, 1, 3)||ชลบุรี
# 0.1770674293141221||(1, 3, 3)||อร์เน็ท
# -1.0||(0, 1, 0)||4mbs
# -1.0||(0, 1, 0)||21gb
# -0.11219008119464104||(8, 54, 576)||เครือ
# 0.8875570999102018||(1, 0, 4)||ควงแขน
# -1.0||(0, 1, 0)||นิ่ม
# 0.7083476147446484||(1, 0, 13)||ครีม
# 1.0||(1, 0, 0)||เกี่ยง
# -1.0||(0, 1, 0)||ที่8
# -0.4829925263400365||(2, 32, 53)||อ
# -0.6431016436108518||(0, 1, 4)||พอดู
# -0.4242453149862559||(3, 110, 758)||มูฟ
# 0.35014967029778976||(18, 30, 221)||ขาย
# 0.6928046810715266||(1, 0, 14)||5qgtl52tfp
# -1.0||(0, 1, 0)||กาก5555555
# -1.0||(0, 1, 0)||เหมือนsevenก็
# -1.0||(0, 1, 0)||กา่ร
# 0.9693003027331258||(2, 0, 2)||sd
# -0.7827898488344065||(0, 1, 2)||or
# -1.0||(0, 1, 0)||เจ๊ง
# 0.2695136784375506||(6, 11, 140)||ต่าง
# -1.0||(0, 1, 0)||เนื้อหา
# -1.0||(0, 1, 0)||2นาที
# -0.26491324158344304||(0, 1, 20)||ตุลาคม
# -1.0||(0, 1, 0)||คัดค้าน
# -1.0||(0, 1, 0)||ยยยยยยยยยยยยย
# -0.35668000313799325||(0, 2, 26)||600
# -0.7827898488344065||(0, 2, 4)||ตรู
# -1.0||(0, 2, 0)||แม่ง
# -0.17791569369068622||(11, 77, 265)||ตาม
# -1.0||(0, 1, 0)||ละเหี่ย
# 0.9844108604338978||(2, 0, 1)||ครา
# 0.16691789070426408||(2, 3, 164)||แพ็ก
# -1.0||(0, 1, 0)||พอควร
# 0.6852862267506707||(2, 0, 29)||map
# -0.7827898488344065||(0, 1, 2)||พนง
# -1.0||(0, 1, 0)||ปรืดๆ
# -1.0||(0, 1, 0)||rsklf0he85
# -0.935129576306047||(0, 2, 1)||ลค
# -1.0||(0, 1, 0)||จิ้ม
# 0.3575461251229868||(1, 2, 2)||ใข้
# -0.8781627844091628||(0, 1, 1)||สลิป
# -1.0||(0, 1, 0)||ร่อ
# -0.2977433170488926||(0, 1, 17)||299
# 1.0||(2, 0, 0)||22.25
# 0.8875570999102018||(1, 0, 4)||major
# 0.2570754194301292||(1, 1, 56)||สาว
# -1.0||(0, 1, 0)||0931457237
# -1.0||(0, 1, 0)||ก3วัน
# 0.716142537666317||(3, 2, 3)||สอน
# -0.8781627844091628||(0, 1, 1)||สสส
# 0.5090090207078518||(3, 1, 70)||gb
# -0.18614050758643402||(1, 14, 240)||พบ
# -0.7827898488344065||(0, 5, 10)||หู
# -0.9057513397214974||(0, 4, 3)||t
# 0.9693003027331258||(2, 0, 2)||entertainment
# -0.6731315882979984||(0, 2, 7)||โคราช
# -0.08610528229563584||(0, 2, 153)||62
# -0.39585909067163527||(0, 1, 11)||128
# -1.0||(0, 1, 0)||แค่h
# 0.3227007917137937||(52, 103, 403)||กว่า
# -1.0||(0, 1, 0)||ก้มๆ
# -1.0||(0, 1, 0)||อ้างอิง99999999999อะไร
# None
